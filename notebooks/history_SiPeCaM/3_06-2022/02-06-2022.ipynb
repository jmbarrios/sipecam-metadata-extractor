# %% [markdown]
# # Next delivery: `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022`

# %% [markdown]
# ## List of files to extract metadata

# %%
# %%bash
# dir_with_sipecam_data=/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022
# list_of_files_and_subdirectories_to_extract_metadata --input_directory "$dir_with_sipecam_data"

# %% [markdown]
# ## Check

# %%
# %%bash
# ls -lh /shared_volume/sipecam_subdirectories_02-06-2022.txt
# Out:
# -rw-r--r-- 1 root root 15K Jun  2 12:26 /shared_volume/sipecam_subdirectories_02-06-2022.txt

# %%
# %%bash
# ls -lh /shared_volume/sipecam_files_to_extract_metadata_from_02-06-2022.txt
# Out:
# -rw-r--r-- 1 root root 10M Jun  2 12:26 /shared_volume/sipecam_files_to_extract_metadata_from_02-06-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_02-06-2022.txt
# Out:
# 130 /shared_volume/sipecam_subdirectories_02-06-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_02-06-2022.txt
# Out:
# 82548 /shared_volume/sipecam_files_to_extract_metadata_from_02-06-2022.txt

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_02-06-2022.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# 20210910_214000.WAV
# 20210910_215000.WAV
# 20210910_220000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# 19700101_000026.WAV
# 20210811_180000.WAV
# 20210811_182000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# 20210821_190000.WAV
# 20210821_192000.WAV
# 20210821_194000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# 20210805_100000.WAV
# 20210805_101000.WAV
# 20210805_102000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# 20210805_084432.WAV
# 20210805_180000.WAV
# 20210805_182000.WAV
# ...

# %% [markdown]
# **Files to be checked**

# %% [markdown]
# "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262012/0~FA674D.WAV" has 0 bytes then will be moved to dir error inside latter dir

# %% [markdown]
# "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10263609/memoria vacia.jpg" as is the only file in "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10263609" then latter dir will be deleted from: `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262223/memoria vacia.jpg" as is the only file in "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262223/" then latter dir will be deleted from: `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/ -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# ...

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# ...

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# ...

# %% [markdown]
# # Checking result of `extract`

# %% [markdown]
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262012
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262223
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/2
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/1
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS
#
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS

# %% [markdown]
# # 1)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262012` has no sipecam files (audios, images, videos), removing from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # 2)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262223` has no sipecam files (audios, images, videos), removing from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # 3)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480` has no sipecam files (audios, images, videos), removing from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # 4)

# %% [markdown]
# **Executing without parallel feature**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/read_metadata_audio.py", line 147, in extract_date
#     return get_date(comment_metadata)#example: 2021-07-28
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_050000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_050000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_050000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210924_050000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609",
#   "FileSize": "5.5 MiB",
#   "FileModifyDate": "2021:09:24 06:01:00-05:00",
#   "FileAccessDate": "2022:06:05 04:38:25-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:28:22-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "File format error"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ...

# %% [markdown]
# **Moving file to dir** `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_050000.WAV"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# mv "$file" "$dir_dst"

# %% [markdown]
# **Rerunning without parallel feature**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/read_metadata_audio.py", line 147, in extract_date
#     return get_date(comment_metadata)#example: 2021-07-28
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_053000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_053000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_053000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210924_053000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609",
#   "FileSize": "5.5 MiB",
#   "FileModifyDate": "2021:09:24 06:31:00-05:00",
#   "FileAccessDate": "2022:06:05 04:44:51-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:28:23-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "File format error"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ...

# %% [markdown]
# **Moving file to dir** `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_053000.WAV"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# mv "$file" "$dir_dst"

# %% [markdown]
# **Rerunning without parallel feature**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/read_metadata_audio.py", line 147, in extract_date
#     return get_date(comment_metadata)#example: 2021-07-28
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_061000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_061000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_061000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210924_061000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609",
#   "FileSize": "5.5 MiB",
#   "FileModifyDate": "2021:09:24 07:11:00-05:00",
#   "FileAccessDate": "2022:06:05 04:55:53-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:28:23-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "File format error"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ...

# %% [markdown]
# ### As there are three files with the same problem this would be added into `check` of `simex` of `audio` cli files

# %%
# %%bash
# dir_audios="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# ls "$dir_audios"| wc -l
# Out:
# 150

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# ...

# %%
# %%bash
# dir_audios="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# ls "$dir_audios"| wc -l
# Out:
# 154

# %% [markdown]
# **Rerunning without parallel feature**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 11, in <module>
#     load_entry_point('simex', 'console_scripts', 'extract_serial_numbers_dates_and_metadata_of_files_and_device')()
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_104000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_104000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_104000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210923_104000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609",
#   "FileSize": "5.5 MiB",
#   "FileModifyDate": "2021:09:23 11:41:00-05:00",
#   "FileAccessDate": "2022:06:05 11:34:50-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:28:01-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "First 2.7 MiB of file is binary 0xff's"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ...

# %% [markdown]
# **Moving file to dir** `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_104000.WAV"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# mv "$file" "$dir_dst"

# %% [markdown]
# **Rerunning without parallel feature**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 11, in <module>
#     load_entry_point('simex', 'console_scripts', 'extract_serial_numbers_dates_and_metadata_of_files_and_device')()
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_103000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_103000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_103000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210923_103000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609",
#   "FileSize": "5.5 MiB",
#   "FileModifyDate": "2021:09:23 11:31:00-05:00",
#   "FileAccessDate": "2022:06:05 11:49:55-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:28:01-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "Entire file is binary 0xff's"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ...

# %% [markdown]
# **Moving file to dir** `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210923_103000.WAV"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error"
# mv "$file" "$dir_dst"

# %% [markdown]
# **Rerunning**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 5)

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 11, in <module>
#     load_entry_point('simex', 'console_scripts', 'extract_serial_numbers_dates_and_metadata_of_files_and_device')()
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 27, in extract_metadata
#     date_of_file = read_metadata_audio.extract_date(filename)
# ...

# %% [markdown]
# **Problematic file:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/20210913_042000.WAV`

# %%
# %%bash
# file="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/20210913_042000.WAV"
# exiftool -a -j "$file"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/20210913_042000.WAV",
#   "ExifToolVersion": 12.41,
#   "FileName": "20210913_042000.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223",
#   "FileSize": "22 MiB",
#   "FileModifyDate": "2021:09:13 05:20:30-05:00",
#   "FileAccessDate": "2022:06:05 12:23:36-05:00",
#   "FileInodeChangeDate": "2022:04:27 17:24:35-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "Entire file is binary 0xff's"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ...

# %% [markdown]
# ### As there are three files with the same problem this would be added into `check` of `simex` of `audio` cli files

# %%
# %%bash
# dir_audios="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/error"
# ls "$dir_audios"| wc -l
# Out:
# 200

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# ...

# %%
# %%bash
# dir_audios="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/error"
# ls "$dir_audios"| wc -l
# Out:
# 201

# %% [markdown]
# **Rerunning**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 6)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/2` has no sipecam files (audios, images, videos), removing from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # 7)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/1` has no sipecam files (audios, images, videos), removing from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %% [markdown]
# # 8)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX`

# %%
from simex import read_metadata_image

# %%
import os

# %%
d = "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX"
img = "RCNX0049.JPG"

# %%
filename = os.path.join(d,img)

# %%
filename
# Out:
# '/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0049.JPG'

# %%
m_device = read_metadata_image.get_metadata_of_device(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 m_device = read_metadata_image.get_metadata_of_device(filename)
#
# File /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/read_metadata_image.py:59, in get_metadata_of_device(filename)
#      57 dict_metadata_of_device = {}
#      58 for k,v in TAGS_FOR_DEVICE.items():
# ---> 59     dict_metadata_of_device[v] = exiftool_metadata[k]
#      60 return dict_metadata_of_device
#
# KeyError: 'EXIF:Make'

# %%
# %%bash
# filename="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0049.JPG"
# exiftool -a -j "$filename"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0049.JPG",
#   "ExifToolVersion": 12.41,
#   "FileName": "RCNX0049.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX",
#   "FileSize": "642 KiB",
#   "FileModifyDate": "2022:01:07 14:32:54-06:00",
#   "FileAccessDate": "2022:06:05 23:18:49-05:00",
#   "FileInodeChangeDate": "2022:04:27 22:39:49-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "Entire file is binary zeros"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ...

# %%
vid="RCNX0003.AVI"

# %%
from simex import read_metadata_video

# %%
filename = os.path.join(d,vid)

# %%
filename
# Out:
# '/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0003.AVI'

# %%
m_device = read_metadata_video.get_metadata_of_file(filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 m_device = read_metadata_video.get_metadata_of_file(filename)
#
# File /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/src/simex/read_metadata_video.py:47, in get_metadata_of_file(filename)
#      45 with exiftool.ExifTool() as et:
#      46     exiftool_metadata_2 = et.get_tags(TAGS_2_FOR_FILE.keys(), filename)
# ---> 47 hachoir_metadata_dict  = metadata_hachoir(filename).exportDictionary()
#      48 bit_rate               = hachoir_metadata_dict["Common"]["Bit rate"]
#      49 endianness             = hachoir_metadata_dict["Common"]["Endianness"]
#
# AttributeError: 'NoneType' object has no attribute 'exportDictionary'

# %%
# %%bash
# filename="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0003.AVI"
# exiftool -a -j "$filename"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX/RCNX0003.AVI",
#   "ExifToolVersion": 12.41,
#   "FileName": "RCNX0003.AVI",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX",
#   "FileSize": "17 MiB",
#   "FileModifyDate": "2022:01:07 14:21:21-06:00",
#   "FileAccessDate": "2022:06:05 23:34:01-05:00",
#   "FileInodeChangeDate": "2022:04:27 22:39:44-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "Error": "Entire file is binary zeros"
# }]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ...

# %% [markdown]
# **All of the files of dir are empty**

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %% [markdown]
# # 9)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2`

# %% [markdown]
# **This dir has only Videos but at the level: `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/` there are dirs of images:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa`

# %%
# %%bash
# filename="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2/FOTOS Camara-trampa 2_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$filename"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048480"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2/RCNX4280.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:30 00:25:00",
#             "SerialNumber": "HLPXGM09048480",
#             "FileSize": "290 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# filename="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa/FOTOS Cámara-trampa_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$filename"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS C\u00e1mara-trampa/RCNX6241.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:08:31 19:18:40",
#             "SerialNumber": "HLPXGM09049482",
#             "FileSize": "244 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %% [markdown]
# **It seems that `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2` and `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2` are related and one solution is that they be combined into one dir, then run simex again in this new dir.**

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX1800.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX1805.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2264.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2339.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2623.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2625.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2818.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/RCNX2820.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/"
# ls "$dir"
# Out:
# VIDEOS CAMARA 2_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/VIDEOS CAMARA 2/` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %% [markdown]
# **Rerunning extract to `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 10)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS`

# %% [markdown]
# Similar case to `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2` but in the level
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/`
#
# there is only one dir of images:
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS`
#
# Then, videos will be moved to dir of images and dir of videos will be removed from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0051.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0054.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0057.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0060.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0063.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0066.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS/RCNX0069.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %% [markdown]
# **Rerunning extract to `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 11)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS`

# %% [markdown]
# In the level
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/`
#
# there is only one dir of images:
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS`
#
# Then, videos will be moved to dir of images and dir of videos will be removed from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0021.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0024.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0027.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0030.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS/RCNX0033.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %% [markdown]
# **Rerunning extract to `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 12)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS`

# %% [markdown]
# In the level
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/`
#
# there is only one dir of images:
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS`
#
# Then, videos will be moved to dir of images and dir of videos will be removed from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %% [markdown]
# **Rerunning extract to `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 13)

# %% [markdown]
# Same as last

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0024.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO/RCNX0027.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO"
# ls "$dir"
# Out:
# VIDEO_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/VIDEO` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 14)

# %% [markdown]
# Same as last

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0030.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS/RCNX0033.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 15)

# %% [markdown]
# Same as last

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 16)

# %% [markdown]
# Same as last

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/FOTOS`

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 17)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 18)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 19)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 20)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 21)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 22)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 23)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 24)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 25)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 26)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 27)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 28)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS`
#
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 29)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 30)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0210.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0213.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0216.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0219.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0222.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0225.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS/RCNX0228.AVI

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 31)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS/RCNX0018.AVI

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 32)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 33)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 34)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0186.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0189.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0192.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0195.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0198.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0201.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS/RCNX0204.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 35)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 36)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 37)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 14

# %% [markdown]
# # 38)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 39)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 40)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 41)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 14

# %% [markdown]
# # 42)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO"
# ls "$dir"
# Out:
# VIDEO_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/VIDEO` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 43)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS/RCNX0021.AVI

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # 44)

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS`

# %% [markdown]
# Same as last

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# dir_src="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS"
# dir_dst="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS"
# for f in $(ls "$dir_src"/*.AVI);do echo "$f"; mv "$f" "$dir_dst/";done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0006.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0018.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS/RCNX0021.AVI
# ...

# %%
# %%bash
# dir="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS"
# ls "$dir"
# Out:
# VIDEOS_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs

# %% [markdown]
# **Removing `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/VIDEOS` from `/shared_volume/sipecam_subdirectories_02-06-2022.txt`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
