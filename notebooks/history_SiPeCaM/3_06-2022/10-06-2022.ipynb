# %% [markdown]
# # Continuation [02-06-2022.ipynb](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/3_06-2022/02-06-2022.ipynb)

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3 2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262012
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262039
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480
# Traceback (most recent call last):
#   File "/usr/local/bin/move_files_to_standard_directory", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/move_files_to_standard_directory.py", line 369, in main
#     dict_source = json.load(f)
#   File "/usr/lib/python3.8/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Grabadoras/Audible/10261149
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/5
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048480
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/100RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/101RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/100RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX

# %% [markdown]
# # Check

# %% [markdown]
# Eliminar `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480` de `/shared_volume/sipecam_subdirectories_02-06-2022.txt` dado que no tiene archivos

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_02-06-2022.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# 1407
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# 681
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# 2730
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# 2730
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3
# 539
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3 2
# 142
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21
# 807
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262012
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth
# 621
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153
# 494
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403
# 4470
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719
# 1875
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153
# 1822
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526
# 788
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606
# 1875
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333
# 807
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403
# 1350
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10263609
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262039
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Grabadoras/Audible/10261149
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609
# 4
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
# 526
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
# 1163
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/4
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/5
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/3
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2
# 859
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa
# 587
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T4/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T3/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1399 LAS PIEDRAS/Camara-Trampa-T1/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048480
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049482/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049093/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM04049093/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048480/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09049482/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048483/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048507/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048448/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048449/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/NODO 3_13_0_1401 EL SANTUARIO/HLPXGM09048209/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049504/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049482/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09049093/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS
# 21
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048507/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/102RECNX/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/100RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048449/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS
# 291
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048480/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049504/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS
# 240
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048507/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048448/FOTOS
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS
# 21
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS
# 83
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa
# 587
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2
# 859
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/101RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/100RECNX
# 1
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/2
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX
# 0

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_02-06-2022.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# Number of files: 1407
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:38:25,898 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609 has serial number 248C7D075B1F40B4
# 2022-06-10 11:38:25,900 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/20210910_224000.WAV has date 2021-09-10
# 2022-06-10 11:38:25,900 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/20210920_031000.WAV has date 2021-09-20
# 2022-06-10 11:38:25,900 [INFO]  DaysBetweenFirstAndLastDate: 10
# 2022-06-10 11:38:26,054 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-09-10", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:38:26,054 [INFO]  last query wasn't successful
# 2022-06-10 11:38:26,185 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:38:26,189 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:38:26,189 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# Number of files: 2730
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:43:40,407 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth has serial number 243B1F055B1F800E
# 2022-06-10 11:43:40,408 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth/20210803_160000.WAV has date 2021-08-03
# 2022-06-10 11:43:40,409 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth/20210822_040000.WAV has date 2021-08-22
# 2022-06-10 11:43:40,409 [INFO]  DaysBetweenFirstAndLastDate: 19
# 2022-06-10 11:43:40,541 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-03", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-22", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:43:40,541 [INFO]  list index out of range
# 2022-06-10 11:43:40,542 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-03", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-22", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# Number of files: 2730
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:43:40,883 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3 has serial number 243B1F055B1F800E
# 2022-06-10 11:43:40,885 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3/20210803_160000.WAV has date 2021-08-03
# 2022-06-10 11:43:40,885 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3/20210822_040000.WAV has date 2021-08-22
# 2022-06-10 11:43:40,885 [INFO]  DaysBetweenFirstAndLastDate: 19
# 2022-06-10 11:43:41,018 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-03", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-22", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:43:41,018 [INFO]  list index out of range
# 2022-06-10 11:43:41,019 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-03", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-22", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21
# Number of files: 807
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:46:01,671 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21 has serial number 243B1F055B1F800E
# 2022-06-10 11:46:01,673 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21/20211021_202000.WAV has date 2021-10-21
# 2022-06-10 11:46:01,673 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21/20211129_010000.WAV has date 2021-11-29
# 2022-06-10 11:46:01,673 [INFO]  DaysBetweenFirstAndLastDate: 39
# 2022-06-10 11:46:01,807 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:46:01,807 [INFO]  list index out of range
# 2022-06-10 11:46:01,808 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth
# Number of files: 621
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:18,551 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth has serial number 248C7D075B1F81A3
# 2022-06-10 11:47:18,553 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth/20220201_230000.WAV has date 2022-02-01
# 2022-06-10 11:47:18,553 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth/20220218_004000.WAV has date 2022-02-18
# 2022-06-10 11:47:18,553 [INFO]  DaysBetweenFirstAndLastDate: 17
# 2022-06-10 11:47:18,698 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-02-01", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-18", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:18,699 [INFO]  last query wasn't successful
# 2022-06-10 11:47:18,821 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:18,824 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:18,824 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153
# Number of files: 494
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:19,123 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153 has serial number 248C7D075B1F81A3
# 2022-06-10 11:47:19,124 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153/20220118_222000.WAV has date 2022-01-18
# 2022-06-10 11:47:19,124 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153/20220201_012000.WAV has date 2022-02-01
# 2022-06-10 11:47:19,124 [INFO]  DaysBetweenFirstAndLastDate: 14
# 2022-06-10 11:47:19,255 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-18", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:19,255 [INFO]  last query wasn't successful
# 2022-06-10 11:47:19,380 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:19,383 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:19,384 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403
# Number of files: 4470
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:19,738 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403 has serial number 242A260460374ABF
# 2022-06-10 11:47:19,739 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403/20220118_132000.WAV has date 2022-01-18
# 2022-06-10 11:47:19,739 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403/20220218_005000.WAV has date 2022-02-18
# 2022-06-10 11:47:19,739 [INFO]  DaysBetweenFirstAndLastDate: 31
# 2022-06-10 11:47:19,870 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-18", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-18", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:19,870 [INFO]  last query wasn't successful
# 2022-06-10 11:47:19,996 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:19,999 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:20,000 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719
# Number of files: 1875
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:20,326 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719 has serial number 2410660659442C2B
# 2022-06-10 11:47:20,328 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719/20211007_230000.WAV has date 2021-10-07
# 2022-06-10 11:47:20,328 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719/20211128_000000.WAV has date 2021-11-28
# 2022-06-10 11:47:20,328 [INFO]  DaysBetweenFirstAndLastDate: 52
# 2022-06-10 11:47:20,459 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2410660659442C2B", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-28", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:20,459 [INFO]  list index out of range
# 2022-06-10 11:47:20,460 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2410660659442C2B", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-28", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153
# Number of files: 1822
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:20,795 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153 has serial number 248C7D075B1F81A3
# 2022-06-10 11:47:20,796 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153/20211007_230000.WAV has date 2021-10-07
# 2022-06-10 11:47:20,796 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153/20211127_000000.WAV has date 2021-11-27
# 2022-06-10 11:47:20,796 [INFO]  DaysBetweenFirstAndLastDate: 51
# 2022-06-10 11:47:20,928 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:20,929 [INFO]  last query wasn't successful
# 2022-06-10 11:47:21,057 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:21,060 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:21,060 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F81A3", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526
# Number of files: 788
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:21,360 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526 has serial number 242A260460371EBA
# 2022-06-10 11:47:21,361 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526/20211021_085000.WAV has date 2021-10-21
# 2022-06-10 11:47:21,361 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526/20211026_024000.WAV has date 2021-10-26
# 2022-06-10 11:47:21,362 [INFO]  DaysBetweenFirstAndLastDate: 5
# 2022-06-10 11:47:21,495 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460371EBA", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-10-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:21,495 [INFO]  last query wasn't successful
# 2022-06-10 11:47:21,619 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460371EBA", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:21,622 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:21,623 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460371EBA", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606
# Number of files: 1875
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:21,948 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606 has serial number 2410660659442C2B
# 2022-06-10 11:47:21,949 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606/20211007_230000.WAV has date 2021-10-07
# 2022-06-10 11:47:21,950 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606/20211128_000000.WAV has date 2021-11-28
# 2022-06-10 11:47:21,950 [INFO]  DaysBetweenFirstAndLastDate: 52
# 2022-06-10 11:47:22,089 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2410660659442C2B", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-28", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:22,089 [INFO]  list index out of range
# 2022-06-10 11:47:22,090 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2410660659442C2B", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-28", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333
# Number of files: 807
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:22,386 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333 has serial number 243B1F055B1F800E
# 2022-06-10 11:47:22,387 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333/20211021_202000.WAV has date 2021-10-21
# 2022-06-10 11:47:22,387 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333/20211129_010000.WAV has date 2021-11-29
# 2022-06-10 11:47:22,388 [INFO]  DaysBetweenFirstAndLastDate: 39
# 2022-06-10 11:47:22,523 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:22,523 [INFO]  list index out of range
# 2022-06-10 11:47:22,524 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F800E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403
# Number of files: 1350
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 11:47:22,828 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403 has serial number 242A260460374ABF
# 2022-06-10 11:47:22,829 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403/20211021_230000.WAV has date 2021-10-21
# 2022-06-10 11:47:22,829 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403/20211127_212000.WAV has date 2021-11-27
# 2022-06-10 11:47:22,829 [INFO]  DaysBetweenFirstAndLastDate: 37
# 2022-06-10 11:47:22,962 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-21", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 11:47:22,962 [INFO]  last query wasn't successful
# 2022-06-10 11:47:23,091 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 11:47:23,094 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 11:47:23,095 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM242A260460374ABF", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
# Number of files: 526
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:03:30,509 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609 has serial number 248C7D075B1F40B4
# 2022-06-10 12:03:30,510 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210920_235000.WAV has date 2021-09-20
# 2022-06-10 12:03:30,510 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/20210924_080000.WAV has date 2021-09-24
# 2022-06-10 12:03:30,510 [INFO]  DaysBetweenFirstAndLastDate: 4
# 2022-06-10 12:03:30,647 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-09-20", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-24", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:03:30,648 [INFO]  last query wasn't successful
# 2022-06-10 12:03:30,771 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:03:30,774 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 12:03:30,774 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F40B4", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
# Number of files: 1163
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:03:31,077 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223 has serial number 243B1F055B1F3F3E
# 2022-06-10 12:03:31,078 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/20210811_180000.WAV has date 2021-08-11
# 2022-06-10 12:03:31,078 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/20210915_024000.WAV has date 2021-09-15
# 2022-06-10 12:03:31,078 [INFO]  DaysBetweenFirstAndLastDate: 35
# 2022-06-10 12:03:31,211 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F3F3E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-11", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-15", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:03:31,211 [INFO]  last query wasn't successful
# 2022-06-10 12:03:31,335 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F3F3E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:03:31,338 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 12:03:31,339 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F3F3E", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2
# Number of files: 859
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:16:20,716 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2 has serial number HLPXGM09048480
# 2022-06-10 12:16:20,717 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2/RCNX1180.JPG has date 2021-08-15
# 2022-06-10 12:16:20,717 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2/RCNX4383.JPG has date 2021-09-30
# 2022-06-10 12:16:20,717 [INFO]  DaysBetweenFirstAndLastDate: 46
# 2022-06-10 12:16:20,863 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-15", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-30", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:16:20,863 [INFO]  last query wasn't successful
# 2022-06-10 12:16:20,988 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:16:20,992 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:16:20,992 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa
# Number of files: 587
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:16:21,294 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa has serial number HLPXGM09049482
# 2022-06-10 12:16:21,295 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa/RCNX3649.JPG has date 2021-08-23
# 2022-06-10 12:16:21,295 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa/RCNX4019.JPG has date 2021-09-26
# 2022-06-10 12:16:21,295 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-06-10 12:16:21,426 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-23", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:16:21,426 [INFO]  last query wasn't successful
# 2022-06-10 12:16:21,551 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:16:21,554 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:16:21,554 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS
# Number of files: 21
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:21:07,214 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS has serial number HLPXGM09048483
# 2022-06-10 12:21:07,215 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS/RCNX0209.JPG has date 2021-10-30
# 2022-06-10 12:21:07,215 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS/RCNX0228.AVI has date 2021-11-26
# 2022-06-10 12:21:07,215 [INFO]  DaysBetweenFirstAndLastDate: 27
# 2022-06-10 12:21:07,350 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-30", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:21:07,350 [INFO]  last query wasn't successful
# 2022-06-10 12:21:07,473 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:21:07,477 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:21:07,477 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS
# Number of files: 291
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:21:33,513 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS has serial number HLPXGM09048209
# 2022-06-10 12:21:33,515 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS/RCNX0206.JPG has date 2021-10-22
# 2022-06-10 12:21:33,515 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS/RCNX0474.AVI has date 2021-11-29
# 2022-06-10 12:21:33,515 [INFO]  DaysBetweenFirstAndLastDate: 38
# 2022-06-10 12:21:33,659 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-22", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:21:33,659 [INFO]  last query wasn't successful
# 2022-06-10 12:21:33,792 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:21:33,794 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 12:21:33,795 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS
# Number of files: 240
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:23:01,508 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS has serial number HLPXGM09048483
# 2022-06-10 12:23:01,510 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS/RCNX0004.JPG has date 2022-02-24
# 2022-06-10 12:23:01,510 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS/RCNX0240.AVI has date 2022-04-01
# 2022-06-10 12:23:01,510 [INFO]  DaysBetweenFirstAndLastDate: 36
# 2022-06-10 12:23:01,650 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-02-24", valueType: String, operator: gte}, {field: date_deployment, value: "2022-04-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:23:01,650 [INFO]  last query wasn't successful
# 2022-06-10 12:23:01,778 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:23:01,781 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:23:01,781 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048483", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS
# Number of files: 21
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:24:15,184 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS has serial number HLPXGM09048449
# 2022-06-10 12:24:15,185 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS/RCNX0004.JPG has date 2022-02-24
# 2022-06-10 12:24:15,185 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS/RCNX0021.AVI has date 2022-03-24
# 2022-06-10 12:24:15,186 [INFO]  DaysBetweenFirstAndLastDate: 28
# 2022-06-10 12:24:15,330 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048449", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-02-24", valueType: String, operator: gte}, {field: date_deployment, value: "2022-03-24", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:24:15,330 [INFO]  last query wasn't successful
# 2022-06-10 12:24:15,455 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048449", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:24:15,459 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:24:15,459 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048449", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS
# Number of files: 83
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:24:15,745 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS has serial number HLPXGM09048209
# 2022-06-10 12:24:15,746 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS/RCNX0004.JPG has date 2022-02-24
# 2022-06-10 12:24:15,747 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS/RCNX0081.AVI has date 2022-04-01
# 2022-06-10 12:24:15,747 [INFO]  DaysBetweenFirstAndLastDate: 36
# 2022-06-10 12:24:15,881 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-02-24", valueType: String, operator: gte}, {field: date_deployment, value: "2022-04-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:24:15,881 [INFO]  last query wasn't successful
# 2022-06-10 12:24:16,007 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:24:16,010 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-06-10 12:24:16,011 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048209", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa
# Number of files: 587
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:24:16,314 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa has serial number HLPXGM09049482
# 2022-06-10 12:24:16,316 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/RCNX3649.JPG has date 2021-08-23
# 2022-06-10 12:24:16,316 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/RCNX4019.JPG has date 2021-09-26
# 2022-06-10 12:24:16,316 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-06-10 12:24:16,454 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-23", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:24:16,455 [INFO]  last query wasn't successful
# 2022-06-10 12:24:16,579 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:24:16,582 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:24:16,582 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2
# Number of files: 859
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2/logs_simex_move_files_to_standard_directory.logs
# 2022-06-10 12:24:16,888 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2 has serial number HLPXGM09048480
# 2022-06-10 12:24:16,889 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2/RCNX1180.JPG has date 2021-08-15
# 2022-06-10 12:24:16,889 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2/RCNX4383.JPG has date 2021-09-30
# 2022-06-10 12:24:16,889 [INFO]  DaysBetweenFirstAndLastDate: 46
# 2022-06-10 12:24:17,018 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-15", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-30", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-06-10 12:24:17,018 [INFO]  last query wasn't successful
# 2022-06-10 12:24:17,143 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-06-10 12:24:17,146 [INFO]  list indices must be integers or slices, not NoneType
# 2022-06-10 12:24:17,147 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048480", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------

# %% [markdown]
# # Are there images, videos, recordings that still need to be moved?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/ -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# if [ -f ~/list_dirs_with_images.txt ]; then
#      rm ~/list_dirs_with_images.txt
# fi
# if [ -f ~/list_dirs_with_images_auxiliary.txt ]; then
#      rm ~/list_dirs_with_images_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/ -name "*.JPG")
#   do
#      dir_image=$(dirname $f)
#      echo "$dir_image" >> ~/list_dirs_with_images_auxiliary.txt
# done
# dirs_image=$(cat ~/list_dirs_with_images_auxiliary.txt|uniq)
# echo "$dirs_image" > ~/list_dirs_with_images.txt
# IFS=$SAVEIFS

# %%
# %%bash
# if [ -f ~/list_dirs_with_videos.txt ]; then
#      rm ~/list_dirs_with_videos.txt
# fi
# if [ -f ~/list_dirs_with_videos_auxiliary.txt ]; then
#      rm ~/list_dirs_with_videos_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/ -name "*.AVI")
#   do
#      dir_video=$(dirname $f)
#      echo "$dir_video" >> ~/list_dirs_with_videos_auxiliary.txt
# done
# dirs_video=$(cat ~/list_dirs_with_videos_auxiliary.txt|uniq)
# echo "$dirs_video" > ~/list_dirs_with_videos.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/AudioMoths.N5.T4/Audio/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 2/Ultra.N5.T3 2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/21-10-21 a 29-11-21
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262012/error/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/Audiomoth
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10262153
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/NODO 3_13_0_1401 EL SANTUARIO/10309403
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262719
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262153
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10306526
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10263606
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10262333
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1400 VILLAROSA/10309403
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10263609/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262012/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262223/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Grabadoras/Audible/10261149/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10263609
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/GRABADORAS/ultra/10262223
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/4/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/2/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/1/error
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/GRABADORAS/5/error

# %%
# %%bash
# cat ~/list_dirs_with_images.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Cámara-trampa
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/100RECNX

# %%
# %%bash
# cat ~/list_dirs_with_videos.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/found.000/dir0000.chk/HLPXGM 09048480/DCIM/100RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1393/FOTOS Camara-trampa 2
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048888/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09049504/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048483/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048449/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1398 FRENO/HLPXGM09048209/FOTOS
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/camara2

# %% [markdown]
# # Delivery /LUSTRE/sacmod/SIPECAM/Cumulo_96
