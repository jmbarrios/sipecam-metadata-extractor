# %% [markdown]
# # Next delivery: `/LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM`

# %% [markdown]
# ## List of files to extract metadata

# %%
# %%bash
# dir_with_sipecam_data="/LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM"
# list_of_files_and_subdirectories_to_extract_metadata --input_directory "$dir_with_sipecam_data"

# %% [markdown]
# ## Check

# %%
# %%bash
# ls -lh /shared_volume/sipecam_subdirectories_20-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 5.9K Jul 20 07:04 /shared_volume/sipecam_subdirectories_20-07-2022.txt

# %%
# %%bash
# ls -lh /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 7.9M Jul 20 07:04 /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_20-07-2022.txt
# Out:
# 58 /shared_volume/sipecam_subdirectories_20-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022.txt
# Out:
# 67779 /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022.txt

# %%
# %%bash
# mv /shared_volume/sipecam_subdirectories_20-07-2022.txt /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt

# %%
# %%bash
# mv /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022.txt /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022_cumulus_81.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt
# Out:
# 58 /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022_cumulus_81.txt
# Out:
# 67779 /shared_volume/sipecam_files_to_extract_metadata_from_20-07-2022_cumulus_81.txt

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# 20211106_180000.WAV
# 20211106_182000.WAV
# 20211106_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847
# 20211106_182000.WAV
# 20211107_093008.WAV
# 20211107_094000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10262780
# 20211107_180000.WAV
# 20211107_182000.WAV
# 20211107_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263592
# 20211106_125000.WAV
# 20211106_130000.WAV
# 20211106_131000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261943
# 20211106_180000.WAV
# 20211106_182000.WAV
# 20211106_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# 20211106_140000.WAV
# 20211106_141000.WAV
# 20211106_142000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# 20220111_101000.WAV
# 20220111_102000.WAV
# 20220111_103000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/51
# 20220110_125959.WAV
# 20220110_130001.WAV
# 20220111_180000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# 20220111_110031.WAV
# 20220111_111000.WAV
# 20220111_112000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# 20220110_130455.WAV
# 20220111_180000.WAV
# 20220111_182000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# 20220111_120000.WAV
# 20220111_121000.WAV
# 20220111_122000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# 20220111_180000.WAV
# 20220111_182000.WAV
# 20220111_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# 20211212_123000.WAV
# 20211212_124000.WAV
# 20211212_125000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# 20211213_180000.WAV
# 20211213_182000.WAV
# 20211213_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# 20211212_180000.WAV
# 20211212_182000.WAV
# 20211212_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# 20211212_153000.WAV
# 20211212_154000.WAV
# 20211212_155000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# 20211212_121932.WAV
# 20211212_180000.WAV
# 20211212_182000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# 20211212_191000.WAV
# 20211212_192000.WAV
# 20211212_193000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# 20211212_192000.WAV
# 20211212_194000.WAV
# 20211212_200000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# 20211212_185305.WAV
# 20211212_185356.WAV
# 20211212_190000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# 20211212_192000.WAV
# 20211212_194000.WAV
# 20211212_200000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# 20211212_192000.WAV
# 20211212_194000.WAV
# 20211212_200000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/60-10261835
# 20211108_130001.WAV
# 20211108_131000.WAV
# 20211108_132000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/61-10262852
# 20211106_184000.WAV
# 20211106_190000.WAV
# 20211106_192000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/177-10305284
# 19700101_000535.WAV
# 20211106_183000.WAV
# 20211106_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# 20211108_180000.WAV
# 20211108_182000.WAV
# 20211108_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# 20211108_105000.WAV
# 20211108_110000.WAV
# 20211108_111000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772
# 20211108_180000.WAV
# 20211108_182000.WAV
# 20211108_184000.WAV
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/01/100RECNX
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/03/100RECNX
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/05/101RECNX
# RCNX0002.JPG
# RCNX0003.AVI
# RCNX0004.JPG
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/04/103RECNX
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/02/102RECNX
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9862
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9617
# RCNX0031.JPG
# RCNX0032.JPG
# RCNX0033.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-8693
# RCNX0010.JPG
# RCNX0011.JPG
# RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9785
# RCNX0007.JPG
# RCNX0008.JPG
# RCNX0009.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9819
# RCNX0010.JPG
# RCNX0011.JPG
# RCNX0012.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049785
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09048693
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09099617
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049819
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049862
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9787
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/8996
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9183
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/0058
# RCNX0013.JPG
# RCNX0014.JPG
# RCNX0015.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9381
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049183/DCIM/HLPXGM09049183
# RCNX0025.JPG
# RCNX0071.JPG
# RCNX0076.JPG
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09048996/DCIM/HLPXGM09048996
# RCNX0029.JPG
# RCNX0030.JPG
# RCNX0032.JPG
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049787/DCIM/HLPXGM09049787
# RCNX0023.JPG
# RCNX0035.JPG
# RCNX0037.JPG
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058
# RCNX0050.JPG
# RCNX0051.AVI
# RCNX0052.JPG
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049381/HLPXGM09049381
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/ -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261943
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/51
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/60-10261835
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/61-10262852
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/177-10305284
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261943
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/51
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/60-10261835
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/61-10262852
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/177-10305284
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261943
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/51
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 248, in main
#     extract_metadata_of_device_from_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 122, in extract_metadata_of_device_from_files
#     f_pathlib = pathlib.Path(filename)
# UnboundLocalError: local variable 'filename' referenced before assignment
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/60-10261835
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/61-10262852
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/177-10305284
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/01/100RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/03/100RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/05/101RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/04/103RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/02/102RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9862
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9617
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-8693
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9785
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9819
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049785
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09048693
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09099617
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049819
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049862
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9787
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/8996
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9183
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/0058
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9381
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049183/DCIM/HLPXGM09049183
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09048996/DCIM/HLPXGM09048996
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049787/DCIM/HLPXGM09049787
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049381/HLPXGM09049381

# %% [markdown]
# **Dir `/LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/51` has no files as audios were moved to `error` dir. Then this dir will be removed from `/shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt`**

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847

# %% [markdown]
# # Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# 1260
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261847
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10262780
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263592
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10261943
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# 5034
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# 2395
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# 751
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# 346
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# 745
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# 1224
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# 4153
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# 1008
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# 1044
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# 4138
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# 1044
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# 1821
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# 968
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# 3869
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# 968
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# 968
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/60-10261835
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/61-10262852
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/177-10305284
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# 1188
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# 4777
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772
# 1188
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/01/100RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/03/100RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/05/101RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/04/103RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1122-NSJP1/02/102RECNX
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9862
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9617
# 49
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-8693
# 180
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9785
# 312
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9819
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049785
# 66
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09048693
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09099617
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049819
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049862
# 183
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9787
# 81
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/8996
# 143
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9183
# 174
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/0058
# 30
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9381
# 81
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996
# 275
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787
# 110
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381
# 134
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058
# 54
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049183/DCIM/HLPXGM09049183
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09048996/DCIM/HLPXGM09048996
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049787/DCIM/HLPXGM09049787
# 0
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058
# 216
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX
# 12
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09049381/HLPXGM09049381
# 0

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_20-07-2022_cumulus_81.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# Number of files: 1260
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 17:39:40,046 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600 has serial number 24F319035DAEB675
# 2022-07-20 17:39:40,048 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600/20211106_190000.WAV has date 2021-11-06
# 2022-07-20 17:39:40,048 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600/20211211_040000.WAV has date 2021-12-11
# 2022-07-20 17:39:40,048 [INFO]  DaysBetweenFirstAndLastDate: 35
# 2022-07-20 17:39:40,220 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-06", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-11", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 17:39:40,220 [INFO]  last query wasn't successful
# 2022-07-20 17:39:40,353 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 17:39:40,353 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 17:39:40,357 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 17:39:40,357 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# Number of files: 5034
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:00,877 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595 has serial number 2453AC025DAEB680
# 2022-07-20 18:03:00,879 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595/20211106_181000.WAV has date 2021-11-06
# 2022-07-20 18:03:00,879 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595/20211211_115000.WAV has date 2021-12-11
# 2022-07-20 18:03:00,879 [INFO]  DaysBetweenFirstAndLastDate: 35
# 2022-07-20 18:03:01,036 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-06", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-11", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:01,036 [INFO]  last query wasn't successful
# 2022-07-20 18:03:01,166 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:01,166 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2022-06-01T18:43:00.000Z'}]}]}}
# 2022-07-20 18:03:01,169 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:01,169 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# Number of files: 2395
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:01,517 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58 has serial number 247AA5015DAEB6BC
# 2022-07-20 18:03:01,518 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58/20220111_174000.WAV has date 2022-01-11
# 2022-07-20 18:03:01,519 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58/20220128_135000.WAV has date 2022-01-28
# 2022-07-20 18:03:01,519 [INFO]  DaysBetweenFirstAndLastDate: 17
# 2022-07-20 18:03:01,664 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-11", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-28", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:01,664 [INFO]  last query wasn't successful
# 2022-07-20 18:03:01,798 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:01,798 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-07T15:26:00.000Z'}]}]}}
# 2022-07-20 18:03:01,801 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:01,801 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# Number of files: 751
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:02,110 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55 has serial number 2453AC025DAEB680
# 2022-07-20 18:03:02,111 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55/20220111_174000.WAV has date 2022-01-11
# 2022-07-20 18:03:02,111 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55/20220116_064000.WAV has date 2022-01-16
# 2022-07-20 18:03:02,111 [INFO]  DaysBetweenFirstAndLastDate: 5
# 2022-07-20 18:03:02,250 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-11", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:02,250 [INFO]  last query wasn't successful
# 2022-07-20 18:03:02,379 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:02,380 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2022-06-01T18:43:00.000Z'}]}]}}
# 2022-07-20 18:03:02,384 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:02,384 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# Number of files: 346
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:02,679 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53 has serial number 2449BC045DAEB669
# 2022-07-20 18:03:02,680 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53/20220111_190000.WAV has date 2022-01-11
# 2022-07-20 18:03:02,680 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53/20220123_182000.WAV has date 2022-01-23
# 2022-07-20 18:03:02,680 [INFO]  DaysBetweenFirstAndLastDate: 12
# 2022-07-20 18:03:02,824 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-11", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-23", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:02,825 [INFO]  last query wasn't successful
# 2022-07-20 18:03:02,956 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:02,956 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T18:34:00.000Z'}]}]}}
# 2022-07-20 18:03:02,960 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:02,960 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# Number of files: 745
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:03,267 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52 has serial number 24F319035DAEB675
# 2022-07-20 18:03:03,268 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52/20220111_174000.WAV has date 2022-01-11
# 2022-07-20 18:03:03,268 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52/20220116_142000.WAV has date 2022-01-16
# 2022-07-20 18:03:03,269 [INFO]  DaysBetweenFirstAndLastDate: 5
# 2022-07-20 18:03:03,416 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-11", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:03,416 [INFO]  last query wasn't successful
# 2022-07-20 18:03:03,546 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:03,546 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:03:03,549 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:03,549 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# Number of files: 1224
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:03,864 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56 has serial number 248C7D075B1F9142
# 2022-07-20 18:03:03,865 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56/20220111_190000.WAV has date 2022-01-11
# 2022-07-20 18:03:03,865 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56/20220214_034000.WAV has date 2022-02-14
# 2022-07-20 18:03:03,865 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-07-20 18:03:04,012 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-11", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-14", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:04,012 [INFO]  last query wasn't successful
# 2022-07-20 18:03:04,146 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:04,147 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T18:34:00.000Z'}, {'date_deployment': '2022-06-01T18:43:00.000Z'}]}]}}
# 2022-07-20 18:03:04,150 [INFO]  list indices must be integers or slices, not NoneType
# 2022-07-20 18:03:04,151 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# Number of files: 4153
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:04,534 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600 has serial number 24F319035DAEB675
# 2022-07-20 18:03:04,536 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600/20211212_140000.WAV has date 2021-12-12
# 2022-07-20 18:03:04,536 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600/20220110_065000.WAV has date 2022-01-10
# 2022-07-20 18:03:04,536 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-20 18:03:04,687 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-10", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:04,687 [INFO]  last query wasn't successful
# 2022-07-20 18:03:04,820 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:04,820 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:03:04,823 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:04,824 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB675", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# Number of files: 1008
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:05,137 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780 has serial number 247AA5015DAEB6BC
# 2022-07-20 18:03:05,139 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780/20211213_202000.WAV has date 2021-12-13
# 2022-07-20 18:03:05,139 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780/20220110_040000.WAV has date 2022-01-10
# 2022-07-20 18:03:05,139 [INFO]  DaysBetweenFirstAndLastDate: 28
# 2022-07-20 18:03:05,287 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-13", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-10", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:05,287 [INFO]  last query wasn't successful
# 2022-07-20 18:03:05,417 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:05,417 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-07T15:26:00.000Z'}]}]}}
# 2022-07-20 18:03:05,420 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:05,420 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB6BC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# Number of files: 1044
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:05,732 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592 has serial number 2449BC045DAEB669
# 2022-07-20 18:03:05,733 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:05,733 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592/20220110_040000.WAV has date 2022-01-10
# 2022-07-20 18:03:05,733 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-20 18:03:05,877 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-10", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:05,877 [INFO]  last query wasn't successful
# 2022-07-20 18:03:06,009 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:06,010 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T18:34:00.000Z'}]}]}}
# 2022-07-20 18:03:06,013 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:06,014 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB669", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# Number of files: 4138
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:06,539 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843 has serial number 248C7D075B1F9142
# 2022-07-20 18:03:06,540 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:06,540 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843/20220110_065000.WAV has date 2022-01-10
# 2022-07-20 18:03:06,540 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-20 18:03:06,686 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-10", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:06,686 [INFO]  last query wasn't successful
# 2022-07-20 18:03:06,816 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:06,816 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T18:34:00.000Z'}, {'date_deployment': '2022-06-01T18:43:00.000Z'}]}]}}
# 2022-07-20 18:03:06,820 [INFO]  list indices must be integers or slices, not NoneType
# 2022-07-20 18:03:06,820 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F9142", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# Number of files: 1044
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:07,147 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595 has serial number 2453AC025DAEB680
# 2022-07-20 18:03:07,148 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:07,148 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595/20220110_040000.WAV has date 2022-01-10
# 2022-07-20 18:03:07,148 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-20 18:03:07,293 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-10", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:07,294 [INFO]  last query wasn't successful
# 2022-07-20 18:03:07,427 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:07,427 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2022-06-01T18:43:00.000Z'}]}]}}
# 2022-07-20 18:03:07,430 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:07,431 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# Number of files: 1821
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:07,782 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57 has serial number 247AA5015DAEB68C
# 2022-07-20 18:03:07,783 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:07,783 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57/20211226_144000.WAV has date 2021-12-26
# 2022-07-20 18:03:07,783 [INFO]  DaysBetweenFirstAndLastDate: 14
# 2022-07-20 18:03:07,929 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB68C", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:07,929 [INFO]  last query wasn't successful
# 2022-07-20 18:03:08,062 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB68C", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:08,063 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:03:08,066 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:08,067 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM247AA5015DAEB68C", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# Number of files: 968
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:08,492 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61 has serial number 2495F30653E1BE08
# 2022-07-20 18:03:08,494 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:08,494 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61/20220108_032000.WAV has date 2022-01-08
# 2022-07-20 18:03:08,494 [INFO]  DaysBetweenFirstAndLastDate: 27
# 2022-07-20 18:03:08,635 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2495F30653E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-08", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:08,635 [INFO]  last query wasn't successful
# 2022-07-20 18:03:08,766 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2495F30653E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:08,767 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-07T00:25:00.000Z'}]}]}}
# 2022-07-20 18:03:08,770 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:08,770 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2495F30653E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# Number of files: 3869
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:09,106 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59 has serial number 2449BC045DAEB6B0
# 2022-07-20 18:03:09,107 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:09,107 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59/20220108_135000.WAV has date 2022-01-08
# 2022-07-20 18:03:09,108 [INFO]  DaysBetweenFirstAndLastDate: 27
# 2022-07-20 18:03:09,254 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB6B0", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-08", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:09,255 [INFO]  last query wasn't successful
# 2022-07-20 18:03:09,386 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB6B0", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:09,387 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:03:09,390 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:09,390 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2449BC045DAEB6B0", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# Number of files: 968
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:09,716 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54 has serial number 248C7D075B1F857D
# 2022-07-20 18:03:09,718 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:09,718 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54/20220108_032000.WAV has date 2022-01-08
# 2022-07-20 18:03:09,718 [INFO]  DaysBetweenFirstAndLastDate: 27
# 2022-07-20 18:03:09,864 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-08", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:09,864 [INFO]  last query wasn't successful
# 2022-07-20 18:03:09,998 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:09,999 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:03:10,001 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:10,002 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# Number of files: 968
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:03:10,326 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60 has serial number 248C7D075B1FB909
# 2022-07-20 18:03:10,327 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60/20211212_232000.WAV has date 2021-12-12
# 2022-07-20 18:03:10,327 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60/20220108_032000.WAV has date 2022-01-08
# 2022-07-20 18:03:10,327 [INFO]  DaysBetweenFirstAndLastDate: 27
# 2022-07-20 18:03:10,466 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1FB909", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-12", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-08", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:03:10,467 [INFO]  last query wasn't successful
# 2022-07-20 18:03:10,602 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1FB909", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:03:10,602 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-08T19:00:00.000Z'}]}]}}
# 2022-07-20 18:03:10,606 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:03:10,606 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1FB909", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# Number of files: 1188
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:21:55,771 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD has serial number 248C7D075B1F857D
# 2022-07-20 18:21:55,772 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD/20211108_234000.WAV has date 2021-11-08
# 2022-07-20 18:21:55,772 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD/20211211_040000.WAV has date 2021-12-11
# 2022-07-20 18:21:55,772 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-20 18:21:55,931 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-08", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-11", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:21:55,932 [INFO]  last query wasn't successful
# 2022-07-20 18:21:56,066 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:21:56,067 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': []}]}}
# 2022-07-20 18:21:56,069 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:21:56,070 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F857D", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# Number of files: 4777
# ...
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:18,838 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-08T20:28:00.000Z'}]}]}}
# 2022-07-20 18:23:18,842 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:18,842 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049381", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996
# Number of files: 275
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:19,169 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996 has serial number HLPXGM09048996
# 2022-07-20 18:23:19,171 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996/RCNX0002.JPG has date 2022-01-09
# 2022-07-20 18:23:19,171 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996/RCNX0270.AVI has date 2022-02-19
# 2022-07-20 18:23:19,171 [INFO]  DaysBetweenFirstAndLastDate: 41
# 2022-07-20 18:23:19,315 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048996", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-09", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-19", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:23:19,316 [INFO]  last query wasn't successful
# 2022-07-20 18:23:19,447 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048996", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:19,447 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-07T21:47:00.000Z'}]}]}}
# 2022-07-20 18:23:19,450 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:19,450 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048996", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787
# Number of files: 110
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:19,752 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787 has serial number HLPXGM09049787
# 2022-07-20 18:23:19,753 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787/RCNX0002.JPG has date 2022-01-09
# 2022-07-20 18:23:19,753 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787/RCNX0108.AVI has date 2022-02-19
# 2022-07-20 18:23:19,754 [INFO]  DaysBetweenFirstAndLastDate: 41
# 2022-07-20 18:23:19,899 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049787", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-09", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-19", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:23:19,900 [INFO]  last query wasn't successful
# 2022-07-20 18:23:20,027 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049787", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:20,027 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-08T16:29:00.000Z'}]}]}}
# 2022-07-20 18:23:20,031 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:20,031 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049787", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381
# Number of files: 134
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:20,334 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381 has serial number HLPXGM09049381
# 2022-07-20 18:23:20,335 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381/RCNX0004.JPG has date 2022-01-09
# 2022-07-20 18:23:20,335 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381/RCNX0129.AVI has date 2022-02-19
# 2022-07-20 18:23:20,335 [INFO]  DaysBetweenFirstAndLastDate: 41
# 2022-07-20 18:23:20,478 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049381", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-09", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-19", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:23:20,478 [INFO]  last query wasn't successful
# 2022-07-20 18:23:20,609 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049381", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:20,609 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-08T20:28:00.000Z'}]}]}}
# 2022-07-20 18:23:20,612 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:20,613 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049381", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058
# Number of files: 54
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:20,915 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058 has serial number HLPXGM09050058
# 2022-07-20 18:23:20,916 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058/RCNX0002.JPG has date 2022-01-10
# 2022-07-20 18:23:20,916 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058/RCNX0054.AVI has date 2022-02-19
# 2022-07-20 18:23:20,916 [INFO]  DaysBetweenFirstAndLastDate: 40
# 2022-07-20 18:23:21,059 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-10", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-19", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:23:21,059 [INFO]  last query wasn't successful
# 2022-07-20 18:23:21,190 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:21,190 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T23:57:00.000Z'}]}]}}
# 2022-07-20 18:23:21,193 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:21,194 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058
# Number of files: 216
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:53,801 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058 has serial number HLPXGM09050058
# 2022-07-20 18:23:53,802 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058/RCNX0055.JPG has date 2021-11-07
# 2022-07-20 18:23:53,802 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058/RCNX0264.AVI has date 2021-12-11
# 2022-07-20 18:23:53,802 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-07-20 18:23:53,945 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-07", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-11", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-20 18:23:53,946 [INFO]  last query wasn't successful
# 2022-07-20 18:23:54,073 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-20 18:23:54,073 [INFO]  Result of query alternative auxiliar to Zendro GQL: {'data': {'physical_devices': [{'device_deploymentsFilter': [{'date_deployment': '2021-11-06T23:57:00.000Z'}]}]}}
# 2022-07-20 18:23:54,075 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-20 18:23:54,076 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09050058", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX
# Number of files: 12
# Logs file: /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX/logs_simex_move_files_to_standard_directory.logs
# 2022-07-20 18:23:54,375 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX has serial number HLPXGM09050058
# 2022-07-20 18:23:54,376 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX/RCNX0004.JPG has date 2021-11-06
# 2022-07-20 18:23:54,376 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX/RCNX0006.AVI has date 2021-11-06
# 2022-07-20 18:23:54,377 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-07-20 18:23:54,377 [INFO]  There were images or videos in /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/100RECNX dir that have DaysBetweenFirstAndLastDate < 2, will not be moved
# 2022-07-20 18:23:54,377 [INFO]  Query to Zendro GQL: None
# 2022-07-20 18:23:54,377 [INFO]  'NoneType' object is not subscriptable
# 2022-07-20 18:23:54,377 [INFO]  unsuccessful query None or error when moving files to standard dir
# 2022-07-20 18:23:54,377 [INFO]  Result of query to Zendro GQL: None
# ---------------------------------------------
# ---------------------------------------------

# %%
# %%bash
# cat /LUSTRE/sacmod/SIPECAM/data/dirs_not_moved_with_simex/dirs_not_moved_with_simex_20-07-2022.txt|grep "Cumulo 81"
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1122-NSJP1/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/58
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/55
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/53
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/52
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1499-NSJP4/56
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263600
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10262780
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263592
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10261843
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_1_1500-Nancy/10263595
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/57
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/61
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/59
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/54
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1503-Huertas/60
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/54-10261758-AUD
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/57-10263587
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Audiomoths/1_81_0_1119-El Durazno/59-10262772
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9617
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-8693
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1499-NSJP4/1_81_1_1499-9785
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049785
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_1_1500-Nancy/HLPX6M09049862
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9787
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/8996
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9183
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/0058
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1503-Huertas/9381
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-996
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-787
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-381
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1501-Apo/1_81_0_1501-058
# /LUSTRE/sacmod/SIPECAM/entrega.05.Julio.2022/Cumulo 81 SIPECAM/Camaras/1_81_0_1119-El Durazno/HLPXGM09050058/DCIM/HLPXGM09050058

# %%
# %%bash
# cat /LUSTRE/sacmod/SIPECAM/data/dirs_moved_with_simex/dirs_moved_with_simex_20-07-2022.txt|grep "/81/"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/248C7D075B1F9135/2021-11-07/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/247AA5015DAEB6BC/2021-11-07/audios/Ultrasonico
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/2449BC045DAEB669/2021-11-06/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/248C7D075B1F9142/2021-11-06/audios/Ultrasonico
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/248C7D075B1FB909/2021-11-08/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/2495F30653E1BE08/2021-11-07/audios/Ultrasonico
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/242A260460377BD3/2021-11-07/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/HLPXGM09049819/2021-11-06/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/HLPXGM09049785/2021-11-07/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/HLPXGM09049862/2021-11-07/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/HLPXGM09048693/2021-11-07/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1499/HLPXGM09049617/2021-11-06/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1122/HLPXGM09049862/2022-01-11/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1122/HLPXGM09049819/2022-01-11/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1500/HLPXGM09048693/2021-12-13/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1500/HLPXGM09049617/2021-12-12/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_1_1500/HLPXGM09049819/2021-12-12/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/HLPXGM09049183/2021-11-08/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/HLPXGM09048996/2021-11-07/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/HLPXGM09049787/2021-11-08/images_videos
# /LUSTRE/sacmod/SIPECAM/data/81/1_81_0_1119/HLPXGM09049381/2021-11-08/images_videos
