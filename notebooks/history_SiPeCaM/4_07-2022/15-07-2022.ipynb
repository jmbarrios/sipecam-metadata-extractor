# %% [markdown]
# # Next delivery: `/LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022`

# %% [markdown]
# ## List of files to extract metadata

# %%
# %%bash
# dir_with_sipecam_data=/LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022
# list_of_files_and_subdirectories_to_extract_metadata --input_directory "$dir_with_sipecam_data"

# %% [markdown]
# ## Check

# %%
# %%bash
# ls -lh /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 2.0K Jul 15 11:23 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# ls -lh /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 7.4M Jul 15 11:23 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# 21 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# 66392 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# mv /shared_volume/sipecam_subdirectories_15-07-2022.txt /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt

# %%
# %%bash
# mv /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_96.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt
# Out:
# 21 /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_96.txt
# Out:
# 66392 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_96.txt

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# 20211014_180000.WAV
# 20211014_182000.WAV
# 20211014_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# 20211014_180000.WAV
# 20211014_182000.WAV
# 20211014_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# 20211014_180000.WAV
# 20211014_182000.WAV
# 20211014_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# 20211013_171505.WAV
# 20211013_172055.WAV
# 20211014_140002.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# 20211014_092000.WAV
# 20211014_093000.WAV
# 20211014_094000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# 20211014_124000.WAV
# 20211014_125000.WAV
# 20211014_130000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# 20211114_180000.WAV
# 20211114_182000.WAV
# 20211114_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# 20211114_180000.WAV
# 20211114_182000.WAV
# 20211114_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# 20211114_134000.WAV
# 20211114_135000.WAV
# 20211114_140000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# 20211114_121000.WAV
# 20211114_122000.WAV
# 20211114_123000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# 20211114_125000.WAV
# 20211114_130000.WAV
# 20211114_131000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C5/C5_U_10262049
# 20211116_180000.WAV
# 20211116_182000.WAV
# 20211116_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# 20211117_180000.WAV
# 20211117_182000.WAV
# 20211117_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# 20211118_124000.WAV
# 20211118_125000.WAV
# 20211118_130000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# 20211117_140000.WAV
# 20211117_141000.WAV
# 20211117_142000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# 20211116_135013.WAV
# 20211116_140000.WAV
# 20211116_141000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# 20211221_180000.WAV
# 20211221_182000.WAV
# 20211221_184000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# 20211220_210000.WAV
# 20211220_212000.WAV
# 20211220_214000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# 20211221_125000.WAV
# 20211221_130000.WAV
# 20211221_131000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# 20211220_210000.WAV
# 20211220_211000.WAV
# 20211220_212000.WAV
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5
# 20211220_212000.WAV
# 20211220_213000.WAV
# 20211220_214000.WAV

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/ -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C5/C5_U_10262049
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C5/C5_U_10262049
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C5/C5_U_10262049
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 248, in main
#     extract_metadata_of_device_from_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 122, in extract_metadata_of_device_from_files
#     f_pathlib = pathlib.Path(filename)
# UnboundLocalError: local variable 'filename' referenced before assignment
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5

# %% [markdown]
# **Dir `/LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C5/C5_U_10262049` had erronous files, will be removed from `/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt`**

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5

# %% [markdown]
# # Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C5
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# 1188
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# 1192
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C5
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# 4754
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# 4744
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# 1044
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C2
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# 4183
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# 4188
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C2
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# 1188
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# 4590
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# 1658
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# 4881
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C4
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# 1369
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C4
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C2
# 0
# /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5
# 5478

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_96.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4
# Number of files: 1188
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:19:39,262 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4 has serial number 2401010753E1BE08
# 2022-07-16 18:19:39,264 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4/20211014_182000.WAV has date 2021-10-14
# 2022-07-16 18:19:39,264 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C4/20211116_030000.WAV has date 2021-11-16
# 2022-07-16 18:19:39,264 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-16 18:19:39,413 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:19:39,413 [INFO]  list index out of range
# 2022-07-16 18:19:39,414 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2
# Number of files: 1192
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:19:39,716 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2 has serial number 248C7D075B1F7A97
# 2022-07-16 18:19:39,717 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2/20211014_182000.WAV has date 2021-10-14
# 2022-07-16 18:19:39,717 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/ultrasonico/1_96_0_1559_C2/20211116_030000.WAV has date 2021-11-16
# 2022-07-16 18:19:39,718 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-16 18:19:39,853 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:19:39,854 [INFO]  list index out of range
# 2022-07-16 18:19:39,854 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4
# Number of files: 4754
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:26:39,118 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4 has serial number 248D9B045EC9F3E8
# 2022-07-16 18:26:39,119 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4/20211014_134000.WAV has date 2021-10-14
# 2022-07-16 18:26:39,119 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/1_96_0_1559_C4/20211116_075000.WAV has date 2021-11-16
# 2022-07-16 18:26:39,119 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-16 18:26:39,271 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248D9B045EC9F3E8", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:26:39,271 [INFO]  list index out of range
# 2022-07-16 18:26:39,272 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248D9B045EC9F3E8", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02
# Number of files: 4744
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:26:39,631 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02 has serial number 24E144055DAEB615
# 2022-07-16 18:26:39,633 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02/20211014_134000.WAV has date 2021-10-14
# 2022-07-16 18:26:39,633 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/10_2021/audible/C2_Chipinque/1_96_0_1559_02/20211116_075000.WAV has date 2021-11-16
# 2022-07-16 18:26:39,633 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-16 18:26:39,774 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-10-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-16", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:26:39,775 [INFO]  last query wasn't successful
# 2022-07-16 18:26:39,908 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:26:39,911 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-16 18:26:39,911 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657
# Number of files: 1044
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:26:40,238 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657 has serial number 24F319035DAEB615
# 2022-07-16 18:26:40,239 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657/20211114_184000.WAV has date 2021-11-14
# 2022-07-16 18:26:40,239 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/ultrasonico/1_96_1_1566_C4/U_C4_10263657/20211213_032000.WAV has date 2021-12-13
# 2022-07-16 18:26:40,239 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-16 18:26:40,377 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-13", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:26:40,377 [INFO]  last query wasn't successful
# 2022-07-16 18:26:40,509 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:26:40,512 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-16 18:26:40,512 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F319035DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506
# Number of files: 4183
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:29:25,964 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506 has serial number 243B1F055B1F95CC
# 2022-07-16 18:29:25,965 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506/20211114_195000.WAV has date 2021-11-14
# 2022-07-16 18:29:25,965 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C4/A_C4_10261506/20211213_095000.WAV has date 2021-12-13
# 2022-07-16 18:29:25,965 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-16 18:29:26,119 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F95CC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-13", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:29:26,120 [INFO]  last query wasn't successful
# 2022-07-16 18:29:26,254 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F95CC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:29:26,257 [INFO]  list indices must be integers or slices, not NoneType
# 2022-07-16 18:29:26,257 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F95CC", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057
# Number of files: 4188
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:29:26,603 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057 has serial number 24A04F075F256D68
# 2022-07-16 18:29:26,604 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057/20211114_195000.WAV has date 2021-11-14
# 2022-07-16 18:29:26,604 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/mauricios/audible/1_96_1_1566_C5/A_C5_10262057/20211213_095000.WAV has date 2021-12-13
# 2022-07-16 18:29:26,604 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-07-16 18:29:26,741 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24A04F075F256D68", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-14", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-13", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:29:26,741 [INFO]  last query wasn't successful
# 2022-07-16 18:29:26,877 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24A04F075F256D68", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:29:26,880 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-16 18:29:26,880 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24A04F075F256D68", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784
# Number of files: 1188
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:35:22,448 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784 has serial number 248C7D075B1F7A97
# 2022-07-16 18:35:22,449 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784/20211117_234000.WAV has date 2021-11-17
# 2022-07-16 18:35:22,450 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/ultrasonico/1_96_1_1560_C2/C2_U_10262784/20211220_010000.WAV has date 2021-12-20
# 2022-07-16 18:35:22,450 [INFO]  DaysBetweenFirstAndLastDate: 33
# 2022-07-16 18:35:22,595 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-17", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:35:22,595 [INFO]  list index out of range
# 2022-07-16 18:35:22,596 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-17", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650
# Number of files: 4590
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:35:22,955 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650 has serial number 24E144055DAEB615
# 2022-07-16 18:35:22,956 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650/20211118_180000.WAV has date 2021-11-18
# 2022-07-16 18:35:22,957 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_1_1560_C4/C4_A_10263650/20211220_061000.WAV has date 2021-12-20
# 2022-07-16 18:35:22,957 [INFO]  DaysBetweenFirstAndLastDate: 32
# 2022-07-16 18:35:23,102 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-18", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:35:23,103 [INFO]  last query wasn't successful
# 2022-07-16 18:35:23,235 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:35:23,238 [INFO]  local variable 'idx_date' referenced before assignment
# 2022-07-16 18:35:23,239 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E144055DAEB615", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182
# Number of files: 1658
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:35:23,560 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182 has serial number 24EB9B0359442868
# 2022-07-16 18:35:23,561 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182/20211117_171000.WAV has date 2021-11-17
# 2022-07-16 18:35:23,561 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C2/C2_A_10262182/20211129_010000.WAV has date 2021-11-29
# 2022-07-16 18:35:23,561 [INFO]  DaysBetweenFirstAndLastDate: 12
# 2022-07-16 18:35:23,699 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24EB9B0359442868", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-17", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-29", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:35:23,699 [INFO]  last query wasn't successful
# 2022-07-16 18:35:23,827 [INFO]  Query alternative auxiliar to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24EB9B0359442868", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# 2022-07-16 18:35:23,830 [INFO]  list indices must be integers or slices, not NoneType
# 2022-07-16 18:35:23,831 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24EB9B0359442868", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850
# Number of files: 4881
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:35:24,196 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850 has serial number 2401010753E1BE08
# 2022-07-16 18:35:24,197 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850/20211116_153000.WAV has date 2021-11-16
# 2022-07-16 18:35:24,198 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/11_2021/chipingue/audible/1_96_0_1560_C5/C5_A_10262850/20211220_061000.WAV has date 2021-12-20
# 2022-07-16 18:35:24,198 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-07-16 18:35:24,333 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-16", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:35:24,334 [INFO]  list index out of range
# 2022-07-16 18:35:24,334 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-16", valueType: String, operator: gte}, {field: date_deployment, value: "2021-12-20", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5
# Number of files: 1369
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:39:00,649 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5 has serial number 248C7D075B1F7A97
# 2022-07-16 18:39:00,650 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5/20211220_214000.WAV has date 2021-12-20
# 2022-07-16 18:39:00,650 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/ultrasonico/1_96_0_1557_C5/20220127_194000.WAV has date 2022-01-27
# 2022-07-16 18:39:00,650 [INFO]  DaysBetweenFirstAndLastDate: 38
# 2022-07-16 18:39:00,800 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-20", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:39:00,801 [INFO]  list index out of range
# 2022-07-16 18:39:00,801 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-20", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5
# Number of files: 5478
# Logs file: /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5/logs_simex_move_files_to_standard_directory.logs
# 2022-07-16 18:54:36,792 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5 has serial number 2401010753E1BE08
# 2022-07-16 18:54:36,794 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5/20211220_225000.WAV has date 2021-12-20
# 2022-07-16 18:54:36,794 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_96/entrega_23.mayo.2022/12_2021/audible/1_96_0_1557_C5/20220127_194000.WAV has date 2022-01-27
# 2022-07-16 18:54:36,794 [INFO]  DaysBetweenFirstAndLastDate: 38
# 2022-07-16 18:54:36,943 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-20", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-16 18:54:36,943 [INFO]  list index out of range
# 2022-07-16 18:54:36,943 [INFO]  unsuccessful query query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2401010753E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-20", valueType: String, operator: gte}, {field: date_deployment, value: "2022-01-27", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# } or error when moving files to standard dir
# ---------------------------------------------
# ---------------------------------------------
