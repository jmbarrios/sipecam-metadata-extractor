# %% [markdown]
# # Next delivery: `/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/`

# %% [markdown]
# ## List of files to extract metadata

# %%
# %%bash
# dir_with_sipecam_data=/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/
# list_of_files_and_subdirectories_to_extract_metadata --input_directory "$dir_with_sipecam_data"

# %% [markdown]
# ## Check

# %%
# %%bash
# ls -lh /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 6.7K Jul 15 11:26 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# ls -lh /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 2.2M Jul 15 11:26 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# 62 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# 17775 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# mv /shared_volume/sipecam_subdirectories_15-07-2022.txt /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt

# %%
# %%bash
# mv /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_31.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# Out:
# 62 /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_31.txt
# Out:
# 17775 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_31.txt

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# 20211208_180000.WAV
# 20211208_182000.WAV
# 20211208_184000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# 20211208_180000.WAV
# 20211208_182000.WAV
# 20211208_184000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652
# 20211208_091050.WAV
# 20211208_092000.WAV
# 20211208_093000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50019
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/48869
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49878
# RCNX0001.JPG
# RCNX0002.JPG
# RCNX0003.AVI
# ...

# %% [markdown]
# **Temporarily will delete next dirs:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/San vicente-1-31-0-1217/49507- recuperada/Fotos`
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/San vicente-1-31-0-1217/49507- recuperada/Videos`
#
# **from `/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt` and ask Omar that rename the files within those dirs with `RCNX0001.AVI` or `RCNX0001.JPG` nomenclature as in `move` cli this numbers are extracted. Also it appears they must be in the same dir and not in different dirs!!!**

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022 -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50019
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/48869
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49878
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50016
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Rio-Verde-1-31-1-1211/49481/DCIM/101RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Rio-Verde-1-31-1-1211/49481/DCIM/100RECNX
# ...

# %% [markdown]
# ## Check

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49507"
# logs=$(find "$d" -name "*logs_simex_extract*.logs")
# cat "$logs"
# Out:
# 2022-07-16 20:40:42,755 [INFO]  extraction of serial_numbers_dates_and_metadata_of_files_and_device
# 2022-07-16 20:40:42,756 [INFO]  logs for extraction of serial_numbers_dates_and_metadata_of_files_and_device in /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49507/49507_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# 2022-07-16 20:40:42,761 [INFO]
# 2022-07-16 20:40:42,761 [INFO]  there were no audios nor images found in dir: /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49507, serial number can not be retrieved from

# %% [markdown]
# **Need to ask Mariana which serial number was used for dir `/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49507`**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Los valles 1_31_0_1218/49507/101RECNX"
# logs=$(find "$d" -name "*logs_simex_extract*.logs")
# cat "$logs"
# Out:
# 2022-07-16 20:40:42,992 [INFO]  extraction of serial_numbers_dates_and_metadata_of_files_and_device
# 2022-07-16 20:40:42,993 [INFO]  logs for extraction of serial_numbers_dates_and_metadata_of_files_and_device in /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Los valles 1_31_0_1218/49507/101RECNX/101RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# 2022-07-16 20:40:42,998 [INFO]
# 2022-07-16 20:40:42,998 [INFO]  there were no audios nor images found in dir: /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Los valles 1_31_0_1218/49507/101RECNX, serial number can not be retrieved from

# %% [markdown]
# **Need to ask Mariana which serial number was used for dir `/LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Los valles 1_31_0_1218/49507/101RECNX`**

# %% [markdown]
# Will delete dirs:
#
# ```
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49507
#
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Los valles 1_31_0_1218/49507/101RECNX
# ```
#
# from:
#
# ```
# /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# ```

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50019
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/48869
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49878
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50016
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Rio-Verde-1-31-1-1211/49481/DCIM/101RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Rio-Verde-1-31-1-1211/49481/DCIM/100RECNX
# ...

# %% [markdown]
# (forgot to delete dirs...now they are gone from /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt)

# %% [markdown]
# # Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# 1332
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520
# 108
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10305652
# 3826
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50019
# 123
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/48869
# 381
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/49878
# 735
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/El ranchito-1-31-1-1210/50016
# 675
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Rio-Verde-1-31-1-1211/49481/DCIM/101RECNX
# 21
# ...

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795
# Number of files: 1332
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/logs_simex_move_files_to_standard_directory.logs
# 2022-07-17 08:20:05,822 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795 has serial number 248D9B0260371FD2
# 2022-07-17 08:20:05,824 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/20211208_212000.WAV has date 2021-12-08
# 2022-07-17 08:20:05,824 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/20220114_022000.WAV has date 2022-01-14
# ...
