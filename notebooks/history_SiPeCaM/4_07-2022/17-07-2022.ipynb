# %% [markdown]
# # Next delivery: `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022`

# %% [markdown]
# ## List of files to extract metadata

# %%
# %%bash
# dir_with_sipecam_data=/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022
# list_of_files_and_subdirectories_to_extract_metadata --input_directory "$dir_with_sipecam_data"

# %% [markdown]
# ## Check

# %%
# %%bash
# ls -lh /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 5.9K Jul 15 11:27 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# ls -lh /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# -rw-r--r-- 1 root root 6.5M Jul 15 11:27 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022.txt
# Out:
# 57 /shared_volume/sipecam_subdirectories_15-07-2022.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt
# Out:
# 54183 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt

# %%
# %%bash
# mv /shared_volume/sipecam_subdirectories_15-07-2022.txt /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt

# %%
# %%bash
# mv /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022.txt /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_33.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt
# Out:
# 57 /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt

# %%
# %%bash
# wc -l /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_33.txt
# Out:
# 54183 /shared_volume/sipecam_files_to_extract_metadata_from_15-07-2022_cumulus_33.txt

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# 20211031_135000.WAV
# 20211031_140000.WAV
# 20211031_141000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# 19700101_000107.WAV
# 20211031_180000.WAV
# 20211031_182000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# 20211007_192000.WAV
# 20211031_180000.WAV
# 20211031_182000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# 20211101_180000.WAV
# 20211101_182000.WAV
# 20211101_184000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# 20211031_155000.WAV
# 20211031_160000.WAV
# 20211031_161000.WAV
# ...

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# if [ -f ~/list_dirs_with_audios.txt ]; then
#      rm ~/list_dirs_with_audios.txt
# fi
# if [ -f ~/list_dirs_with_audios_auxiliary.txt ]; then
#      rm ~/list_dirs_with_audios_auxiliary.txt
# fi
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(find /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022 -name "*.WAV")
#   do
#      dir_audio=$(dirname $f)
#      echo "$dir_audio" >> ~/list_dirs_with_audios_auxiliary.txt
# done
# dirs_audio=$(cat ~/list_dirs_with_audios_auxiliary.txt|uniq)
# echo "$dirs_audio" > ~/list_dirs_with_audios.txt
# IFS=$SAVEIFS

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305537 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305352
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305583
# ...

# %% [markdown]
# # check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305537 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305352
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305583
# ...

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305537 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305352
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305583
# ...

# %% [markdown]
# ## Dir: `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX`

# %% [markdown]
# **Rerunning sequentially**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 36, in extract_metadata
#     tuple_metadata_of_file = (filename,read_metadata_video.get_metadata_of_file(filename))
#   File "/usr/local/lib/python3.8/dist-packages/simex/read_metadata_video.py", line 52, in get_metadata_of_file
# ...

# %% [markdown]
# **File:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0012.AVI`

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0012.AVI"
# exiftool -a -j "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0012.AVI",
#   "ExifToolVersion": 12.43,
#   "FileName": "RCNX0012.AVI",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX",
#   "FileSize": "11 MB",
#   "FileModifyDate": "2021:10:31 13:34:26-06:00",
#   "FileAccessDate": "2022:07:17 19:44:32-05:00",
#   "FileInodeChangeDate": "2022:06:09 15:11:11-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "FileType": "AVI",
#   "FileTypeExtension": "avi",
#   "MIMEType": "video/x-msvideo",
#   "FrameRate": 12.5,
#   "MaxDataRate": "2.592e+04 kB/s",
#   "FrameCount": 64,
#   "StreamCount": 1,
#   "StreamType": "Video",
#   "VideoCodec": "MJPG",
#   "VideoFrameRate": 12.5,
#   "VideoFrameCount": 64,
#   "Quality": "Default",
#   "SampleSize": "Variable",
#   "BMPVersion": "Windows V3",
#   "ImageWidth": 1024,
#   "ImageHeight": 720,
# ...

# %% [markdown]
# **Checking video it appears some people were configuring camera trap, then will move all the sequence "10.JPG, 11.JPG and 12.AVI" to dir `error`**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/"
# mkdir "$d/error"
# mv "$d/RCNX0012.AVI" "$d/error/"

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/"
# mv "$d/RCNX0010.JPG" "$d/error/"
# mv "$d/RCNX0011.JPG" "$d/error/"

# %% [markdown]
# **Rerunning**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/extract_serial_numbers_dates_and_metadata_of_files_and_device", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 254, in main
#     extract_metadata_of_files(input_directory,
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 168, in extract_metadata_of_files
#     tuple_date, tuple_metadata_of_file = extract_metadata(filename)
#   File "/usr/local/lib/python3.8/dist-packages/simex/extract_serial_numbers_dates_and_metadata_of_files_and_device.py", line 36, in extract_metadata
#     tuple_metadata_of_file = (filename,read_metadata_video.get_metadata_of_file(filename))
#   File "/usr/local/lib/python3.8/dist-packages/simex/read_metadata_video.py", line 52, in get_metadata_of_file
# ...

# %% [markdown]
# **File:**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0138.AVI`
#
# **has fauna, then locally `simex` will be modified implementing a `try` ... `except` block in `read` metadata video**

# %% [markdown]
# **Rerunning**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX"
# file_json=$(find "$dir_to_be_processed" -name "*.json")
# python3 -mjson.tool "$file_json"|head -n 50
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049899"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:17 12:34:54",
#             "SerialNumber": "HLPXGM09049899",
#             "FileSize": "1029 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX"
# file_json=$(find "$dir_to_be_processed" -name "*.json")
# python3 -mjson.tool "$file_json"|tail -n 50
# Out:
#             "GPSLatitudeRef": "North",
#             "GPSLongitudeRef": "West",
#             "GPSLatitude": 17.5759,
#             "GPSLongitude": -100.6003,
#             "SerialNumber": "HLPXGM09049899"
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/LaMona-1-33-1225/49899/DCIM/100RECNX/RCNX0108.AVI": {
#             "BitRate": "17.1 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
#             "VideoCompression": "Motion JPEG DIB (fourcc:\"MJPG\")",
#             "AudioSampleRate": "",
#             "AudioCompressionRate": "",
#             "AudioCompression": "",
#             "AudioBitRate": "",
#             "FileSize": "11 MB",
#             "DateTimeOriginal": "2021:11:25 10:24:17",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
# ...

# %% [markdown]
# ## Dir `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Las mesas-1-33-1-1219/49899`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Las mesas-1-33-1-1219/49899"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# ## Dir `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Caldo-Flaco-1-33-1-1220/49899`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Caldo-Flaco-1-33-1-1220/49899"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# ## Dir `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/El Pinito-1-33-1-1222/49899/102RECNX`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/El Pinito-1-33-1-1222/49899/102RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# ## Dir `/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/El Pinito-1-33-1-1222/49899/103RECNX`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/El Pinito-1-33-1-1222/49899/103RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305537 AU
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305352
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305583
# ...

# %% [markdown]
# # Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305349
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# 1080
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10307495
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306500 ULT
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10309702 AU
# 2901
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10305537 AU
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305352
# 1080
# /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1227-La trementina/10305583
# 0
# ...

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_15-07-2022_cumulus_33.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT
# Number of files: 1080
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT/logs_simex_move_files_to_standard_directory.logs
# 2022-07-17 21:40:27,621 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT has serial number 248D9B0260371F78
# 2022-07-17 21:40:27,623 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT/20211031_214000.WAV has date 2021-10-31
# 2022-07-17 21:40:27,623 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_33/entrega_09.junio.2022/Nodo-33-Tecpan/Audiomoth-1-33-1-1225-La mona/10306527 ULT/20211202_022000.WAV has date 2021-12-02
# ...
