# %% [markdown]
# # After Jaime fixed a bug that was keeping out some forms delivered by sipecam partners here will check [1_revision_of_past_executions](https://github.com/CONABIO/sipecam-metadata-extractor/blob/main/notebooks/history_SiPeCaM/1_revision_of_past_executions.ipynb)

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %% [markdown]
# # Dir `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-29 21:00:04,468 [INFO]  Validating lat and long of file are correct using lat long of cumulus centroid
# 2022-08-29 21:00:04,469 [INFO]  Latitude and Longitude of file are in cumulus geometry
# 2022-08-29 21:00:04,469 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-29 21:00:04,622 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX/RCNX0057.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049514/2021-07-28/images_videos with name 1f89d9b16a7e9ee3a961a4c6399e5f7d_0057.AVI
# 2022-08-29 21:00:04,626 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049514/2021-07-28/images_videos/1f89d9b16a7e9ee3a961a4c6399e5f7d_0057.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049514/2021-07-28/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049514/2021-07-28/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 60 "$file_for_logs"
# Out:
# 2022-08-29 20:59:53,765 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX has serial number HLPXGM09049514
# 2022-08-29 20:59:53,767 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX/RCNX0004.JPG has date 2021-07-28
# 2022-08-29 20:59:53,767 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX/RCNX0183.AVI has date 2021-08-26
# 2022-08-29 20:59:53,767 [INFO]  DaysBetweenFirstAndLastDate: 29
# 2022-08-29 20:59:53,936 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049514", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-07-28", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-26", valueType: String, operator: lte}]}) {
# ...

# %% [markdown]
# # Dir `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-30 06:53:49,446 [INFO]  Validating lat and long of file are correct using lat long of cumulus centroid
# 2022-08-30 06:53:49,446 [INFO]  Latitude and Longitude of file are in cumulus geometry
# 2022-08-30 06:53:49,446 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-30 06:53:49,549 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX/RCNX0021.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049271/2021-07-28/images_videos with name 7d30f5fe9d6b12e03f300e1767ec60a1_0021.AVI
# 2022-08-30 06:53:49,551 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049271/2021-07-28/images_videos/7d30f5fe9d6b12e03f300e1767ec60a1_0021.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049271/2021-07-28/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049271/2021-07-28/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 60 "$file_for_logs"
# Out:
# 2022-08-30 06:53:47,477 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX has serial number HLPXGM09049271
# 2022-08-30 06:53:47,478 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX/RCNX0004.JPG has date 2021-07-29
# 2022-08-30 06:53:47,479 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX/RCNX0027.AVI has date 2021-08-26
# 2022-08-30 06:53:47,479 [INFO]  DaysBetweenFirstAndLastDate: 28
# 2022-08-30 06:53:47,654 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-07-29", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-26", valueType: String, operator: lte}]}) {
# ...

# %% [markdown]
# # Dir `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-30 07:21:40,545 [INFO]  Validating lat and long of file are correct using lat long of cumulus centroid
# 2022-08-30 07:21:40,546 [INFO]  Latitude and Longitude of file are in cumulus geometry
# 2022-08-30 07:21:40,546 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-30 07:21:40,612 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX/RCNX0060.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048925/2021-07-29/images_videos with name 1e13310b1447c0c7a5fd1c664853b9d1_0060.AVI
# 2022-08-30 07:21:40,615 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048925/2021-07-29/images_videos/1e13310b1447c0c7a5fd1c664853b9d1_0060.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048925/2021-07-29/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048925/2021-07-29/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 40 "$file_for_logs"
# Out:
# 2022-08-30 07:21:35,695 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX has serial number HLPXGM09048925
# 2022-08-30 07:21:35,696 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX/RCNX0049.JPG has date 2021-07-29
# 2022-08-30 07:21:35,696 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX/RCNX0072.AVI has date 2021-08-29
# 2022-08-30 07:21:35,696 [INFO]  DaysBetweenFirstAndLastDate: 31
# 2022-08-30 07:21:35,878 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048925", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-07-29", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-29", valueType: String, operator: lte}]}) {
#       node {
# ...

# %% [markdown]
# # Dir `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4`

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-30 07:24:18,405 [INFO]  Validating lat and long of file are correct using lat long of cumulus centroid
# 2022-08-30 07:24:18,406 [INFO]  Latitude and Longitude of file are in cumulus geometry
# 2022-08-30 07:24:18,406 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-30 07:24:18,453 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4/RCNX0018.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048599/2021-07-29/images_videos with name fa9483b8b480209850ec9d9f39d93eb7_0018.AVI
# 2022-08-30 07:24:18,456 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048599/2021-07-29/images_videos/fa9483b8b480209850ec9d9f39d93eb7_0018.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048599/2021-07-29/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048599/2021-07-29/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 40 "$file_for_logs"
# Out:
# 2022-08-30 07:24:17,274 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4 has serial number HLPXGM09048599
# 2022-08-30 07:24:17,275 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4/RCNX0004.JPG has date 2021-07-29
# 2022-08-30 07:24:17,275 [INFO]  File /LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4/RCNX0020.JPG has date 2021-08-30
# 2022-08-30 07:24:17,275 [INFO]  DaysBetweenFirstAndLastDate: 32
# 2022-08-30 07:24:17,443 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048599", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-07-29", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-30", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
# ...

# %% [markdown]
# # Creating txt with dirs

# %%
# %%bash
# rm /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt

# %%
# %%bash
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_5" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_4/" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_3" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10306516 ultra" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09049201" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_1_1338/Camaras/1338_3/100RECNX" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_1_1338/Camaras/1338_4/100RECNX" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_0_1339/1339_3/100RECNX/" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_0_1339/1339_4" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/entrega_22.marzo.2022/Mes 6/3_92_0_1339/3_92_0_1339_ 2/HLPXGM09049314" >> /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt

# %% [markdown]
# ## Check every dir has wav, jpg, avi files

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|head -n 3
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# 20211114_180000.WAV
# 20211114_182000.WAV
# 20211114_184000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# 20211114_110000.WAV
# 20211114_111000.WAV
# 20211114_112000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# 20211114_110000.WAV
# 20211114_111000.WAV
# 20211114_112000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# 20210904_180000.WAV
# 20210904_182000.WAV
# 20210904_184000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# 20210904_093000.WAV
# 20210904_094000.WAV
# 20210904_095000.WAV
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# 20210904_123000.WAV
# 20210904_124000.WAV
# 20210904_125000.WAV
# ...

# %% [markdown]
# ## Check every dir has json of extract cli

# %%
# %%bash
# #check every first subdirectory has extract json
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#   do echo "$f"
#      ls "$f"|grep ".*extract.*"
#      echo "----------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# ----------------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# Nueva carpeta_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs
# ----------------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# Nueva carpeta_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs
# ----------------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# ----------------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# ----------------------
# ...

# %% [markdown]
# ## As there are more dirs without extract info rerun all clis of simex for these

# %% [markdown]
# ## check_if_files_in_dir_are_from_different_serial_numbers_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#     do echo "$dir_to_be_processed"
#     check_if_files_in_dir_are_from_different_serial_numbers_and_move_them --input_directory "$dir_to_be_processed" --number_of_processes 10
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# ----------------
# ...

# %% [markdown]
# ## Check if any new dir was created

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for d in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#     do echo "$d"
#     find "$d" -type d -name '*new_dir*'
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# ----------------
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# ----------------
# ...

# %% [markdown]
# # Which directories are of audio?

# %%
# %%bash
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi" >> ~/list_dirs_with_audios.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10306516 ultra" >> ~/list_dirs_with_audios.txt

# %%
# %%bash
# cat ~/list_dirs_with_audios.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733
# ...

# %% [markdown]
# ## check_if_there_are_audio_empty_files_in_dir_and_move_them

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat ~/list_dirs_with_audios.txt)
#     do echo "$dir_to_be_processed"
#     check_if_there_are_audio_empty_files_in_dir_and_move_them --input_directory_audio "$dir_to_be_processed" --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733
# ...

# %% [markdown]
# # Extract serial number, dates and metadata of files and device

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733
# ...

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733
# ...

# %% [markdown]
# ## Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/
# 1
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# 885
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# 2399
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# 1152
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# 336
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible
# 0
# ...

# %% [markdown]
# ## Check logs of `move` cli

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/rerunning_simex_because_missing_info/1/sipecam_subdirectories_cumulus_92.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 1 ]; then
#         logs_file=$(find "$f" -name "logs_simex_move_files_to_standard_directory_*.logs")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# Number of files: 885
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico/logs_simex_move_files_to_standard_directory_2022-08-31-10-58-05.logs
# 2022-08-31 10:58:05,236 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico has serial number 24E4C30453E1BE08
# 2022-08-31 10:58:05,237 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico/20210904_202000.WAV has date 2021-09-04
# 2022-08-31 10:58:05,237 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico/20210930_182000.WAV has date 2021-09-30
# 2022-08-31 10:58:05,237 [INFO]  DaysBetweenFirstAndLastDate: 26
# ...

# %% [markdown]
# ## Rerunning `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2` as timeout happened

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_2022-08-31-18-33-23.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-31 18:33:24,975 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-31 18:33:25,013 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2/RCNX0021.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos with name a3d020b054911fc034ff8bb96b1523de_0021.AVI
# 2022-08-31 18:33:25,015 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos/a3d020b054911fc034ff8bb96b1523de_0021.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos, continuing with move cli
# 2022-08-31 18:33:25,017 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos/a3d020b054911fc034ff8bb96b1523de_0021.jpg doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048599/2021-09-02/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 40 "$file_for_logs"
# Out:
# 2022-08-31 18:33:23,424 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2 has serial number HLPXGM09048599
# 2022-08-31 18:33:23,425 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2/RCNX0004.JPG has date 2021-09-02
# 2022-08-31 18:33:23,425 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2/RCNX0030.AVI has date 2021-10-04
# 2022-08-31 18:33:23,426 [INFO]  DaysBetweenFirstAndLastDate: 32
# 2022-08-31 18:33:23,652 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048599", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-09-02", valueType: String, operator: gte}, {field: date_deployment, value: "2021-10-04", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
# ...

# %% [markdown]
# ## For the dir `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta`
#
# this is a case that only has two images and one video and therefore only in one day was taken this files will hardcode `move` cli specifically `MIN_NUMBER_OF_DAYS` which is set to `2` will be `1`

# %% [markdown]
# **Rerunning `move` cli**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta"
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"

# %% [markdown]
# # Check

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_2022-08-31-18-43-57.logs')
# tail -n 20 "$file_for_logs"
# Out:
# 2022-08-31 18:43:57,695 [INFO]  Writing lat long of centroid of cumulus for MetadataFiles
# 2022-08-31 18:43:57,699 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta/RCNX0001.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos with name 8c22c8167a2b937cdb8c1a3d187d9332_0001.JPG
# 2022-08-31 18:43:57,702 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos/8c22c8167a2b937cdb8c1a3d187d9332_0001.JPG doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos, continuing with move cli
# 2022-08-31 18:43:57,703 [INFO]  File /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos/8c22c8167a2b937cdb8c1a3d187d9332_0001.jpg doesn't exists in /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos, continuing with move cli
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048890/2021-09-04/images_videos"
# file_for_logs=$(find "$dir_to_be_processed" -name 'logs_simex_move_files_to_standard_directory_*.logs')
# head -n 40 "$file_for_logs"
# Out:
# 2022-08-31 18:43:57,212 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta has serial number HLPXGM09048890
# 2022-08-31 18:43:57,213 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta/RCNX0002.JPG has date 2021-09-19
# 2022-08-31 18:43:57,213 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta/RCNX0003.AVI has date 2021-09-19
# 2022-08-31 18:43:57,213 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-08-31 18:43:57,371 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048890", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-09-19", valueType: String, operator: gte}, {field: date_deployment, value: "2021-09-19", valueType: String, operator: lte}]}) {
#       node {
# ...

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_moved_with_simex"
# ls -lht "$path_std_dir"
# Out:
# total 68K
# -rw-r--r-- 1 root 1100 1.4K Aug 31 18:43 dirs_moved_with_simex_31-08-2022.txt
# -rw-r--r-- 1 root 1100  249 Aug 30 07:24 dirs_moved_with_simex_30-08-2022.txt
# -rw-r--r-- 1 root 1100   83 Aug 29 21:00 dirs_moved_with_simex_29-08-2022.txt
# -rw-r--r-- 1 root 1100 3.9K Jul 20 18:23 dirs_moved_with_simex_20-07-2022.txt
# -rw-r--r-- 1 root 1100 7.0K Jul 19 15:53 dirs_moved_with_simex_19-07-2022.txt
# -rw-r--r-- 1 root 1100  438 Jul 18 10:16 dirs_moved_with_simex_18-07-2022.txt
# -rw-r--r-- 1 root 1100 5.1K Jul 17 22:22 dirs_moved_with_simex_17-07-2022.txt
# -rw-r--r-- 1 root 1100  614 Jul 16 18:46 dirs_moved_with_simex_16-07-2022.txt
# -rw-r--r-- 1 root 1100 4.6K Jun 10 12:27 dirs_moved_with_simex_10-06-2022.txt
# -rw-r--r-- 1 root 1100  415 Jun  1 16:56 dirs_moved_with_simex_01-06-2022.txt
# -rw-r--r-- 1 1108 1100   83 Apr  5 14:33 dirs_moved_with_simex_05-04-2022.txt
# -rw-r--r-- 1 1108 1100 4.0K Apr  4 22:50 dirs_moved_with_simex_04-04-2022.txt
# ...

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_moved_with_simex"
# txt_file=$(find "$path_std_dir" -name "*29-08-2022.txt")
# cat "$txt_file"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049514/2021-07-28/images_videos

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_moved_with_simex"
# txt_file=$(find "$path_std_dir" -name "*30-08-2022.txt")
# cat "$txt_file"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/HLPXGM09049271/2021-07-28/images_videos
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048925/2021-07-29/images_videos
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1339/HLPXGM09048599/2021-07-29/images_videos

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_moved_with_simex"
# txt_file=$(find "$path_std_dir" -name "*31-08-2022.txt")
# cat "$txt_file"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1341/24F3190160371DCA/2021-11-14/audios/Ultrasonico
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1341/24E1440360371EA1/2021-11-14/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/248C7D075B1F7CCE/2021-07-28/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1338/2453AC025DAEB645/2021-07-28/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/243B1F055B1F7A97/2021-09-02/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1343/24F3190160371DCA/2021-10-09/audios/Ultrasonico
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1334/248C7D075B1F7CCE/2021-10-08/audios/Audible
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09049092/2021-09-04/images_videos
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09048594/2021-09-04/images_videos
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_0_1342/HLPXGM09049271/2021-09-04/images_videos
# /LUSTRE/sacmod/SIPECAM/data/92/3_92_1_1340/HLPXGM09048270/2021-09-02/images_videos
# ...

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/files_moved_with_simex"
# ls -lht "$path_std_dir"
# Out:
# total 45M
# -rw-r--r-- 1 root 1100 1.7M Aug 31 18:43 files_moved_with_simex_31-08-2022.txt
# -rw-r--r-- 1 root 1100  15K Aug 30 07:24 files_moved_with_simex_30-08-2022.txt
# -rw-r--r-- 1 root 1100  23K Aug 29 21:00 files_moved_with_simex_29-08-2022.txt
# -rw-r--r-- 1 root 1100  44M Aug  6 14:55 files_moved_with_simex_all_data_until_06-08-2022.txt
# drwxr-sr-x 2 root 1100 4.0K Aug  6 14:52 nosirve

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_not_moved_with_simex"
# ls -lht "$path_std_dir"
# Out:
# total 36K
# -rw-r--r-- 1 root 1100 1.3K Aug 31 11:11 dirs_not_moved_with_simex_31-08-2022.txt
# -rw-r--r-- 1 root 1100  13K Aug  6 13:07 dirs_not_moved_with_simex_19-07-2022.txt
# -rw-r--r-- 1 root 1100 5.2K Jul 20 18:23 dirs_not_moved_with_simex_20-07-2022.txt
# -rw-r--r-- 1 root 1100 1.4K Jul 20 06:42 dirs_not_moved_with_simex_17-07-2022.txt
# -rw-r--r-- 1 root 1100  465 Jul 18 14:43 dirs_not_moved_with_simex_18-07-2022.txt

# %%
# %%bash
# path_std_dir="/LUSTRE/sacmod/SIPECAM/data/dirs_not_moved_with_simex"
# txt_file=$(find "$path_std_dir" -name "*31-08-2022.txt")
# cat "$txt_file"
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_3
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi
# /LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_1_1338/Camaras/1338_3/100RECNX
# ...

# %% [markdown]
# **there are no dirs that need to be removed from last `txt` as when rerunning `move` was for dirs that aren't in last `txt`**
