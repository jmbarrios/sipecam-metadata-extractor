# %% [markdown]
# # Continuation of checking dirs that had error when executing `extract..` cli of `simex` See [10-03-2022.ipynb](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/10-03-2022.ipynb)

# %% [markdown]
# Dirs that had error were from cameras, most of errors were related to no GPS information. Commits:
#
# From:
#
# [8f0050529062a497180105f740d2044dc0284cdb](https://github.com/CONABIO/sipecam-metadata-extractor/commit/8f0050529062a497180105f740d2044dc0284cdb)
#
# To:
#
# [6f659fdcc59f996c96be659025b988a9c9ba3bb3](https://github.com/CONABIO/sipecam-metadata-extractor/commit/6f659fdcc59f996c96be659025b988a9c9ba3bb3)
#
# implemented handling of this situation.

# %% [markdown]
# # 9

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048599"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:14 13:44:29",
#             "SerialNumber": "HLPXGM09048599",
#             "FileSize": "897 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/camras/centro"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/camras/centro"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/camras/centro/centro_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/camras/centro/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:12:14 08:57:38",
#             "SerialNumber": "HLPXGM09048271",
#             "FileSize": "592 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 11

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049514"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:12:04 02:58:49",
#             "SerialNumber": "HLPXGM09049514",
#             "FileSize": "269 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 12

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:17 11:59:42",
#             "SerialNumber": "HLPXGM09049271",
#             "FileSize": "983 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 13

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_2/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_2/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_2/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048890"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_2/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:17 07:54:52",
#             "SerialNumber": "HLPXGM09048890",
#             "FileSize": "868 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 14

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_4/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_4/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_4/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048594"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_1_1335/3_92_1_1335_4/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:18 13:30:20",
#             "SerialNumber": "HLPXGM09048594",
#             "FileSize": "900 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 15

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2"
# json_file=$(find "$dir_to_be_processed" -name "*1342_2*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2/1342_2_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048594"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:20 23:58:02",
#             "SerialNumber": "HLPXGM09048594",
#             "FileSize": "219 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 16

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_5"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_5"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_5/1342_5_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_5/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:15 07:10:52",
#             "SerialNumber": "HLPXGM09049271",
#             "FileSize": "358 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 17

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4"
# json_file=$(find "$dir_to_be_processed" -name "*1342_4*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4/1342_4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049201"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:08:28 00:55:37",
#             "SerialNumber": "HLPXGM09049201",
#             "FileSize": "277 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 18

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_3/Nueva carpeta"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_3/Nueva carpeta"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_3/Nueva carpeta/Nueva carpeta_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048890"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_3/Nueva carpeta/RCNX0002.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:19 04:41:11",
#             "SerialNumber": "HLPXGM09048890",
#             "FileSize": "255 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 19

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5"
# json_file=$(find "$dir_to_be_processed" -name "*1340_5*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/1340_5_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:20 23:08:34",
#             "SerialNumber": "HLPXGM09048271",
#             "FileSize": "299 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 20

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1"
# json_file=$(find "$dir_to_be_processed" -name "*1340_1*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/1340_1_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048270"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:02 12:04:30",
#             "SerialNumber": "HLPXGM09048270",
#             "FileSize": "752 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 21

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_2"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_2"
# json_file=$(find "$dir_to_be_processed" -name "*1340_2*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_2/1340_2_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048599"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_2/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:02 14:26:07",
#             "SerialNumber": "HLPXGM09048599",
#             "FileSize": "706 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 22

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_4"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_4"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_4/1340_4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049514"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_4/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:06 10:17:10",
#             "SerialNumber": "HLPXGM09049514",
#             "FileSize": "703 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 23

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_3"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_3"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_3/1340_3_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048925"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_3/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:13 18:39:24",
#             "SerialNumber": "HLPXGM09048925",
#             "FileSize": "250 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
# ...

# %% [markdown]
# # 24

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch1/HLPXGM09048599/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch1/HLPXGM09048599/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch1/HLPXGM09048599/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048599"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch1/HLPXGM09048599/100RECNX/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 10:04:04",
#             "SerialNumber": "HLPXGM09048599",
#             "FileSize": "607 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 25

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch3/HLPXGM09049514/HLPXGM09049514"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch3/HLPXGM09049514/HLPXGM09049514"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch3/HLPXGM09049514/HLPXGM09049514/HLPXGM09049514_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049514"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch3/HLPXGM09049514/HLPXGM09049514/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 13:18:34",
#             "SerialNumber": "HLPXGM09049514",
#             "FileSize": "708 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 26

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch4/HLPXGM09048271/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch4/HLPXGM09048271/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch4/HLPXGM09048271/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch4/HLPXGM09048271/100RECNX/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:12 16:23:03",
#             "SerialNumber": "HLPXGM09048271",
#             "FileSize": "888 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 27

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch2/HLPXGM0948270/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch2/HLPXGM0948270/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch2/HLPXGM0948270/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048270"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch2/HLPXGM0948270/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 11:42:00",
#             "SerialNumber": "HLPXGM09048270",
#             "FileSize": "623 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
# ...

# %% [markdown]
# # 28

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048890"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048890"
# json_file=$(find "$dir_to_be_processed" -name "*09048890*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048890/09048890_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048890"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048890/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:08 09:03:57",
#             "SerialNumber": "HLPXGM09048890",
#             "FileSize": "460 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 29

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048594"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048594"
# json_file=$(find "$dir_to_be_processed" -name "*09048594*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048594/09048594_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048594"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048594/RCNX0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:31 02:20:59",
#             "SerialNumber": "HLPXGM09048594",
#             "FileSize": "341 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 30

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049201"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049201"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049201/09049201_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049201"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049201/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:09:25 07:04:18",
#             "SerialNumber": "HLPXGM09049201",
#             "FileSize": "253 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 31

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049271"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049271"
# json_file=$(find "$dir_to_be_processed" -name "*09049271*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049271/09049271_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049271"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049271/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:30 23:42:40",
#             "SerialNumber": "HLPXGM09049271",
#             "FileSize": "280 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # 32

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 1/3_92_0_1339/1339_5/100RECNX"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --parallel --number_of_processes 10

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 1/3_92_0_1339/1339_5/100RECNX"
# json_file=$(find "$dir_to_be_processed" -name "*.json")
# echo "$json_file"
# python3 -mjson.tool "$json_file"|head -n 100
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 1/3_92_0_1339/1339_5/100RECNX/100RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049201"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 1/3_92_0_1339/1339_5/100RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:07:08 07:00:01",
#             "SerialNumber": "HLPXGM09049201",
#             "FileSize": "327 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
# ...

# %% [markdown]
# # Move files to standard directory

# %%
# %%bash
# echo "SIPECAM_ZENDRO_GQL_URL=https://gql.sipecamdata.conabio.gob.mx/" > ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_USER=<user>" >> ~/.simex_env
# echo "SIPECAM_ZENDRO_GQL_PASSWORD=<password>" >> ~/.simex_env

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_09-03-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# path_std_dir=/LUSTRE/sacmod/SIPECAM/data
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     move_files_to_standard_directory --directory_with_file_of_serial_number_and_dates "$dir_to_be_processed" --path_for_standard_directory "$path_std_dir"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/Audio
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/Audio/Nueva carpeta/Unidad de USB
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_1/ultrasonico
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/ultrasonica
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/audible
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_2/audible
# ...

# %% [markdown]
# ## Check

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_09-03-2022.txt)
#   do echo "$f"
#      ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_5/Audio
# 1
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio
# 1117
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta
# 3133
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_2/Audio/Nueva carpeta/Unidad de USB
# 0
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_1/ultrasonico
# 1008
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_1/audible
# 1628
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_2/audible
# 3746
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_0_1342/1342_4/audible
# 2399
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/ultrasonica
# 1152
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_5/audible
# 2766
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/ultrasonica
# 337
# /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 2/3_92_1_1340/1340_1/audible
# 960
# ...

# %%
# %%bash
# #check every first subdirectory has a JPG, WAV or AVI file
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for f in $(cat /shared_volume/sipecam_subdirectories_09-03-2022.txt)
#   do
#      number_of_sipecam_files=$(ls "$f"|grep "[WAV|wav|JPG|jpg|AVI|avi]$"|wc -l)
#      if [ "$number_of_sipecam_files" -gt 2 ]; then
#         logs_file=$(find "$f" -maxdepth 1 -name "*move*")
#         if [ -f "$logs_file" ]; then
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#             echo "Directory: $f"
#             echo "Number of files: $number_of_sipecam_files"
#             echo "Logs file: $logs_file"
#             cat "$logs_file"
#             echo "---------------------------------------------"
#             echo "---------------------------------------------"
#         fi
#      fi
# done
# IFS=$SAVEIFS
# Out:
# ---------------------------------------------
# ---------------------------------------------
# Directory: /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio
# Number of files: 1117
# Logs file: /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/logs_simex_move_files_to_standard_directory.logs
# 2022-03-16 11:48:14,948 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio has serial number 24F3190160371DCA
# 2022-03-16 11:48:14,949 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/20211114_184000.WAV has date 2021-11-14
# 2022-03-16 11:48:14,949 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/20211215_000000.WAV has date 2021-12-15
# 2022-03-16 11:48:14,949 [INFO]  DaysBetweenFirstAndLastDate: 31
# 2022-03-16 11:48:15,094 [INFO]  Query to Zendro GQL: query {
# ...
