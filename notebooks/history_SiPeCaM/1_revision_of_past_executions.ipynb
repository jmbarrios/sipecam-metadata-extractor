# %% [markdown]
# # Checking some dirs that had error for some reason in 1_03-2022, 2_04-2022 dirs

# %% [markdown]
# # [09-03-2022.ipynb](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/09-03-2022.ipynb)

# %% [markdown]
# ## 1)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_3/100RECNX` contiene archivos que inician en `2021-07-28` y finalizan en `2021-08-26` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-09`
#
# Ver
#
# ```
#
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049514", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
#
# ```
#
# ```
#
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T18:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T19:39:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T16:37:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T19:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T19:21:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:53:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 2)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Playon 1338/Camaras/1338_4/100RECNX` contiene archivos que inician en `2021-07-29` y finalizan en `2021-08-26` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-08`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
#
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T14:29:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 3)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_3/100RECNX` contiene archivos que inician en `2021-07-29` y finalizan en `2021-08-29` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-12-19`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048925", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-12-19T18:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:01:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:03:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T13:00:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 4)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/Entregas_2021/octubre_2021/SIPECAM/Galacia 1339/1339_4` contiene archivos que inician en `2021-07-29` y finalizan en `2021-08-30` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-09`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048599", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T14:53:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T19:33:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T16:00:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T20:27:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:14:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# # [16-03-2022](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb)

# %% [markdown]
# ## 5)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio` contiene archivos que inician en `2021-11-14` y finalizan en `2021-12-15` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2022-01-27`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F3190160371DCA", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
#
# ```
#
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2022-01-27T17:53:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:11:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:11:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:36:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 6)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_0_1341/3_92_0_1341_3/audio/Nueva carpeta` contiene archivos que inician en `2021-11-14` y finalizan en `2021-12-06` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-09`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E1440360371EA1", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T14:56:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:05:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-10-09`?**

# %% [markdown]
# ## 7)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1/ultrasonico` contiene archivos que inician en `2021-09-04` y finalizan en `2021-10-02` Tales fechas no se empalman con la primera fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E4C30453E1BE08", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T14:56:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:09:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-28T17:43:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 8)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2/audible` contiene archivos que inician en `2021-09-04` y finalizan en `2021-09-30` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7CCE", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-28T16:20:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 9)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4/audible` contiene archivos que inician en `2021-09-04` y finalizan en `2021-09-21` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-29`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2411E5085944285C", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-29T17:05:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-29`? o esta fecha `2021-07-29` es muy lejana?**

# %% [markdown]
# ## 10)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/ultrasonica` contiene archivos que inician en `2021-09-03` y finalizan en `2021-10-05` Tales fechas no se empalman con la segunda fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-29`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248D9B045EC9E6B1", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T13:50:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-29T17:05:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:41:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T15:56:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
#
# ```
#
# **Se asignaría `2021-07-29`? o esta fecha `2021-07-29` es muy lejana?**

# %% [markdown]
# ## 11)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5/audible` contiene archivos que inician en `2021-09-03` y finalizan en `2021-09-22` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2453AC025DAEB645", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-28T17:43:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T17:53:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T16:32:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 12)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/ultrasonica` contiene archivos que inician en `2021-09-02` y finalizan en `2021-09-11` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM2423C2045F256D74", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-28T16:20:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 13)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1/audible` contiene archivos que inician en `2021-09-02` y finalizan en `2021-09-09` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-29`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM243B1F055B1F7A97", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-29T15:47:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-29`? o esta fecha `2021-07-29` es muy lejana?**

# %% [markdown]
# ## 14)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_0_1343/Ch3/10306733` contiene archivos que inician en `2021-10-08` y finalizan en `2021-11-08` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2022-01-27`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F3190160371DCA", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2022-01-27T17:53:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:11:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:11:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:36:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 15)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594/10262847 audi` contiene archivos que inician en `2021-10-08` y finalizan en `2021-10-21` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248C7D075B1F7CCE", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-07-28T16:20:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 16)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 4/3_92_1_1335/3_92_1_1335_5/DCIM/100RECNX` contiene archivos que inician en `2021-11-13` y finalizan en `2021-12-13` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-08`.
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T14:29:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-10-08`?**

# %% [markdown]
# ## 17)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_1` contiene archivos que inician en `2021-09-04` y finalizan en `2021-09-29` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-08`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049092", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T14:49:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T13:52:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-29T15:55:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T20:10:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T16:38:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T16:48:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:08:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 18)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_2` contiene archivos que inician en `2021-09-04` y finalizan en `2021-09-30` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-28`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048594", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:56:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T15:50:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-28T22:29:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T15:58:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:55:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T16:09:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**

# %% [markdown]
# ## 19)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_5` contiene archivos que inician en `2021-09-04` y finalizan en `2021-10-01` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-10-08`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T14:29:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# **Revisar cómo resolver este caso**

# %% [markdown]
# ## 20)
#
# La entrega de `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_4` contiene archivos que inician en `2021-08-12` y finalizan en `2021-09-01` Tales fechas no se empalman con la primer fecha que tenemos de colocación de dispositivo en Kobo: `2021-07-29`
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049201", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
#
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T17:43:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T14:45:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-29T21:02:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
# **Se asignaría `2021-07-29`? o esta fecha `2021-07-29` es muy lejana?**

# %% [markdown]
# ## 21)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_0_1342/1342_3/Nueva carpeta`
#
# inicio: 2021-09-19
#
# fin: 2021-09-19
#
# **Se asignaría `2021-07-28`? o esta fecha `2021-07-28` es muy lejana?**
#
# (dos fotos y un video únicamente)
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048890", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T14:54:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T14:08:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-28T16:35:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T18:28:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T17:45:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:02:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T15:33:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T14:57:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 22)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_5`
#
# inicio: 2021-09-03
#
# fin: 2021-10-05
#
# **Se asignaría `2021-07-29`? o esta fecha `2021-07-29` es muy lejana?**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T19:25:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T16:03:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:54:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-29T17:15:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T17:12:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T17:20:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:42:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T18:05:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T13:48:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T16:40:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 23)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_1`
#
# inicio: 2021-09-02
#
# fin: 2021-09-13
#
# Se asignaría 2021-07-28? o esta fecha 2021-07-28 es muy lejana?
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048270", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T16:24:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T15:17:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-28T18:02:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 24)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_2`
#
# inicio: 2021-09-02
#
# fin: 2021-10-04
#
#
# **Asignar 2021-10-09**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048599", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T14:53:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T19:33:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T16:00:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T20:27:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:14:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T14:34:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 25)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_4/`
#
# inicio: 2021-09-03
#
# fin: 2021-10-01
#
# **Revisar cómo resolver este caso.**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049514", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T18:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T19:39:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T16:37:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T19:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T19:21:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T16:46:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 26)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 2/3_92_1_1340/1340_3`
#
# inicio: 2021-09-02
#
# fin: 2021-10-17
#
#
# **Revisar cómo resolver este caso.**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048925", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-12-19T18:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:01:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:03:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T13:00:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-14T16:28:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# Number 24 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch1/HLPXGM09048599/100RECNX/100RECNX/`
#
# (check this last statement)

# %% [markdown]
# Number 25 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch3/HLPXGM09049514/HLPXGM09049514/HLPXGM09049514`
#
# (check this last statement)

# %% [markdown]
# Number 26 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch4/HLPXGM09048271/100RECNX/100RECNX/`
#
# (check this last statement)

# %% [markdown]
# Number 27 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_0_1343/Ch2/HLPXGM0948270/100RECNX/100RECNX/`
#
# (check this last statement)

# %% [markdown]
# Number 28 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09048890/09048890/`
#
# (check this last statement)

# %% [markdown]
# ## 27)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09048594`
#
# inicio: 2021-10-21
#
# fin: 2021-11-05
#
# **Asignar 2021-10-08**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048594", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:56:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T15:50:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-28T22:29:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T15:58:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:55:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T16:09:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-14T14:10:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 28)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 3/3_92_1_1334/09049201`
#
# inicio: 2021-09-09
#
# fin: 2021-10-06
#
# **Asignar 2021-10-08**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049201", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T17:43:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-13T14:45:00.000Z"
#           },
#           {
#             "date_deployment": "2021-07-29T21:02:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# Number 31 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 3/3_92_1_1334/09049271/09049271/`
#
# (check this last statement)

# %% [markdown]
# Number 32 of https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/16-03-2022.ipynb is ok, their files were moved successfully but are repeated here: `/LUSTRE/sacmod/SIPECAM/cumulo_92/Mes 1/3_92_0_1339/1339_5/100RECNX/100RECNX/`
#
# (check this last statement)

# %% [markdown]
# ## 29)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_1_1338/Camaras/1338_3/100RECNX`
#
# inicio: 2021-07-28
#
# fin: 2021-08-26
#
# **Revisar cómo resolver este caso**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049514", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T18:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T19:39:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T16:37:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T19:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T19:21:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T16:46:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 30)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_1_1338/Camaras/1338_4/100RECNX`
#
# inicio: 2021-07-29
#
# fin: 2021-08-26
#
#
# **Revisar cómo resolver este caso**
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T14:29:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-14T15:43:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 31)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_0_1339/1339_3/100RECNX/`
#
# inicio: 2021-07-29
#
# fin: 2021-08-29
#
#
# **Revisar cómo resolver este caso**
#
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048925", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-12-19T18:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:01:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T16:03:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T13:00:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-14T16:28:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 32)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/primera_entrega/Mes 1/3_92_0_1339/1339_4`
#
# inicio: 2021-07-29
#
# fin: 2021-08-30
#
# **Revisar cómo resolver este caso**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048599", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T14:53:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T19:33:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-27T16:00:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T20:27:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T16:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T16:14:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T14:34:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# # [17-03-2022](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/17-03-2022.ipynb)

# %% [markdown]
# ## 33)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_04_RanchoNuevo/101RECNX`
#
# inicio: 2021-08-29
#
# fin: 2021-08-30
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049680", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-08-04T16:35:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-13T16:59:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# **Se asignaría `2021-08-04`?**

# %% [markdown]
# # [28-03-2022](https://github.com/CONABIO/sipecam-metadata-extractor/blob/develop/notebooks/history_SiPeCaM/1_03-2022/28-03-2022.ipynb)

# %% [markdown]
# ## 34)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/entrega_22.marzo.2022/Mes 5/3_92_0_1336/3_92_0_1336_5/HLPXGM09048568`
#
# inicio: 2022-01-05
#
# fin: 2022-01-19
#
# **Asignar 2021-12-18**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049514", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-09T18:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-11-14T16:04:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-18T19:39:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T16:37:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-05T19:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-07T19:21:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-12T16:46:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 35)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/entrega_22.marzo.2022/Mes 6/3_92_1_1338/3_92_1_1338_4/HLPXGM09049271`
#
# inicio: 2022-02-10
#
# fin: 2022-02-27
#
# **Se asignaría 2022-01-26 ?**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049271", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2021-10-08T16:06:00.000Z"
#           },
#           {
#             "date_deployment": "2021-12-19T16:13:00.000Z"
#           },
#           {
#             "date_deployment": "2022-01-26T17:36:00.000Z"
#           },
#           {
#             "date_deployment": "2022-03-04T17:34:00.000Z"
#           },
#           {
#             "date_deployment": "2022-04-06T14:29:00.000Z"
#           },
#           {
#             "date_deployment": "2022-05-14T15:43:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## 36)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/entrega_22.marzo.2022/Mes 6/3_92_0_1339/3_92_0_1339_ 4/HLPXGM09048890`
#
# inicio: 2022-01-27
#
# fin: 2022-03-01
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048890", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2022-01-27", valueType: String, operator: gte}, {field: date_deployment, value: "2022-03-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# ```
#
# **Previous error was that there was more than one date of deployment. This has been fixed. Then only run again `move` cli**

# %% [markdown]
# ## 37)
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_92/entrega_22.marzo.2022/Mes 6/3_92_0_1339/3_92_0_1339_ 2/HLPXGM09049314`
#
# inicio: 2022-01-26
#
# fin: 2022-02-26
#
# **Revisar cómo resolver este caso**
#
# ```
# query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049314", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}) {
#       date_deployment
#     }
#   }
# }
# ```
#
# ```
# {
#   "data": {
#     "physical_devices": [
#       {
#         "device_deploymentsFilter": [
#           {
#             "date_deployment": "2022-05-12T15:44:00.000Z"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
