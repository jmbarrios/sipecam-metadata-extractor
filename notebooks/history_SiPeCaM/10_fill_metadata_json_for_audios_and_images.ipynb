# %% [markdown]
# # In file `files_with_missing_metadata_2022-07-29` there are files which don't have metadata in their correspondent `json` file

# %%
l = []
file = "files_with_missing_metadata_2022-07-29.txt"
with open(file, 'r') as src:
    for f in src:
        line = f.rstrip()
        l.append(line)

# %%
l[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/42d8aa3b49eb0d43954ed044ef58fdfc.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/fcf6407b5833c183baf810915b81b183.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/e3564578bbcc8314464a4248e5dede06.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/dfbabb8a28b8f234d88f6683f3da859b.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4220711e3005214ddc83dee6d5d39c34.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4dd2b2ee52388cc1aca233691beb3421.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/aa24ceb9fb6264f5c44bb3771315a831.wav',
# ...

# %%
len(l)
# Out:
# 102679

# %%
l[len(l)-1]
# Out:
# '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/5c0f93f5be5accea3b86c4bc94d7a5bb.WAV'

# %%
l = []
file = "files_with_missing_metadata_2022-07-29.txt"
with open(file, 'r') as src:
    for f in src:
        line = f.rstrip()
        substr = line.split("audios")[0]
        if "images_videos" not in substr:
            if substr not in l:
                l.append(substr)
        else:
            substr = line.split("images_videos")[0]
            if substr not in l:
                l.append(substr)

# %%
l
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/',
# ...

# %% [markdown]
# **For the case of the dir with images let's see which files are not in `json`**

# %%
l = []
file = "files_with_missing_metadata_2022-07-29.txt"
with open(file, 'r') as src:
    for f in src:
        line = f.rstrip()
        substr = line.split("audios")[0]
        if "images_videos" in substr:
            l.append(substr)

# %%
l
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/ca811beabda05c07d7ce37209f45ac40_0008.JPG',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/15a3c8fa7a750ca6ada3792531a3dbf2_0004.JPG',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/74f3a15286d1f204e6019a7631d0f5a7_0002.JPG',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/1e20e16cbc5edbd7edb2f19d2f0c5083_0005.JPG',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/8eca12188c0b61969507741c9115d8a2_0001.JPG',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/0bc093f74bd086afc9ef9b728b374dda_0007.JPG']

# %% [markdown]
# **Let's check if this numbers are repeated**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[1-2].JPG"
# Out:
# 74f3a15286d1f204e6019a7631d0f5a7_0002.JPG
# 8eca12188c0b61969507741c9115d8a2_0001.JPG
# ce6f5df4a590edb30eaeb014e0c2ffd4_0001.JPG
# e660334b7477becf3bb02b64135dd242_0002.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[4-5].JPG"
# Out:
# 15a3c8fa7a750ca6ada3792531a3dbf2_0004.JPG
# 1e20e16cbc5edbd7edb2f19d2f0c5083_0005.JPG
# 31422e4d11873d87648cd6a4c75f841d_0005.JPG
# d8d6de82c7125a1e5998dbc5719bafb0_0004.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[7-8].JPG"
# Out:
# 0bc093f74bd086afc9ef9b728b374dda_0007.JPG
# c0683990047847e14629668f6781e62e_0008.JPG
# c564892ae2c4636620b77748fa18d7bb_0007.JPG
# ca811beabda05c07d7ce37209f45ac40_0008.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_0010.JPG"
# Out:
# 0fb63870e55b1b72a60357ffeb1b74f1_0010.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_0011.JPG"
# Out:
# cd3ef53bf41b698f987a0fd361ccc9c0_0011.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[3,6,9].AVI"
# Out:
# 11e1a01bdd48afd27ca3ab0257d0d962_0009.AVI
# 50737fa64600d499eb82fcffe373666c_0003.AVI
# 627b66600140fefb8a180e88a21fb722_0009.AVI
# 9c739b7c2ee9958db05e2fbd98fbe26f_0003.AVI
# c686f7ee4fd5ae6698cd829aca0c705c_0006.AVI
# ceeb56704fb126659c02bf798e5e5c14_0006.AVI

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_0012.AVI"
# Out:
# 1623a2e2f5967352817986d16674963e_0012.AVI

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[3,6,9].mp4"
# Out:
# 11e1a01bdd48afd27ca3ab0257d0d962_0009.mp4
# 50737fa64600d499eb82fcffe373666c_0003.mp4
# 627b66600140fefb8a180e88a21fb722_0009.mp4
# 9c739b7c2ee9958db05e2fbd98fbe26f_0003.mp4
# c686f7ee4fd5ae6698cd829aca0c705c_0006.mp4
# ceeb56704fb126659c02bf798e5e5c14_0006.mp4

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# ls "$d"|grep ".*_000[3,6,9].webm"
# Out:
# 11e1a01bdd48afd27ca3ab0257d0d962_0009.webm
# 50737fa64600d499eb82fcffe373666c_0003.webm
# 627b66600140fefb8a180e88a21fb722_0009.webm
# 9c739b7c2ee9958db05e2fbd98fbe26f_0003.webm
# c686f7ee4fd5ae6698cd829aca0c705c_0006.webm
# ceeb56704fb126659c02bf798e5e5c14_0006.webm

# %% [markdown]
# **Let's review json**

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/images_videos_simex_metadata_files_and_device_17-07-2022.json"
# python3 -mjson.tool "$j"|head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 35,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049899",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-03",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.57516,
#         "Longitude": -100.53432,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/120d7a479cedb659e94668fc8c8489a0_0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:12:06 20:51:50",
#             "SerialNumber": "HLPXGM09049899",
#             "FileSize": "241 kB",
# ...

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/images_videos_simex_metadata_files_and_device_17-07-2022.json"
# python3 -mjson.tool "$j"|tail -n 80
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/c429c0c079b6a89a31055b6109d51fca_0108.AVI": {
#             "BitRate": "5.2 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
#             "VideoCompression": "Motion JPEG DIB (fourcc:\"MJPG\")",
#             "AudioSampleRate": "",
#             "AudioCompressionRate": "",
#             "AudioCompression": "",
#             "AudioBitRate": "",
#             "FileSize": "3.3 MB",
#             "DateTimeOriginal": "2021:12:10 00:06:42",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
# ...

# %% [markdown]
# **Let's check if any image has correct coordinates**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/050560667eb6bae9d137fc657888c633_0406.JPG"
# exiftool -a -j -n "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/050560667eb6bae9d137fc657888c633_0406.JPG",
#   "ExifToolVersion": 12.43,
#   "FileName": "050560667eb6bae9d137fc657888c633_0406.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos",
#   "FileSize": 250896,
#   "FileModifyDate": "2022:01:03 21:19:08-06:00",
#   "FileAccessDate": "2022:08:02 12:17:27-05:00",
#   "FileInodeChangeDate": "2022:08:01 19:53:58-05:00",
#   "FilePermissions": 100777,
#   "FileType": "JPEG",
#   "FileTypeExtension": "JPG",
#   "MIMEType": "image/jpeg",
#   "ExifByteOrder": "II",
#   "Make": "RECONYX",
#   "Model": "HF2 PRO COVERT",
#   "XResolution": 72,
#   "YResolution": 72,
#   "ResolutionUnit": 2,
#   "ModifyDate": "2022:01:03 21:19:09",
#   "YCbCrPositioning": 2,
#   "ExposureTime": 0.01666666667,
#   "ISO": 200,
#   "TimeZoneOffset": 0,
#   "ExifVersion": "0220",
# ...

# %% [markdown]
# **It appear's the images have their coordinates masked...**

# %% [markdown]
# **Let's check coordinates of the images that have repeated number**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/8eca12188c0b61969507741c9115d8a2_0001.JPG"
# exiftool -a -j -n "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/8eca12188c0b61969507741c9115d8a2_0001.JPG",
#   "ExifToolVersion": 12.43,
#   "FileName": "8eca12188c0b61969507741c9115d8a2_0001.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos",
#   "FileSize": 292201,
#   "FileModifyDate": "2021:12:03 19:02:06-06:00",
#   "FileAccessDate": "2022:08:02 12:27:51-05:00",
#   "FileInodeChangeDate": "2022:07:17 22:21:55-05:00",
#   "FilePermissions": 100777,
#   "FileType": "JPEG",
#   "FileTypeExtension": "JPG",
#   "MIMEType": "image/jpeg",
#   "ExifByteOrder": "II",
#   "Make": "RECONYX",
#   "Model": "HF2 PRO COVERT",
#   "XResolution": 72,
#   "YResolution": 72,
#   "ResolutionUnit": 2,
#   "ModifyDate": "2021:12:03 19:02:07",
#   "YCbCrPositioning": 2,
#   "ExposureTime": 0.03333333333,
#   "ISO": 400,
#   "ExifVersion": "0220",
#   "DateTimeOriginal": "2021:12:03 19:02:07",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/ce6f5df4a590edb30eaeb014e0c2ffd4_0001.JPG"
# exiftool -a -j -n "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/ce6f5df4a590edb30eaeb014e0c2ffd4_0001.JPG",
#   "ExifToolVersion": 12.43,
#   "FileName": "ce6f5df4a590edb30eaeb014e0c2ffd4_0001.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos",
#   "FileSize": 729220,
#   "FileModifyDate": "2021:12:05 11:40:10-06:00",
#   "FileAccessDate": "2022:08:01 19:53:08-05:00",
#   "FileInodeChangeDate": "2022:08:01 19:53:08-05:00",
#   "FilePermissions": 100777,
#   "FileType": "JPEG",
#   "FileTypeExtension": "JPG",
#   "MIMEType": "image/jpeg",
#   "ExifByteOrder": "II",
#   "Make": "RECONYX",
#   "Model": "HF2 PRO COVERT",
#   "XResolution": 72,
#   "YResolution": 72,
#   "ResolutionUnit": 2,
#   "ModifyDate": "2021:12:05 11:40:11",
#   "YCbCrPositioning": 2,
#   "ExposureTime": 0.02677083333,
#   "ISO": 400,
#   "TimeZoneOffset": 0,
#   "ExifVersion": "0220",
# ...

# %% [markdown]
# **Another images**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/74f3a15286d1f204e6019a7631d0f5a7_0002.JPG"
# exiftool -a -j -n "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/74f3a15286d1f204e6019a7631d0f5a7_0002.JPG",
#   "ExifToolVersion": 12.43,
#   "FileName": "74f3a15286d1f204e6019a7631d0f5a7_0002.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos",
#   "FileSize": 291208,
#   "FileModifyDate": "2021:12:03 19:02:08-06:00",
#   "FileAccessDate": "2022:07:17 22:21:55-05:00",
#   "FileInodeChangeDate": "2022:07:17 22:21:55-05:00",
#   "FilePermissions": 100777,
#   "FileType": "JPEG",
#   "FileTypeExtension": "JPG",
#   "MIMEType": "image/jpeg",
#   "ExifByteOrder": "II",
#   "Make": "RECONYX",
#   "Model": "HF2 PRO COVERT",
#   "XResolution": 72,
#   "YResolution": 72,
#   "ResolutionUnit": 2,
#   "ModifyDate": "2021:12:03 19:02:08",
#   "YCbCrPositioning": 2,
#   "ExposureTime": 0.03333333333,
#   "ISO": 400,
#   "ExifVersion": "0220",
#   "DateTimeOriginal": "2021:12:03 19:02:08",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/e660334b7477becf3bb02b64135dd242_0002.JPG"
# exiftool -a -j -n "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/e660334b7477becf3bb02b64135dd242_0002.JPG",
#   "ExifToolVersion": 12.43,
#   "FileName": "e660334b7477becf3bb02b64135dd242_0002.JPG",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos",
#   "FileSize": 663833,
#   "FileModifyDate": "2021:12:05 11:40:12-06:00",
#   "FileAccessDate": "2022:08:01 19:52:23-05:00",
#   "FileInodeChangeDate": "2022:08:01 19:52:23-05:00",
#   "FilePermissions": 100777,
#   "FileType": "JPEG",
#   "FileTypeExtension": "JPG",
#   "MIMEType": "image/jpeg",
#   "ExifByteOrder": "II",
#   "Make": "RECONYX",
#   "Model": "HF2 PRO COVERT",
#   "XResolution": 72,
#   "YResolution": 72,
#   "ResolutionUnit": 2,
#   "ModifyDate": "2021:12:05 11:40:12",
#   "YCbCrPositioning": 2,
#   "ExposureTime": 0.02677083333,
#   "ISO": 400,
#   "TimeZoneOffset": 0,
#   "ExifVersion": "0220",
# ...

# %% [markdown]
# **Manually reviewing the images, next are the ones that need to be moved**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# mv "$d/ce6f5df4a590edb30eaeb014e0c2ffd4_0001.JPG" "$dst/"
# mv "$d/d8d6de82c7125a1e5998dbc5719bafb0_0004.JPG" "$dst/"
# mv "$d/31422e4d11873d87648cd6a4c75f841d_0005.JPG" "$dst/"
# mv "$d/c564892ae2c4636620b77748fa18d7bb_0007.JPG" "$dst/"
# mv "$d/c0683990047847e14629668f6781e62e_0008.JPG" "$dst/"

# %% [markdown]
# **Manually reviewing the videos, next are the ones that need to be moved**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# mv "$d/9c739b7c2ee9958db05e2fbd98fbe26f_0003.mp4" "$dst/"
# mv "$d/9c739b7c2ee9958db05e2fbd98fbe26f_0003.AVI" "$dst/"
# mv "$d/9c739b7c2ee9958db05e2fbd98fbe26f_0003.webm" "$dst/"
# mv "$d/ceeb56704fb126659c02bf798e5e5c14_0006.mp4" "$dst/"
# mv "$d/ceeb56704fb126659c02bf798e5e5c14_0006.AVI" "$dst/"
# mv "$d/ceeb56704fb126659c02bf798e5e5c14_0006.webm" "$dst/"
# mv "$d/627b66600140fefb8a180e88a21fb722_0009.mp4" "$dst/"
# mv "$d/627b66600140fefb8a180e88a21fb722_0009.webm" "$dst/"
# mv "$d/627b66600140fefb8a180e88a21fb722_0009.AVI" "$dst/"

# %% [markdown]
# **Reviewing manually the images, it seems that the coordinates that must be in json are:**

# %% [markdown]
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049899",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-03",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.5751,
#         "Longitude": -100.5342,
#         "NodeCategoryIntegrity": "Integro"
#     }
# ```

# %% [markdown]
# **Hardcoding code of `extract`cli with last info...**

# %% [markdown]
# **extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/images_videos_simex_metadata_files_and_device_03-08-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049899",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-03",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.5751,
#         "Longitude": -100.5342,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/fabb0f21925f38252cf722f3bf30a876_0290.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:12:30 18:22:26",
#             "SerialNumber": "HLPXGM09049899",
#             "FileSize": "251 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/HLPXGM09049899/2021-12-03/images_videos/images_videos_simex_metadata_files_and_device_03-08-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "",
#             "AudioCompressionRate": "",
#             "AudioCompression": "",
#             "AudioBitRate": "",
#             "FileSize": "3.5 MB",
#             "DateTimeOriginal": "2021:12:13 01:45:24",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
#             "StreamCount": 1,
#             "AudioSampleCount": -1,
#             "Encoding": "",
#             "NumChannels": -1,
#             "AvgBytesPerSec": -1,
#             "BitsPerSample": -1,
#             "Duration": "5.12 s",
#             "MaxDataRate": 26542080,
#             "Megapixels": 0.73728,
#             "GPSLatitudeRef": "North",
# ...

# %% [markdown]
# # We found that a video was wrong

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/data/99/4_99_0_1583/HLPXGM09049534/2022-02-04/images_videos/71a5acd4de1924efc5ed740f6ad3c055_1044.AVI`

# %% [markdown]
# **Will be moved**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/99/4_99_0_1583/HLPXGM09049534/2022-02-04/images_videos/71a5acd4de1924efc5ed740f6ad3c055_1044.AVI"
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# mv "$f" "$dst/"

# %% [markdown]
# **And this video wasn't in the `json`..., then will not rerun extract cli**

# %% [markdown]
# ## For the case of audios

# %%
# %%bash
# f="/shared_volume/dirs_audio_with_missing_metadata_2022-07-29.txt"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/' > "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/' >> "$f"
# echo '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/' >> "$f"

# %%
# %%bash
# cat "/shared_volume/dirs_audio_with_missing_metadata_2022-07-29.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/
# ...

# %%
# %%bash
# f="/shared_volume/dirs_audio_with_missing_metadata_2022-07-29.txt"
# for dir_to_be_processed in $(cat "$f");do
#     json=$(find "$dir_to_be_processed" -name "*.json")
#     echo "$json"
#     python3 -mjson.tool "$json"|head -n 50
#     echo "-------------------------"
# done
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 29,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-22",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.46268,
#         "Longitude": -100.19501,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4644f4c89d836f4aeef0527b7e262b55.wav": {
#             "Battery": "4.6V",
#             "Datetime": "20:40:00 25/02/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %%
# %%bash
# python3 -mjson.tool "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/Audible_simex_metadata_files_and_device_18-07-2022.json"|head -n 50
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 9,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360374A34",
#         "SerialNumber": "24E1440360374A34",
#         "NomenclatureNode": "1_33_0_1224",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-01-10",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.54693,
#         "Longitude": -100.63046,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/3abb27544a93ee745d68ff74accc48a4.WAV": {
#             "Battery": "3.3V",
#             "Datetime": "15:30:00 13/01/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "24E1440360374A34",
# ...

# %%
# %%bash
# python3 -mjson.tool "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json"|head -n 50
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 141,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360374A34",
#         "SerialNumber": "24E1440360374A34",
#         "NomenclatureNode": "1_33_0_1224",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-01-10",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.54693,
#         "Longitude": -100.63046,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/7b0bc5520a566b03fd368964a3a16564.wav": {
#             "Battery": "3.2V",
#             "Datetime": "21:00:00 24/04/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "24E1440360374A34",
# ...

# %% [markdown]
# **Lets check if there are repeated files in each of the dirs**

# %%
import os
import glob
import itertools
import pathlib

# %%
file="/shared_volume/dirs_audio_with_missing_metadata_2022-07-29.txt"

# %%
def multiple_file_types(input_directory, patterns, recursive=False):
    """
    Return iterable with files that have a common pattern. Will search
    in a recursive or non recursive way.
    Args:
        input_directory (str): directory where files with common pattern
        will be searched.
        patterns (list): list of patterns to search for.
    Returns:
        iterable with files that have a common pattern.
    """
    if recursive:
        expression = "/**/*"
    else:
        expression = "/*"
    return itertools.chain.from_iterable(glob.iglob(input_directory + \
                                                    expression + pattern,
                                                    recursive=recursive) for pattern in patterns)

# %%
patterns = ["WAV", "wav"]

# %%
with open(file, 'r') as src:
    dictionary = {}
    dirs = src.read().splitlines()
    for d in dirs:
        iterable = multiple_file_types(d,patterns, recursive=True)
        dictionary[d] = {}
        dictionary[d]["not_repeated"] = []
        dictionary[d]["repeated"] = []
        l2 = dictionary[d]["not_repeated"]
        l3 = dictionary[d]["repeated"]
        l2_check = []
        l3_check = []
        for audio_file in iterable:
            audio_file_pathlib = pathlib.Path(audio_file)
            audio_file_no_suffix = audio_file.split(audio_file_pathlib.suffix)[0]
            #audio_filename = audio_file_pathlib.name.split(audio_file_pathlib.suffix)[0]
            if audio_file_no_suffix not in l2_check:
                l2_check.append(audio_file_no_suffix)
                l2.append(audio_file)
            else:
                l3_check.append(audio_file_no_suffix)
                l3.append(audio_file)

# %%
dirs
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/',
# ...

# %%
l_1_repeated = dictionary['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/']["repeated"]

# %%
len(l_1_repeated)
# Out:
# 1173

# %%
l_1_not_repeated = dictionary['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/']["not_repeated"]

# %%
len(l_1_not_repeated)
# Out:
# 3872

# %%
l_1_repeated[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/42d8aa3b49eb0d43954ed044ef58fdfc.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/fcf6407b5833c183baf810915b81b183.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/cf56c803a3698677e815824094015086.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4220711e3005214ddc83dee6d5d39c34.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/518eddf0cea44802260d79bd851cc5e6.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/aa24ceb9fb6264f5c44bb3771315a831.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/f03250ce70e35967643025e18876909d.wav',
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# ls "$d"|grep "42d8aa3b49eb0d43954ed044ef58fdfc"
# Out:
# 42d8aa3b49eb0d43954ed044ef58fdfc.WAV
# 42d8aa3b49eb0d43954ed044ef58fdfc.wav

# %% [markdown]
# **Checking that are the same audio**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# cp "$d/42d8aa3b49eb0d43954ed044ef58fdfc.WAV" .
# cp "$d/42d8aa3b49eb0d43954ed044ef58fdfc.wav" .

# %% [markdown]
# **Checking which dirs have repeated files and how many files are repeated**

# %%
for d in dirs:
    print(d)
    print(len(dictionary[d]["repeated"]))
    print("-"*40)
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/
# 1173
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/
# 0
# ----------------------------------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/
# 0
# ----------------------------------------
# ...

# %%
# %%bash
# cat /shared_volume/dirs_audio_with_missing_metadata_2022-07-29.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/
# ...

# %% [markdown]
# # It was implemented a cli to check if a dir have different serial numbers of files as this situation was detected...

# %% [markdown]
# **For each dir check if files have different serial numbers and move files inside a dir**

# %%
# %%bash
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/" >> /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt

# %%
# %%bash
# cat /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/
# ...

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt)
#     do echo "$dir_to_be_processed"
#     s_n_r=$(echo "$dir_to_be_processed"|cut -d'/' -f8)
#     echo "$s_n_r"
#     check_if_files_in_dir_are_from_different_serial_numbers_and_move_them --input_directory "$dir_to_be_processed" --serial_number_reference "$s_n_r" --number_of_processes 10
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/
# 248D9B0260371FD2
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/
# 24E1440360372FF8
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/
# 24F3190160371FAB
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/
# 24F3190160371FAB
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/
# 248D9B0260371FD2
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/
# 24F31901603734A9
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/
# 24E1440360371ED3
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/
# ...

# %% [markdown]
# **Check which dirs were created**

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for d in $(cat /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt)
#     do echo "$d"
#     find "$d" -type d -name '*[0-9]*'
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24E1440360371ED3
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/242A260460373575
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371FAB
# ...

# %%
# %%bash
# ls /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39/*.wav|wc -l
# ls /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85/*.wav|wc -l
# ls /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9/*.wav|wc -l
# ls /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C/*.wav|wc -l
# Out:
# 989
# 165
# 348
# 324

# %%
989+165+348+324
# Out:
# 1826

# %% [markdown]
# **Move dirs that have serial number different from the std dir**

# %%
# %%bash
# mkdir -p /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/

# %%
# %%bash
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24E1440360371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/242A260460373575" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371FAB" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/24E1440360372FF8" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/24F3190160374A1B" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/24E1440360371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/242A260460373575" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/24E1440360371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/248D9B0260371F39" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/248D9B026037BD85" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/24E1440360371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/248D9B0260371FD2" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/248D9B0260371F39" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/248D9B026037BD85" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/248C7D075B1F35B9" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/24F3190160374A1B" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/242A260460373575" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/24E1440360372FF8" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/24F3190160371FAB" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/248C7D075B1F35B9" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/24F3190160374A1B" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/24E1440360371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/24E1440360372FF8" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/24F3190160371FAB" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/24F3190160371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/24F3190160377B16" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/248D9B0260377D10" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/24F3190160371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/24E1440360374A34" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/248D9B0260377D10" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/24F3190160371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/24E1440360374A34" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/24F3190160377B16" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/248D9B0260371F78" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/24F31901603749F6" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/248D9B0260372F15" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/24F3190160377B48" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/24F31901603749F6" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/24F3190160377B16" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/24E1440360372FF8" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/248D9B0260372F15" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/24F3190160371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/24F3190160374A1B" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/24F3190160377B16" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/248D9B0260377D10" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/24F3190160371FAB" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/24F3190160377B48" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/24F31901603749F6" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/248D9B0260372F15" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/24F3190160377B48" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/248D9B0260371F78" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/24F31901603749F6" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/24F3190160371F6C" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/248D9B0260371EA1" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/24F3190160371ED3" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/24E1440360374A34" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/242A2604603734A9" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# echo "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/248D9B0260377D10" >> /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt

# %%
# %%bash
# cat /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24E1440360371ED3
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/242A260460373575
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371FAB
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575
# ...

# %% [markdown]
# **(this solution was not good, see down for a better solution) Move to dir: /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/**

# %%
# %%bash
# txt="/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt"
# dst_dir="/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/"
# for d in $(cat "$txt")
#     do
#         mv "$d" "$dst_dir"
# done
# Out:
# mv: cannot move '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C' to '/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/24F3190160371F6C': Directory not empty
# mv: cannot move '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575' to '/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/242A260460373575': Directory not empty
# mv: cannot move '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/24E1440360371ED3' to '/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/24E1440360371ED3': Directory not empty
# mv: cannot move '/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/242A260460373575' to '/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/242A260460373575': Directory not empty
# ...

# %% [markdown]
# **Check**

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for d in $(cat /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt)
#     do echo "$d"
#     find "$d" -type d -name '*[0-9]*'
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/24E1440360371ED3
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/242A260460373575
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/
# ...

# %% [markdown]
# **Is better next solution of Move to dir: /LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/**

# %%
# %%bash
# txt="/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt"
# dst_dir="/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/"
# for d in $(cat "$txt")
#     do
#         serial_number=$(echo $d|cut -d'/' -f8)
#         for f in $(ls "$d")
#             do
#                 mkdir -p "$dst_dir$serial_number"
#                 mv "$d/$f" "$dst_dir$serial_number"
#             done
# done
# Out:
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39': No such file or directory
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85': No such file or directory
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9': No such file or directory
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C': No such file or directory
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24E1440360371ED3': No such file or directory
# ls: cannot access '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/242A260460373575': No such file or directory
# ...

# %% [markdown]
# **Check if there are no wavs files**

# %%
# %%bash
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for d in $(cat /shared_volume/complete_dirs_audio_with_missing_metadata_2022-07-29.txt)
#     do
#     dirs_with_diff_serial_number=$(find "$d" -type d -name '*[0-9]*')
#     for dir_diff in $dirs_with_diff_serial_number
#         do
#             echo "$dir_diff"
#             ls "$dir_diff"
#         done
#     echo "----------------"
# done
# IFS=$SAVEIFS
# Out:
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/24E1440360371ED3
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/242A260460373575
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/248D9B0260371F39
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/248D9B026037BD85
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/24F3190160371F6C
# ----------------
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/24E1440360371F6C
# ...

# %% [markdown]
# **Delete dirs with different serial numbers**

# %%
# %%bash
# txt="/LUSTRE/sacmod/SIPECAM/dirs_with_different_serial_numbers_detected_simex/05-08-2022/list_dirs_different_serial_number.txt"
# for d in $(cat "$txt")
#     do
#         echo "$d"
#         rm -rf "$d"
# done
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B0260371F39
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/248D9B026037BD85
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F31901603734A9
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/24F3190160371F6C
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24E1440360371ED3
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/242A260460373575
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371FAB
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/24F3190160371F6C
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/242A260460373575
# ...

# %% [markdown]
# ## For serial number: 248D9B0260371FD2

# %% [markdown]
# **Which json is the one related to this json? use json of `extract`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep '248D9B0260371FD2' | head -n 5
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/10306795_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2"
#             "SerialNumber": "248D9B0260371FD2",
#             "Comment": "Recorded at 20:40:00 19/12/2021 (UTC-6) by AudioMoth 248D9B0260371FD2 at medium gain setting while battery state was 4.4V and temperature was 23.3C.",
#             "SerialNumber": "248D9B0260371FD2",
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306520/10306520_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ----------------------------
# ...

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     echo "$dir_to_be_processed"
#     json=$(find "$dir_to_be_processed" -maxdepth 1 -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep '248D9B0260371FD2' | head -n 5
#     echo "-----------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/Lost1611644_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# -----------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/Lost4283135_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# -----------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/Lost4033497_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# -----------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349
# ...

# %% [markdown]
# **Check logs of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_15-07-2022_cumulus_31.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260371FD2' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 50
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/logs_simex_move_files_to_standard_directory.logs
# 2022-07-17 08:20:05,822 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795 has serial number 248D9B0260371FD2
# 2022-07-17 08:20:05,824 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/20211208_212000.WAV has date 2021-12-08
# 2022-07-17 08:20:05,824 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_31/entrega_09.junio.2022/Nodo-31-Atoyac/Audiomoth-1-31-0-1218-los valles/10306795/20220114_022000.WAV has date 2022-01-14
# 2022-07-17 08:20:05,824 [INFO]  DaysBetweenFirstAndLastDate: 37
# 2022-07-17 08:20:06,124 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248D9B0260371FD2", operator: like}) {
# ...

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260371FD2' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 50
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **There is a log which have audios that were taken in 175 days!!! why simex didn't produce a warning and thereby will not be moved**

# %% [markdown]
# ## An adaptation to `move` cli will be implemented to take into account MAX_NUMBER_DAYS... now all files that appear in the logs will be moved backed to the dir original

# %% [markdown]
# Dir original:
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/
# ```
#
# Dir destiny:
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible
# ```

# %% [markdown]
# **First from `logs`**
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/logs_simex_move_files_to_standard_directory.logs
# ```
#
# **all files moved will be put in a txt**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/logs_simex_move_files_to_standard_directory.logs"
# grep "with name" "$logs"|cut -d':' -f4|cut -d' ' -f5 > "1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"

# %%
# %%bash
# head -n 10 "1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# f08b1f1c4d0b7080cd9a3d7733fe72c1.WAV
# a1c55497aa67e4d2207aa14538c630d3.WAV
# 52d6cfd3b505b055d3d531b45d3157f0.WAV
# d0092feea5994e7ac03f96a1d0c8dd40.WAV
# 29b335c10eafc898bdb845419ad03f9e.WAV
# c59bb1624cfcee9f46ec8627febbf0dd.WAV
# 38f7016298304eecf75198ef9e31e2e4.WAV
# 4384622d6301621234ba2c7a892bf08d.WAV
# de75f810695b8ac24f460dbc262fdeac.WAV
# 61f7cb52b440d9d041ec2de08ce7eb93.WAV

# %%
# %%bash
# tail -n 10 "1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# 20ff09f7fab8823ccb9f5610a77772da.WAV
# b71b88ccd7ae5c5b93b1a55d0565c3dd.WAV
# ee36f80464404ed29ad53ff8e1017d83.WAV
# 995c81515757dd7341ca3760372409e7.WAV
# ef724aa1a1de0f381438ad1ad7739dd5.WAV
# c478d2ca9451fca71c89ae8d598a601a.WAV
# 8de06f99210ebcfde36741297c4f627a.WAV
# 5236ee91e2b35998311e0beb180fab5c.WAV
# 2c60fd43a166a208613728e35cf24ae1.WAV
# b5cdb3f8d6daa8ee414986dd969a8116.WAV

# %%
# %%bash
# wc -l "1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# 10635 1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt

# %% [markdown]
# **Include path where data is and create another .txt**

# %%
# %%bash
# path=/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible
# for f in $(cat "1_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt")
#     do
#         echo "$path/$f" >> "2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
#     done

# %%
# %%bash
# head -n 10 "2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/f08b1f1c4d0b7080cd9a3d7733fe72c1.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/a1c55497aa67e4d2207aa14538c630d3.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/52d6cfd3b505b055d3d531b45d3157f0.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/d0092feea5994e7ac03f96a1d0c8dd40.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/29b335c10eafc898bdb845419ad03f9e.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/c59bb1624cfcee9f46ec8627febbf0dd.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/38f7016298304eecf75198ef9e31e2e4.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4384622d6301621234ba2c7a892bf08d.WAV
# ...

# %%
# %%bash
# tail -n 10 "2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/20ff09f7fab8823ccb9f5610a77772da.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/b71b88ccd7ae5c5b93b1a55d0565c3dd.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/ee36f80464404ed29ad53ff8e1017d83.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/995c81515757dd7341ca3760372409e7.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/ef724aa1a1de0f381438ad1ad7739dd5.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/c478d2ca9451fca71c89ae8d598a601a.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/8de06f99210ebcfde36741297c4f627a.WAV
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/5236ee91e2b35998311e0beb180fab5c.WAV
# ...

# %%
# %%bash
# wc -l "2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# Out:
# 10635 2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt

# %% [markdown]
# **Each file from last txt will be moved to `/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/`**

# %%
# %%bash
# dst_dir="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/"
# for f in $(cat "2_audio_files_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt")
#     do
#     mv "$f" "$dst_dir"
# done

# %% [markdown]
# **Lets check if there are repeated files in dir `/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/`**

# %%
import os
import glob
import itertools
import pathlib

# %%
def multiple_file_types(input_directory, patterns, recursive=False):
    """
    Return iterable with files that have a common pattern. Will search
    in a recursive or non recursive way.
    Args:
        input_directory (str): directory where files with common pattern
        will be searched.
        patterns (list): list of patterns to search for.
    Returns:
        iterable with files that have a common pattern.
    """
    if recursive:
        expression = "/**/*"
    else:
        expression = "/*"
    return itertools.chain.from_iterable(glob.iglob(input_directory + \
                                                    expression + pattern,
                                                    recursive=recursive) for pattern in patterns)

# %%
patterns = ["WAV", "wav"]

# %%
d = "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/"

# %%
iterable = multiple_file_types(d,patterns, recursive=True)
l_not_repeated = []
l_repeated = []
l_not_repeated_check = []
l_repeated_check = []
for audio_file in iterable:
    audio_file_pathlib = pathlib.Path(audio_file)
    audio_file_no_suffix = audio_file.split(audio_file_pathlib.suffix)[0]
    #audio_filename = audio_file_pathlib.name.split(audio_file_pathlib.suffix)[0]
    if audio_file_no_suffix not in l_not_repeated_check:
        l_not_repeated_check.append(audio_file_no_suffix)
        l_not_repeated.append(audio_file)
    else:
        l_repeated_check.append(audio_file_no_suffix)
        l_repeated.append(audio_file)

# %%
len(l_repeated)
# Out:
# 1173

# %%
len(l_not_repeated)
# Out:
# 3872

# %%
l_repeated[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/42d8aa3b49eb0d43954ed044ef58fdfc.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/fcf6407b5833c183baf810915b81b183.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/cf56c803a3698677e815824094015086.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4220711e3005214ddc83dee6d5d39c34.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/518eddf0cea44802260d79bd851cc5e6.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/aa24ceb9fb6264f5c44bb3771315a831.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/f03250ce70e35967643025e18876909d.wav',
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# ls "$d"|grep "42d8aa3b49eb0d43954ed044ef58fdfc"
# Out:
# 42d8aa3b49eb0d43954ed044ef58fdfc.WAV
# 42d8aa3b49eb0d43954ed044ef58fdfc.wav

# %% [markdown]
# **Checking that are the same audio**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# cp "$d/42d8aa3b49eb0d43954ed044ef58fdfc.WAV" .
# cp "$d/42d8aa3b49eb0d43954ed044ef58fdfc.wav" .

# %%
split_d = d.split("/")
cumulus = split_d[5]
nom_node = split_d[6]
num_serial = split_d[7]
date_dep = split_d[8]
filename_repeated = "".join(["/shared_volume/",
                             "repeated_audio_files_04-08-2022",
                             "_",
                             cumulus,
                             "_",
                             nom_node,
                             "_",
                             num_serial,
                             "_",
                             date_dep,
                             ".txt"])
print(filename_repeated)
with open(filename_repeated, 'a') as dst:
    for audio_file in l_repeated:
        dst.write(audio_file + "\n")
print("-"*40)
# Out:
# /shared_volume/repeated_audio_files_04-08-2022_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt
# ----------------------------------------

# %%
# %%bash
# wc -l /shared_volume/repeated_audio_files_04-08-2022_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt
# Out:
# 1173 /shared_volume/repeated_audio_files_04-08-2022_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt

# %%
# %%bash
# head -n 5 /shared_volume/repeated_audio_files_04-08-2022_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/42d8aa3b49eb0d43954ed044ef58fdfc.wav
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/fcf6407b5833c183baf810915b81b183.wav
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/cf56c803a3698677e815824094015086.wav
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4220711e3005214ddc83dee6d5d39c34.wav
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/518eddf0cea44802260d79bd851cc5e6.wav

# %% [markdown]
# **Move files in last txt**

# %%
# %%bash
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# txt="/shared_volume/repeated_audio_files_04-08-2022_31_1_31_1_1213_248D9B0260371FD2_2022-02-22.txt"
# for f in $(cat "$txt")
#     do
#         mv "$f" "$dst/"
# done

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# ls "$d"|grep "42d8aa3b49eb0d43954ed044ef58fdfc"
# Out:
# 42d8aa3b49eb0d43954ed044ef58fdfc.WAV

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 29,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-22",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.46268,
#         "Longitude": -100.19501,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/4644f4c89d836f4aeef0527b7e262b55.wav": {
#             "Battery": "4.6V",
#             "Datetime": "20:40:00 25/02/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-22",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.46268,
#         "Longitude": -100.19501,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/c150ffe29f2489608c43414d5c759011.WAV": {
#             "Battery": "4.5V",
#             "Datetime": "02:30:00 27/02/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.46268,
#             "Longitude": -100.19501
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/fe814e29dc81d64a2b6222c7d5ac804b.WAV": "2022-02-22",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible/f20b83cfb380bd419e7fb9edff2d329b.WAV": "2022-03-08"
#     },
#     "DaysBetweenFirstAndLastDate": 14
# }

# %% [markdown]
# ## For serial number: 24E1440360372FF8

# %% [markdown]
# **Check logs of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24E1440360372FF8' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 50
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 25/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-22
#
# 2022-03-18
#
# nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-22, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.47822, -100.23096, node category of integrity: Integro
#
#
# ----
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 30/logs_simex_move_files_to_standard_directory.logs
#
#
# 2022-02-22
#
# 2022-03-25
#
# nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-22, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.47822, -100.23096, node category of integrity: Integro
#
# ----
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 21/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-22
#
# 2022-03-06
#
# nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-22, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.47822, -100.23096, node category of integrity: Integro
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 24,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360372FF8",
#         "SerialNumber": "24E1440360372FF8",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-22",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.47822,
#         "Longitude": -100.23096,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/0b740f35672e10a1ca0664c15486bce5.wav": {
#             "Battery": "4.4V",
#             "Datetime": "09:50:00 02/03/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360372FF8",
#         "SerialNumber": "24E1440360372FF8",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-22",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.47822,
#         "Longitude": -100.23096,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/629d8e272ecc058cdf7c8301270918a5.wav": {
#             "Battery": "4.2V",
#             "Datetime": "21:20:00 15/03/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.47822,
#             "Longitude": -100.23096
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/5e91e40d31be5f9ab56474011c7f689e.wav": "2022-02-22",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24E1440360372FF8/2022-02-22/audios/Audible/5f23c28da2dd086a1372ea554af24ec3.wav": "2022-03-17"
#     },
#     "DaysBetweenFirstAndLastDate": 23
# }

# %% [markdown]
# ## 24F3190160371FAB/2022-02-23

# %% [markdown]
# **Check logs of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F3190160371FAB' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 50
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:15:16,832 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644 has serial number 24F3190160371FAB
# 2022-07-19 13:15:16,834 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/20220406_125000.WAV has date 2022-04-06
# 2022-07-19 13:15:16,834 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/20220430_110000.WAV has date 2022-04-30
# 2022-07-19 13:15:16,834 [INFO]  DaysBetweenFirstAndLastDate: 24
# 2022-07-19 13:15:17,019 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F3190160371FAB", operator: like}) {
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 22/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-23
#
# 2022-03-09
#
# nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-23, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.46504, -100.23405, node category of integrity: Integro
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 19/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-23
#
# 2022-03-01
#
# nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-23, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.46504, -100.23405, node category of integrity: Integro
#
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 6,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160371FAB",
#         "SerialNumber": "24F3190160371FAB",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-23",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.46504,
#         "Longitude": -100.23405,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/534576210bc0ce331e5f46493104356b.wav": {
#             "Battery": "4.7V",
#             "Datetime": "06:20:00 25/02/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160371FAB",
#         "SerialNumber": "24F3190160371FAB",
#         "NomenclatureNode": "1_31_1_1213",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-02-23",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.46504,
#         "Longitude": -100.23405,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/f74c2437fa4e24a0979d2f809e04f456.wav": {
#             "Battery": "4.8V",
#             "Datetime": "22:20:00 23/02/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.46504,
#             "Longitude": -100.23405
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/f74c2437fa4e24a0979d2f809e04f456.wav": "2022-02-23",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/24F3190160371FAB/2022-02-23/audios/Audible/be4a755ec49d0a604a79f6aa69099155.wav": "2022-03-12"
#     },
#     "DaysBetweenFirstAndLastDate": 17
# }

# %% [markdown]
# ## 24F3190160371FAB/2022-01-15/

# %% [markdown]
# **Check logs of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F3190160371FAB' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 50
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:15:16,832 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644 has serial number 24F3190160371FAB
# 2022-07-19 13:15:16,834 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/20220406_125000.WAV has date 2022-04-06
# 2022-07-19 13:15:16,834 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/20220430_110000.WAV has date 2022-04-30
# 2022-07-19 13:15:16,834 [INFO]  DaysBetweenFirstAndLastDate: 24
# 2022-07-19 13:15:17,019 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F3190160371FAB", operator: like}) {
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 134/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-15
#
# 2022-01-31
#
# nom node: 1_31_0_1216, cum name: 31, date of depl: 2022-01-15, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.39877, -100.26656, node category of integrity: Degradado
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 133/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-15
#
# 2022-01-25
#
# nom node: 1_31_0_1216, cum name: 31, date of depl: 2022-01-15, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.39877, -100.26656, node category of integrity: Degradado
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 131/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-15
#
# 2022-01-20
#
# node: 1_31_0_1216, cum name: 31, date of depl: 2022-01-15, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.39877, -100.26656, node category of integrity: Degradado
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 5,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160371FAB",
#         "SerialNumber": "24F3190160371FAB",
#         "NomenclatureNode": "1_31_0_1216",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-01-15",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.39877,
#         "Longitude": -100.26656,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/3462f243784258ae309d7140d0ff19d9.wav": {
#             "Battery": "4.1V",
#             "Datetime": "11:40:00 20/01/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160371FAB",
#         "SerialNumber": "24F3190160371FAB",
#         "NomenclatureNode": "1_31_0_1216",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2022-01-15",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.39877,
#         "Longitude": -100.26656,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/8d75ba2b11e6ad2ce3b4a148ce97eb4c.wav": {
#             "Battery": "4.0V",
#             "Datetime": "21:40:00 27/01/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.39877,
#             "Longitude": -100.26656
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/a094671bdbb21285c2b62788afbcb3f2.wav": "2022-01-17",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1216/24F3190160371FAB/2022-01-15/audios/Audible/f13fee43acdb527d720621e8c5f69eba.wav": "2022-02-18"
#     },
#     "DaysBetweenFirstAndLastDate": 32
# }

# %% [markdown]
# ## 248D9B0260371FD2/2021-11-06

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260371FD2' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 84/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-11-18
#
# 2021-12-07
#
#
# nom node: 1_31_0_1217, cum name: 31, date of depl: 2021-11-06, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31268, -100.28287, node category of integrity: Degradado
#
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 81/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-11-15
#
# 2021-11-26
#
# nom node: 1_31_0_1217, cum name: 31, date of depl: 2021-11-06, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31268, -100.28287, node category of integrity: Degradado
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico
#
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 11,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2",
#         "NomenclatureNode": "1_31_0_1217",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-11-06",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31268,
#         "Longitude": -100.28287,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/ba1f875f840c8c0dea9ebe601e4f7cba.wav": {
#             "Battery": "4.6V",
#             "Datetime": "23:20:00 15/11/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371FD2",
#         "SerialNumber": "248D9B0260371FD2",
#         "NomenclatureNode": "1_31_0_1217",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-11-06",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31268,
#         "Longitude": -100.28287,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/cb3adafd3516f079825fa21f45a6bef0.wav": {
#             "Battery": "4.5V",
#             "Datetime": "04:20:00 26/11/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.31268,
#             "Longitude": -100.28287
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/b0abff5245f50acb858520fafed90e6e.wav": "2021-11-15",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/248D9B0260371FD2/2021-11-06/audios/Ultrasonico/878b78a2835bb9897f64be25a8ff23c0.wav": "2021-11-28"
#     },
#     "DaysBetweenFirstAndLastDate": 13
# }

# %% [markdown]
# # 24F31901603734A9/2021-11-06/

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F31901603734A9' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 74/logs_simex_move_files_to_standard_directory.logs
#
# 2021-11-07
#
# 2021-11-22
#
# nom node: 1_31_0_1217, cum name: 31, date of depl: 2021-11-06, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31268, -100.28287, node category of integrity: Degradado
#
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 77/logs_simex_move_files_to_standard_directory.logs
#
# 2021-11-10
#
# 2021-12-02
#
# nom node: 1_31_0_1217, cum name: 31, date of depl: 2021-11-06, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31268, -100.28287, node category of integrity: Degradado
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 79/logs_simex_move_files_to_standard_directory.logs
#
# 2021-11-12
#
# 2021-12-06
#
# nom node: 1_31_0_1217, cum name: 31, date of depl: 2021-11-06, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31268, -100.28287, node category of integrity: Degradado
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible
#
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 24,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F31901603734A9",
#         "SerialNumber": "24F31901603734A9",
#         "NomenclatureNode": "1_31_0_1217",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-11-06",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31268,
#         "Longitude": -100.28287,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/ef8c9d78da78b09881f70c48b2837df7.wav": {
#             "Battery": "4.1V",
#             "Datetime": "01:10:00 05/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F31901603734A9",
#         "SerialNumber": "24F31901603734A9",
#         "NomenclatureNode": "1_31_0_1217",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-11-06",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31268,
#         "Longitude": -100.28287,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/629b1a2a92548999f7dde9f1e144c56f.wav": {
#             "Battery": "4.1V",
#             "Datetime": "01:10:00 01/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.31268,
#             "Longitude": -100.28287
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/d721f7f10068429ac0f58eba60236cc7.wav": "2021-11-19",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_0_1217/24F31901603734A9/2021-11-06/audios/Audible/ac7398e186554d6a8cc9e45b062bc75a.wav": "2021-12-06"
#     },
#     "DaysBetweenFirstAndLastDate": 17
# }

# %% [markdown]
# # 24E1440360371ED3/2021-12-12/

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24E1440360371ED3' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 145/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-11
#
# 2021-12-23
#
# nom node: 1_31_1_1211, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.31772, -100.15701, node category of integrity: Integro
#
#  /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible
#
#  ---
#
#  /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 154/logs_simex_move_files_to_standard_directory.logs
#
#  2021-12-23
#
#  2022-01-13
#
#  nom node: 1_31_1_1211, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31772, -100.15701, node category of integrity: Integro
#
#
#   /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible
#
#  ---
#
#  /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 153/logs_simex_move_files_to_standard_directory.logs
#
#  2021-12-21
#
#  2022-01-12
#
#  nom node: 1_31_1_1211, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.31772, -100.15701, node category of integrity: Integro
#
#  /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible
#
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 22,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360371ED3",
#         "SerialNumber": "24E1440360371ED3",
#         "NomenclatureNode": "1_31_1_1211",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-12-12",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31772,
#         "Longitude": -100.15701,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/401adf21dd750c88f44129d184faf1c0.wav": {
#             "Battery": "3.7V",
#             "Datetime": "06:40:00 01/01/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360371ED3",
#         "SerialNumber": "24E1440360371ED3",
#         "NomenclatureNode": "1_31_1_1211",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-12-12",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.31772,
#         "Longitude": -100.15701,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/7453fa3de5ff2921a885e5fee3b870a7.wav": {
#             "Battery": "3.7V",
#             "Datetime": "14:00:00 30/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.31772,
#             "Longitude": -100.15701
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/f3e15d62aea94b09e6c4e86e0440a675.wav": "2021-12-11",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1211/24E1440360371ED3/2021-12-12/audios/Audible/074f2a6d8a205ec62c17f28043cba58e.wav": "2022-01-07"
#     },
#     "DaysBetweenFirstAndLastDate": 27
# }

# %% [markdown]
# # 242A260460373575/2021-12-12

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '242A260460373575' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 150/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-18
#
# 2022-01-03
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 146/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-13
#
# 2021-12-25
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 148/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-15
#
# 2021-12-29
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 143/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-12-11
#
# 2021-12-20
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 144/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-11
#
# 2021-12-20
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 152/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-20
#
# 2022-01-09
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 137/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-11
#
# 2022-02-09
#
# nom node: 1_31_1_1209, cum name: 31, date of depl: 2021-12-12, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.32408, -100.15482, node category of integrity: Integro
#
#  /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
#  ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible
#
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 60,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 242A260460373575",
#         "SerialNumber": "242A260460373575",
#         "NomenclatureNode": "1_31_1_1209",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-12-12",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.32408,
#         "Longitude": -100.15482,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/a33e097ad9cad6555407b80c2aede8a9.wav": {
#             "Battery": "3.5V",
#             "Datetime": "02:10:00 22/01/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 242A260460373575",
#         "SerialNumber": "242A260460373575",
#         "NomenclatureNode": "1_31_1_1209",
#         "CumulusName": "31",
#         "CentroidCumulusLatitude": 17.36169,
#         "CentroidCumulusLongitude": -100.25274,
#         "DateDeployment": "2021-12-12",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.32408,
#         "Longitude": -100.15482,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/5f9e9030ba625b24c2db4640f7d81e8c.wav": {
#             "Battery": "3.5V",
#             "Datetime": "11:00:00 23/01/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.32408,
#             "Longitude": -100.15482
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/825cadcf91916a0d2f43691399440f3f.wav": "2021-12-12",
#         "/LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1209/242A260460373575/2021-12-12/audios/Audible/95df6b529535b4b38d61e5be9afdcdf6.wav": "2022-01-25"
#     },
#     "DaysBetweenFirstAndLastDate": 44
# }

# %% [markdown]
# # 242A2604603734A9/2021-12-04

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '242A2604603734A9' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 166/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-04
#
# 2022-01-09
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 169/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-12-23
#
# 2021-12-29
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 167/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-12-09
#
# 2021-12-16
#
#  nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 171/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-05
#
# 2022-01-09
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 170/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-29
#
# 2022-01-05
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 168/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-16
#
# 2021-12-23
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
#  /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
#
# ---
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible
#
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 7,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 242A2604603734A9",
#         "SerialNumber": "242A2604603734A9",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.49907,
#         "Longitude": -100.60352,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/7eb5e9fc717dc42f9c2d115d983efcb3.wav": {
#             "Battery": "4.1V",
#             "Datetime": "20:20:00 16/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 242A2604603734A9",
#         "SerialNumber": "242A2604603734A9",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.49907,
#         "Longitude": -100.60352,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/bf29f265b4dd4f222defd8530df49bf3.wav": {
#             "Battery": "3.9V",
#             "Datetime": "05:10:00 01/01/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "FileSize": "5.8 MB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 00:30:00 22/12/2021 (UTC-6) by AudioMoth 242A2604603734A9 at medium gain setting while battery state was 4.0V and temperature was 19.9C.",
#             "Duration": 60.0050833333333,
#             "CentroidCumulusLatitude": 17.57587,
#             "CentroidCumulusLongitude": -100.64479,
#             "Latitude": 17.49907,
#             "Longitude": -100.60352
#         },
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/242A2604603734A9/2021-12-04/audios/Audible/f1173f704718b27dd3b0d8bebabb83d6.wav": {
#             "Battery": "4.1V",
# ...

# %% [markdown]
# # 24F3190160377B16/2021-12-05

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F3190160377B16' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:15:17,482 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135 has serial number 24F3190160377B16
# 2022-07-19 13:15:17,483 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/20220318_232000.WAV has date 2022-03-18
# 2022-07-19 13:15:17,483 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/20220328_055000.WAV has date 2022-03-28
# 2022-07-19 13:15:17,483 [INFO]  DaysBetweenFirstAndLastDate: 10
# 2022-07-19 13:15:17,626 [INFO]  Query to Zendro GQL: query {
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 164/logs_simex_move_files_to_standard_directory.logs
#
#
# 2021-12-26
#
# 2022-01-06
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-05, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.5099, -100.59505, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico
#
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 159/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-05
#
# 2021-12-16
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-05, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.5099, -100.59505, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 11,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B16",
#         "SerialNumber": "24F3190160377B16",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-05",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.5099,
#         "Longitude": -100.59505,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/ff196439d3979686894c256eddb001b3.wav": {
#             "Battery": "4.3V",
#             "Datetime": "01:00:00 06/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B16",
#         "SerialNumber": "24F3190160377B16",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-05",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.5099,
#         "Longitude": -100.59505,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/6e8c6f5a4b4d11862db26b4d3758e387.wav": {
#             "Battery": "4.2V",
#             "Datetime": "22:20:00 30/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.5099,
#             "Longitude": -100.59505
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/587ed692c0a1cbb30e86956849deb370.wav": "2021-12-05",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/24F3190160377B16/2021-12-05/audios/Ultrasonico/096035162558fd100702381ae780d9a9.wav": "2021-12-31"
#     },
#     "DaysBetweenFirstAndLastDate": 26
# }

# %% [markdown]
# # 248D9B0260377D10/2021-12-04/

# %% [markdown]
# **Lets check if there are repeated files in dir `/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/`**

# %%
import os
import glob
import itertools
import pathlib

# %%
def multiple_file_types(input_directory, patterns, recursive=False):
    """
    Return iterable with files that have a common pattern. Will search
    in a recursive or non recursive way.
    Args:
        input_directory (str): directory where files with common pattern
        will be searched.
        patterns (list): list of patterns to search for.
    Returns:
        iterable with files that have a common pattern.
    """
    if recursive:
        expression = "/**/*"
    else:
        expression = "/*"
    return itertools.chain.from_iterable(glob.iglob(input_directory + \
                                                    expression + pattern,
                                                    recursive=recursive) for pattern in patterns)

# %%
patterns = ["WAV", "wav"]

# %%
d = "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/"

# %%
iterable = multiple_file_types(d,patterns, recursive=True)
l_not_repeated = []
l_repeated = []
l_not_repeated_check = []
l_repeated_check = []
for audio_file in iterable:
    audio_file_pathlib = pathlib.Path(audio_file)
    audio_file_no_suffix = audio_file.split(audio_file_pathlib.suffix)[0]
    #audio_filename = audio_file_pathlib.name.split(audio_file_pathlib.suffix)[0]
    if audio_file_no_suffix not in l_not_repeated_check:
        l_not_repeated_check.append(audio_file_no_suffix)
        l_not_repeated.append(audio_file)
    else:
        l_repeated_check.append(audio_file_no_suffix)
        l_repeated.append(audio_file)

# %%
len(l_repeated)
# Out:
# 234

# %%
len(l_not_repeated)
# Out:
# 1296

# %%
l_repeated[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/3c4c03e38e37692560622151e7303a79.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/5142732140e5073cc25ca4d9c4912702.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/a517a5054e7c8e51a8f06597141fb1e7.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/5643ffcbd1cd846a1b7abf4698f7bb59.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/741af7f1f3416288eac7ccfdc188de68.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/f4fb1b1e0e6235aa11dda0e34a5a0f92.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/d76c3653cec19ede37c8945b86660fa0.wav',
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/"
# ls "$d"|grep "3c4c03e38e37692560622151e7303a79"
# Out:
# 3c4c03e38e37692560622151e7303a79.WAV
# 3c4c03e38e37692560622151e7303a79.wav

# %%
split_d = d.split("/")
cumulus = split_d[5]
nom_node = split_d[6]
num_serial = split_d[7]
date_dep = split_d[8]
filename_repeated = "".join(["/shared_volume/",
                             "repeated_audio_files_05-08-2022",
                             "_",
                             cumulus,
                             "_",
                             nom_node,
                             "_",
                             num_serial,
                             "_",
                             date_dep,
                             ".txt"])
print(filename_repeated)
with open(filename_repeated, 'a') as dst:
    for audio_file in l_repeated:
        dst.write(audio_file + "\n")
print("-"*40)
# Out:
# /shared_volume/repeated_audio_files_05-08-2022_33_1_33_0_1223_248D9B0260377D10_2021-12-04.txt
# ----------------------------------------

# %%
# %%bash
# wc -l /shared_volume/repeated_audio_files_05-08-2022_33_1_33_0_1223_248D9B0260377D10_2021-12-04.txt
# Out:
# 234 /shared_volume/repeated_audio_files_05-08-2022_33_1_33_0_1223_248D9B0260377D10_2021-12-04.txt

# %%
# %%bash
# head -n 5 /shared_volume/repeated_audio_files_05-08-2022_33_1_33_0_1223_248D9B0260377D10_2021-12-04.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/3c4c03e38e37692560622151e7303a79.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/5142732140e5073cc25ca4d9c4912702.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/a517a5054e7c8e51a8f06597141fb1e7.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/5643ffcbd1cd846a1b7abf4698f7bb59.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/741af7f1f3416288eac7ccfdc188de68.wav

# %% [markdown]
# **Move files in last txt**

# %%
# %%bash
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# txt="/shared_volume/repeated_audio_files_05-08-2022_33_1_33_0_1223_248D9B0260377D10_2021-12-04.txt"
# for f in $(cat "$txt")
#     do
#         mv "$f" "$dst/"
# done

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/"
# ls "$d"|grep "3c4c03e38e37692560622151e7303a79"
# Out:
# 3c4c03e38e37692560622151e7303a79.WAV

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260377D10' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10306554/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-04
#
# 2022-01-09
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 161/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-17
#
# 2021-12-24
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 162/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-20
#
# 2021-12-28
#
# nom node: 1_33_0_1223, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.49907, -100.60352, node category of integrity: Degradado
#
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico
#
# ---
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 8,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260377D10",
#         "SerialNumber": "248D9B0260377D10",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.49907,
#         "Longitude": -100.60352,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/2797b19d1d08a71373cba4c4c886a8b0.wav": {
#             "Battery": "4.3V",
#             "Datetime": "04:40:00 22/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260377D10",
#         "SerialNumber": "248D9B0260377D10",
#         "NomenclatureNode": "1_33_0_1223",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.49907,
#         "Longitude": -100.60352,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/f966affe69b1f7f0da098f659fdb5577.WAV": {
#             "Battery": "4.3V",
#             "Datetime": "04:00:00 21/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.49907,
#             "Longitude": -100.60352
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/41a9ada9ab214561a1936d75424bf26c.WAV": "2021-12-04",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1223/248D9B0260377D10/2021-12-04/audios/Ultrasonico/a8d9eeba302c78e80a3e235a66aee2ed.WAV": "2022-01-09"
#     },
#     "DaysBetweenFirstAndLastDate": 36
# }

# %% [markdown]
# # 24F3190160377B48/2022-02-19

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F3190160377B48' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:17:14,278 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349 has serial number 24F3190160377B48
# ...

# %% [markdown]
# **There is a log which have audios that were taken in 78 days!!! why simex didn't produce a warning and thereby will not be moved**

# %% [markdown]
# ## An adaptation to `move` cli will be implemented to take into account MAX_NUMBER_DAYS... now all files that appear in the logs will be moved backed to the dir original

# %% [markdown]
# Dir original:
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/
# ```
#
# Dir destiny:
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/
# ```

# %% [markdown]
# **First from `logs`**
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/logs_simex_move_files_to_standard_directory.logs
# ```
#
# **all files moved will be put in a txt**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/logs_simex_move_files_to_standard_directory.logs"
# grep "with name" "$logs"|cut -d':' -f4|cut -d' ' -f5 > "1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"

# %%
# %%bash
# head -n 10 "1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# b9be642d4c84c1b6d6a12d8bc0270bec.wav
# e818937b66ebc1affee60c564ad34c6c.wav
# 8f62930835d0d43b4e21e23bdafcce27.wav
# 3a6579312ade7d4c203a4830c6b948da.wav
# cdb4ba75e95957d55db25af0832b61ef.wav
# f9697207b4a6a46eca582dad5cc63d70.wav
# c8bec03a5bb392b9158b9c1acc7a8280.wav
# 9155b1227c2b264a00c03f267772d94f.wav
# db722443a9f7eaae51a1f543aa17e307.wav
# 6d9f9bfa1544316aeb7be7753ee956bc.wav

# %%
# %%bash
# tail -n 10 "1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# 27f6ca9692135d97b7836554d6e21c19.wav
# 9a2b8d4f0a8e0527d01df16080ec1443.wav
# 121fb620b9b047991dd6c3752d1d02c8.wav
# b96a7c71458d6154eebdee535361e0e8.wav
# 2f569e157c8024ccfca0b1b840a763c6.wav
# 702f44eb7c24660b840a700e722b8584.wav
# 9e927b086eea9e8c3329f986ec7c4451.wav
# c2115fa3ca3527ec02d81c44447a337a.wav
# 248972d155df720cfee9a673695b3b4c.wav
# 92a89003ec6ae00d1773581280a11bdb.wav

# %%
# %%bash
# wc -l "1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# 1000 1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt

# %% [markdown]
# **Include path where data is and create another .txt**

# %%
# %%bash
# path=/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico
# for f in $(cat "1_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt")
#     do
#         echo "$path/$f" >> "2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
#     done

# %%
# %%bash
# head -n 10 "2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/b9be642d4c84c1b6d6a12d8bc0270bec.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/e818937b66ebc1affee60c564ad34c6c.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/8f62930835d0d43b4e21e23bdafcce27.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/3a6579312ade7d4c203a4830c6b948da.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/cdb4ba75e95957d55db25af0832b61ef.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/f9697207b4a6a46eca582dad5cc63d70.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/c8bec03a5bb392b9158b9c1acc7a8280.wav
# ...

# %%
# %%bash
# tail -n 10 "2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/27f6ca9692135d97b7836554d6e21c19.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/9a2b8d4f0a8e0527d01df16080ec1443.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/121fb620b9b047991dd6c3752d1d02c8.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/b96a7c71458d6154eebdee535361e0e8.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/2f569e157c8024ccfca0b1b840a763c6.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/702f44eb7c24660b840a700e722b8584.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/9e927b086eea9e8c3329f986ec7c4451.wav
# ...

# %%
# %%bash
# wc -l "2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt"
# Out:
# 1000 2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt

# %% [markdown]
# **Each file from last txt will be moved to `/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/`**

# %%
#%%bash
#dst_dir="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/"
#for f in $(cat "2_audio_files_33_1_33_1_1219_24F3190160377B48_2022-02-19.txt")
#    do
#    mv "$f" "$dst_dir"
#done

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 5/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-13
#
# 2022-03-24
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 78,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B48",
#         "SerialNumber": "24F3190160377B48",
#         "NomenclatureNode": "1_33_1_1219",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-19",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.65949,
#         "Longitude": -100.70323,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/b9be642d4c84c1b6d6a12d8bc0270bec.wav": {
#             "Battery": "4.0V",
#             "Datetime": "04:20:00 18/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B48",
#         "SerialNumber": "24F3190160377B48",
#         "NomenclatureNode": "1_33_1_1219",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-19",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.65949,
#         "Longitude": -100.70323,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/831c90d19d502eccc9b6f801bfa55322.wav": {
#             "Battery": "4.3V",
#             "Datetime": "21:00:00 13/03/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.65949,
#             "Longitude": -100.70323
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/831c90d19d502eccc9b6f801bfa55322.wav": "2022-03-13",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico/3808097a585ad2dd0540bbc13141a93c.wav": "2022-03-18"
#     },
#     "DaysBetweenFirstAndLastDate": 5
# }

# %% [markdown]
# # 248D9B0260371F78/2022-02-19/

# %% [markdown]
# **Lets check if there are repeated files in dir `/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/`**

# %%
import os
import glob
import itertools
import pathlib

# %%
def multiple_file_types(input_directory, patterns, recursive=False):
    """
    Return iterable with files that have a common pattern. Will search
    in a recursive or non recursive way.
    Args:
        input_directory (str): directory where files with common pattern
        will be searched.
        patterns (list): list of patterns to search for.
    Returns:
        iterable with files that have a common pattern.
    """
    if recursive:
        expression = "/**/*"
    else:
        expression = "/*"
    return itertools.chain.from_iterable(glob.iglob(input_directory + \
                                                    expression + pattern,
                                                    recursive=recursive) for pattern in patterns)

# %%
patterns = ["WAV", "wav"]

# %%
d = "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/"

# %%
iterable = multiple_file_types(d,patterns, recursive=True)
l_not_repeated = []
l_repeated = []
l_not_repeated_check = []
l_repeated_check = []
for audio_file in iterable:
    audio_file_pathlib = pathlib.Path(audio_file)
    audio_file_no_suffix = audio_file.split(audio_file_pathlib.suffix)[0]
    #audio_filename = audio_file_pathlib.name.split(audio_file_pathlib.suffix)[0]
    if audio_file_no_suffix not in l_not_repeated_check:
        l_not_repeated_check.append(audio_file_no_suffix)
        l_not_repeated.append(audio_file)
    else:
        l_repeated_check.append(audio_file_no_suffix)
        l_repeated.append(audio_file)

# %%
len(l_repeated)
# Out:
# 2727

# %%
len(l_not_repeated)
# Out:
# 4026

# %%
l_repeated[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/6c68d190181e987c49f8ffa774fcde0e.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/dcc56b07d36b92fb8c52023dd3e26b7c.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/90c96f161fae7229c85fd806e4406594.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/cfc76089fd8b162bcd842dd66fbd4d99.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/dd10338bb86e6548a66960a122c2f450.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/fb1d5c38acbef844629aeb23b412544a.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/0d0f3ca8d391ad3d62013e455f52a329.wav',
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/"
# ls "$d"|grep "6c68d190181e987c49f8ffa774fcde0e"
# Out:
# 6c68d190181e987c49f8ffa774fcde0e.WAV
# 6c68d190181e987c49f8ffa774fcde0e.wav

# %%
split_d = d.split("/")
cumulus = split_d[5]
nom_node = split_d[6]
num_serial = split_d[7]
date_dep = split_d[8]
filename_repeated = "".join(["/shared_volume/",
                             "repeated_audio_files_05-08-2022",
                             "_",
                             cumulus,
                             "_",
                             nom_node,
                             "_",
                             num_serial,
                             "_",
                             date_dep,
                             ".txt"])
print(filename_repeated)
with open(filename_repeated, 'a') as dst:
    for audio_file in l_repeated:
        dst.write(audio_file + "\n")
print("-"*40)
# Out:
# /shared_volume/repeated_audio_files_05-08-2022_33_1_33_1_1219_248D9B0260371F78_2022-02-19.txt
# ----------------------------------------

# %%
# %%bash
# wc -l /shared_volume/repeated_audio_files_05-08-2022_33_1_33_1_1219_248D9B0260371F78_2022-02-19.txt
# Out:
# 2727 /shared_volume/repeated_audio_files_05-08-2022_33_1_33_1_1219_248D9B0260371F78_2022-02-19.txt

# %%
# %%bash
# head -n 5 /shared_volume/repeated_audio_files_05-08-2022_33_1_33_1_1219_248D9B0260371F78_2022-02-19.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/6c68d190181e987c49f8ffa774fcde0e.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/dcc56b07d36b92fb8c52023dd3e26b7c.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/90c96f161fae7229c85fd806e4406594.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/cfc76089fd8b162bcd842dd66fbd4d99.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/dd10338bb86e6548a66960a122c2f450.wav

# %% [markdown]
# **Move files in last txt**

# %%
# %%bash
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# txt="/shared_volume/repeated_audio_files_05-08-2022_33_1_33_1_1219_248D9B0260371F78_2022-02-19.txt"
# for f in $(cat "$txt")
#     do
#         mv "$f" "$dst/"
# done

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/"
# ls "$d"|grep "6c68d190181e987c49f8ffa774fcde0e"
# Out:
# 6c68d190181e987c49f8ffa774fcde0e.WAV

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260371F78' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:17:13,659 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497 has serial number 248D9B0260371F78
# 2022-07-19 13:17:13,660 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/20220208_172000.WAV has date 2022-02-08
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost350627/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-19
#
# 2022-03-29
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost325016/10305349/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-05
#
# 2022-03-19
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-22
#
# 2022-03-22
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 2/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-26
#
# 2022-03-26
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 104/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-15
#
# 2022-02-22
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 4/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-08
#
# 2022-03-20
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 3/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-03
#
# 2022-03-28
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 6/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-18
#
# 2022-03-28
#
# nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
#
#  /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 10,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371F78",
#         "SerialNumber": "248D9B0260371F78",
#         "NomenclatureNode": "1_33_1_1219",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-19",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.65949,
#         "Longitude": -100.70323,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/7bf958a2f650c86a34926e4abb27594d.wav": {
#             "Battery": "4.0V",
#             "Datetime": "06:10:00 25/03/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371F78",
#         "SerialNumber": "248D9B0260371F78",
#         "NomenclatureNode": "1_33_1_1219",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-19",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.65949,
#         "Longitude": -100.70323,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/1d259589d83941630933b8239bd11c77.WAV": {
#             "Battery": "3.9V",
#             "Datetime": "06:00:00 29/03/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*05-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/Audible_simex_metadata_files_and_device_05-08-2022.json
#             "Latitude": 17.65949,
#             "Longitude": -100.70323
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/d9da0f42d70c11d394ab34b4d9ca8b3c.wav": "2022-02-12",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/248D9B0260371F78/2022-02-19/audios/Audible/d795fe70c18506626170c72d8ae3f874.WAV": "2022-03-29"
#     },
#     "DaysBetweenFirstAndLastDate": 45
# }

# %% [markdown]
# # 24E1440360374A34/2022-01-10

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_33_1.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24E1440360374A34' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10305352/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10305583/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10307444/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10306502/logs_simex_move_files_to_standard_directory.logs
# 2022-07-18 10:15:31,659 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10306502 has serial number 24E1440360374A34
# 2022-07-18 10:15:31,660 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10306502/20220110_224000.WAV has date 2022-01-10
# ...

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24E1440360374A34' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ...

# %%
# %%bash
# ls /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible|wc -l
# Out:
# 3475

# %% [markdown]
# **There are 2 logs which have audios that were taken in 117, 141 days!!! why simex didn't produce a warning and thereby will not be moved**

# %% [markdown]
# ## An adaptation to `move` cli will be implemented to take into account MAX_NUMBER_DAYS... now all files that appear in the logs will be moved backed to the dir original

# %% [markdown]
# Dir original:
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/
# ```
#
# Dir destiny:
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
# ```

# %% [markdown]
# **First from `logs`**
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/logs_simex_move_files_to_standard_directory.logs
# ```
#
# **all files moved will be put in a txt**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/logs_simex_move_files_to_standard_directory.logs"
# grep "with name" "$logs"|cut -d':' -f4|cut -d' ' -f5 > "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"

# %%
# %%bash
# head -n 10 "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 80cadc8755d99be6f797cee3cfac5240.WAV
# ace1bfe5f32a256d1d19e8cb80c5b4b4.WAV
# e8dcc7785abe16445432a1cb495aa402.WAV
# 366cdd92e9d6b134cd30f61b63b1c6a8.WAV
# 4b2acb9a463379080c2983f6bdb6ce30.WAV
# 0bda868d64c67d4f784f613481ffb170.WAV
# 6da219a952d66498028165b00137ea89.WAV
# 92d9d7ac8a4277c5c573b9a7549b5019.WAV
# 19510b888e0cc23ff05def9d5fd8c775.WAV
# 3b13a3bbe6dfbbadee9c1e8454135ef6.WAV

# %%
# %%bash
# tail -n 10 "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 6ac99191ea74e7fb66dead9b7a2715d9.WAV
# 45b8b2f649afbacf85c4fc78b51920c0.WAV
# 4a242ee98ec47658bd4bd378fbc23b22.WAV
# 8d9157da239c941e2f7e09c0658ee736.WAV
# c09f50f467907589e60ae78648b45f1d.WAV
# a6feef5ad54fd7d4d72c89e54be68cc2.WAV
# f72cf08dfa313e9e02d7f8d4a23255e3.WAV
# 510bfeddb2346ef1b5120c4a64122da2.WAV
# 20ad80e135ed8423a68052ee6ebcffe3.WAV
# 8d7653b71c4f8cf622b4704c48bf9f8b.WAV

# %%
# %%bash
# wc -l "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 3307 1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt

# %% [markdown]
# **Include path where data is and create another .txt**

# %%
# %%bash
# path=/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
# for f in $(cat "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt")
#     do
#         echo "$path/$f" >> "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
#     done

# %%
# %%bash
# head -n 10 "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/80cadc8755d99be6f797cee3cfac5240.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/ace1bfe5f32a256d1d19e8cb80c5b4b4.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/e8dcc7785abe16445432a1cb495aa402.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/366cdd92e9d6b134cd30f61b63b1c6a8.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/4b2acb9a463379080c2983f6bdb6ce30.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/0bda868d64c67d4f784f613481ffb170.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/6da219a952d66498028165b00137ea89.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/92d9d7ac8a4277c5c573b9a7549b5019.WAV
# ...

# %%
# %%bash
# tail -n 10 "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/6ac99191ea74e7fb66dead9b7a2715d9.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/45b8b2f649afbacf85c4fc78b51920c0.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/4a242ee98ec47658bd4bd378fbc23b22.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/8d9157da239c941e2f7e09c0658ee736.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/c09f50f467907589e60ae78648b45f1d.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/a6feef5ad54fd7d4d72c89e54be68cc2.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/f72cf08dfa313e9e02d7f8d4a23255e3.WAV
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/510bfeddb2346ef1b5120c4a64122da2.WAV
# ...

# %%
# %%bash
# wc -l "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 3307 2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt

# %% [markdown]
# **Each file from last txt will be moved to `/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/`**

# %%
#%%bash
#dst_dir="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/"
#for f in $(cat "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt")
#    do
#    mv "$f" "$dst_dir"
#done

# %%
# %%bash
# ls /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible|wc -l
# Out:
# 1428

# %% [markdown]
# Dir original:
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/
# ```
#
# Dir destiny:
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
# ```

# %% [markdown]
# **First from `logs`**
#
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/logs_simex_move_files_to_standard_directory.logs
# ```
#
# **all files moved will be put in a txt**

# %%
# %%bash
# ls "/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/"|wc -l
# Out:
# 5

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/logs_simex_move_files_to_standard_directory.logs"
# grep "with name" "$logs"|cut -d':' -f4|cut -d' ' -f5 > "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"

# %%
# %%bash
# head -n 10 "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 7b0bc5520a566b03fd368964a3a16564.wav
# 1d2108c69ccd3b94246defc2fa1b5d57.wav
# afc27b58333279971eec25951d10dba2.wav
# 14e9629ed0fdf9b985439c2e11a0f478.wav
# 02cf883ada85e779b9d670fa6cf640f7.wav
# 97ba6e1a5523944682d19e9550491ada.wav
# 74ed0eea8ded90d71e92f1a0212efe23.wav
# 6e66222cb8912e13ad3d167d7803482c.wav
# c737aad434a5146efad74a5229d3044e.wav
# 8a4f9f51ffec73862846516c0f7d6657.wav

# %%
# %%bash
# tail -n 10 "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 42ff87b3674176c8b0b5a6b24a01b47a.wav
# 131f6b96f384b52d3d2e254b3ac19a87.wav
# 47ee16a4cbbec4157a9b0354940770e7.wav
# 37cb864e8cedcefc44a0e6c3e5c64c95.wav
# 1c59713a6a391012e805fc4e372c3a84.wav
# 11540c13791e98c320e08b25253afff0.wav
# e268bfa6859b822d207efccf7c3237f9.wav
# bfd9560628dd1fc003d88872b846cfd9.wav
# 66b467387d10b3292c4b6bc219f8c687.wav
# 2d29f375748bbc6fa09eff1bf233f769.wav

# %%
# %%bash
# wc -l "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 624 1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt

# %% [markdown]
# **Include path where data is and create another .txt**

# %%
# %%bash
# rm "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"

# %%
# %%bash
# path=/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
# for f in $(cat "1_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt")
#     do
#         echo "$path/$f" >> "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
#     done

# %%
# %%bash
# head -n 10 "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/7b0bc5520a566b03fd368964a3a16564.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/1d2108c69ccd3b94246defc2fa1b5d57.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/afc27b58333279971eec25951d10dba2.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/14e9629ed0fdf9b985439c2e11a0f478.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/02cf883ada85e779b9d670fa6cf640f7.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/97ba6e1a5523944682d19e9550491ada.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/74ed0eea8ded90d71e92f1a0212efe23.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/6e66222cb8912e13ad3d167d7803482c.wav
# ...

# %%
# %%bash
# tail -n 10 "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/42ff87b3674176c8b0b5a6b24a01b47a.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/131f6b96f384b52d3d2e254b3ac19a87.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/47ee16a4cbbec4157a9b0354940770e7.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/37cb864e8cedcefc44a0e6c3e5c64c95.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/1c59713a6a391012e805fc4e372c3a84.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/11540c13791e98c320e08b25253afff0.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/e268bfa6859b822d207efccf7c3237f9.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/bfd9560628dd1fc003d88872b846cfd9.wav
# ...

# %%
# %%bash
# wc -l "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt"
# Out:
# 624 2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt

# %% [markdown]
# **Each file from last txt will be moved to `/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/`**

# %%
#%%bash
#dst_dir="/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/"
#for f in $(cat "2_audio_files_33_1_33_0_1224_24E1440360374A34_2022-01-10.txt")
#    do
#    mv "$f" "$dst_dir"
#done

# %%
# %%bash
# ls /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible|wc -l
# Out:
# 1242

# %%
# %%bash
# ls "/LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/"|wc -l
# Out:
# 191

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/cumulo_33/1_33_0_1224/10306502/logs_simex_move_files_to_standard_directory.logs
#
# 2022-01-10
#
# 2022-01-19
#
# node: 1_33_0_1224, cum name: 33, date of depl: 2022-01-10, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.54693, -100.63046, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 157/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-04
#
# 2022-01-13
#
# nom node: 1_33_0_1224, cum name: 33, date of depl: 2022-01-10, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.54693, -100.63046, node category of integrity: Degradado
#
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 141,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360374A34",
#         "SerialNumber": "24E1440360374A34",
#         "NomenclatureNode": "1_33_0_1224",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-01-10",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.54693,
#         "Longitude": -100.63046,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/7b0bc5520a566b03fd368964a3a16564.wav": {
#             "Battery": "3.2V",
#             "Datetime": "21:00:00 24/04/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24E1440360374A34",
#         "SerialNumber": "24E1440360374A34",
#         "NomenclatureNode": "1_33_0_1224",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-01-10",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.54693,
#         "Longitude": -100.63046,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/9ab99846ba55abd5a7c12409f811302e.WAV": {
#             "Battery": "3.4V",
#             "Datetime": "05:20:00 12/01/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
#             "Latitude": 17.54693,
#             "Longitude": -100.63046
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/8fa0558bfb74523a1addf9d6cb6ad641.wav": "2021-12-04",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible/cd0acc9bdd22301a13a4f843f0bc9d37.WAV": "2022-01-19"
#     },
#     "DaysBetweenFirstAndLastDate": 46
# }

# %% [markdown]
# # 248D9B0260371F78/2021-12-04

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260371F78' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:17:13,659 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497 has serial number 248D9B0260371F78
# 2022-07-19 13:17:13,660 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/20220208_172000.WAV has date 2022-02-08
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 10/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-03
#
# 2021-12-18
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.57816, -100.51826, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 12/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-04
#
# 2021-12-23
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.57816, -100.51826, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 8/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-04
#
# 2021-12-16
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.57816, -100.51826, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible
#
# ---
#
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 12,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371F78",
#         "SerialNumber": "248D9B0260371F78",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.57816,
#         "Longitude": -100.51826,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/950cca88199119badf5727ee44845200.wav": {
#             "Battery": "4.1V",
#             "Datetime": "15:20:00 16/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260371F78",
#         "SerialNumber": "248D9B0260371F78",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.57816,
#         "Longitude": -100.51826,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/aadf1557b7a06152d12e5f24e83f7d23.wav": {
#             "Battery": "4.2V",
#             "Datetime": "15:20:00 08/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
#             "Latitude": 17.57816,
#             "Longitude": -100.51826
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/b45b412a36817f784c044608dc0e840c.wav": "2021-12-06",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260371F78/2021-12-04/audios/Audible/8c607bac2ecb54017511e6b7bca44276.wav": "2021-12-23"
#     },
#     "DaysBetweenFirstAndLastDate": 17
# }

# %% [markdown]
# # 248D9B0260372F15/2021-12-04

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '248D9B0260372F15' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4033497/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10305349/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost461305/10307495/logs_simex_move_files_to_standard_directory.logs
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 9/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-03
#
# 2021-12-17
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 17/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-11
#
# 2022-01-09
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 13/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-05
#
# 2022-01-01
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 16/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-10
#
# 2022-01-05
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 15/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-07
#
# 2022-01-01
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 11/logs_simex_move_files_to_standard_directory.logs
#
# 2021-12-03
#
# 2021-12-20
#
# nom node: 1_33_1_1222, cum name: 33, date of depl: 2021-12-04, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.58421, -100.52076, node category of integrity: Integro
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
#
# ---
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 17,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260372F15",
#         "SerialNumber": "248D9B0260372F15",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.58421,
#         "Longitude": -100.52076,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/372089be7f8877cb0464121398dc211b.wav": {
#             "Battery": "4.2V",
#             "Datetime": "19:10:00 12/12/2021 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 248D9B0260372F15",
#         "SerialNumber": "248D9B0260372F15",
#         "NomenclatureNode": "1_33_1_1222",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2021-12-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.58421,
#         "Longitude": -100.52076,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/ca1b54dc32b91aa297f69d13a2e11c73.wav": {
#             "Battery": "4.1V",
#             "Datetime": "20:30:00 20/12/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
#             "Latitude": 17.58421,
#             "Longitude": -100.52076
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/d7cd1e462bd970e71a2352e4a8354e56.wav": "2021-12-07",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1222/248D9B0260372F15/2021-12-04/audios/Audible/e47bb0c4551c31f9b825d70e59a7ba30.wav": "2022-01-09"
#     },
#     "DaysBetweenFirstAndLastDate": 33
# }

# %% [markdown]
# # 24F3190160377B16/2022-02-17

# %% [markdown]
# **Lets check if there are repeated files in dir `/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/`**

# %%
import os
import glob
import itertools
import pathlib

# %%
def multiple_file_types(input_directory, patterns, recursive=False):
    """
    Return iterable with files that have a common pattern. Will search
    in a recursive or non recursive way.
    Args:
        input_directory (str): directory where files with common pattern
        will be searched.
        patterns (list): list of patterns to search for.
    Returns:
        iterable with files that have a common pattern.
    """
    if recursive:
        expression = "/**/*"
    else:
        expression = "/*"
    return itertools.chain.from_iterable(glob.iglob(input_directory + \
                                                    expression + pattern,
                                                    recursive=recursive) for pattern in patterns)

# %%
patterns = ["WAV", "wav"]

# %%
d = "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"

# %%
iterable = multiple_file_types(d,patterns, recursive=True)
l_not_repeated = []
l_repeated = []
l_not_repeated_check = []
l_repeated_check = []
for audio_file in iterable:
    audio_file_pathlib = pathlib.Path(audio_file)
    audio_file_no_suffix = audio_file.split(audio_file_pathlib.suffix)[0]
    #audio_filename = audio_file_pathlib.name.split(audio_file_pathlib.suffix)[0]
    if audio_file_no_suffix not in l_not_repeated_check:
        l_not_repeated_check.append(audio_file_no_suffix)
        l_not_repeated.append(audio_file)
    else:
        l_repeated_check.append(audio_file_no_suffix)
        l_repeated.append(audio_file)

# %%
len(l_repeated)
# Out:
# 341

# %%
len(l_not_repeated)
# Out:
# 4220

# %%
l_repeated[0:10]
# Out:
# ['/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/f42d596880fd004b0db29b37d94c312b.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/1bcf90735c09f32a4f1b0c59cd7b0442.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/f015b669b0994d72b062212f65613462.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/6147460670d7ddff3d5ad2eea427e0fd.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/76f0d780811abda78f06e4805cebd3f1.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/5ddb3213e21963defea93605b087476b.wav',
#  '/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/83184427147a0e4f25fc3857116facf2.wav',
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"
# ls "$d"|grep "f42d596880fd004b0db29b37d94c312b"
# Out:
# f42d596880fd004b0db29b37d94c312b.WAV
# f42d596880fd004b0db29b37d94c312b.wav

# %%
split_d = d.split("/")
cumulus = split_d[5]
nom_node = split_d[6]
num_serial = split_d[7]
date_dep = split_d[8]
filename_repeated = "".join(["/shared_volume/",
                             "repeated_audio_files_06-08-2022",
                             "_",
                             cumulus,
                             "_",
                             nom_node,
                             "_",
                             num_serial,
                             "_",
                             date_dep,
                             ".txt"])
print(filename_repeated)
with open(filename_repeated, 'a') as dst:
    for audio_file in l_repeated:
        dst.write(audio_file + "\n")
print("-"*40)
# Out:
# /shared_volume/repeated_audio_files_06-08-2022_33_1_33_0_1226_24F3190160377B16_2022-02-17.txt
# ----------------------------------------

# %%
# %%bash
# wc -l /shared_volume/repeated_audio_files_06-08-2022_33_1_33_0_1226_24F3190160377B16_2022-02-17.txt
# Out:
# 341 /shared_volume/repeated_audio_files_06-08-2022_33_1_33_0_1226_24F3190160377B16_2022-02-17.txt

# %%
# %%bash
# head -n 5 /shared_volume/repeated_audio_files_06-08-2022_33_1_33_0_1226_24F3190160377B16_2022-02-17.txt
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/f42d596880fd004b0db29b37d94c312b.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/1bcf90735c09f32a4f1b0c59cd7b0442.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/f015b669b0994d72b062212f65613462.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/6147460670d7ddff3d5ad2eea427e0fd.wav
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/76f0d780811abda78f06e4805cebd3f1.wav

# %% [markdown]
# **Move files in last txt**

# %%
# %%bash
# dst="/LUSTRE/sacmod/SIPECAM/sipecam_files_simex_error"
# txt="/shared_volume/repeated_audio_files_06-08-2022_33_1_33_0_1226_24F3190160377B16_2022-02-17.txt"
# for f in $(cat "$txt")
#     do
#         mv "$f" "$dst/"
# done

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"
# ls "$d"|grep "f42d596880fd004b0db29b37d94c312b"
# Out:
# f42d596880fd004b0db29b37d94c312b.WAV

# %% [markdown]
# **Check json of `move`cli**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_18-07-2022_cumulus_31_33.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     logs=$(find "$dir_to_be_processed" -maxdepth 1 -name "logs_simex_move_files*.logs")
#     echo "$logs"
#     var=$(cat "$logs"|grep '24F3190160377B16' | head -n 1)
#     if [ -z "$var" ]
#     then
#           echo "serial number not found"
#     else
#           cat "$logs"|head -n 70
#     fi
#     echo "----------------------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1611644/logs_simex_move_files_to_standard_directory.logs
# serial number not found
# ----------------------------
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:15:17,482 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135 has serial number 24F3190160377B16
# 2022-07-19 13:15:17,483 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/20220318_232000.WAV has date 2022-03-18
# 2022-07-19 13:15:17,483 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/20220328_055000.WAV has date 2022-03-28
# 2022-07-19 13:15:17,483 [INFO]  DaysBetweenFirstAndLastDate: 10
# 2022-07-19 13:15:17,626 [INFO]  Query to Zendro GQL: query {
# ...

# %% [markdown]
# **Dates of deployment and coordinates of different directories are mapped to same dir**

# %% [markdown]
# ```
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4283135/logs_simex_move_files_to_standard_directory.logs
#
# 2022-03-18
#
# 2022-03-28
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
#  /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 112/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-19
#
# 2022-03-22
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
#  /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 110/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-16
#
# 2022-03-17
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 106/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-18
#
# 2022-03-04
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
#  /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 109/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-16
#
# 2022-03-15
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 108/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-16
#
# 2022-03-11
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 105/logs_simex_move_files_to_standard_directory.logs
#
# 2022-02-16
#
# 2022-02-27
#
# nom node: 1_33_0_1226, cum name: 33, date of depl: 2022-02-17, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.62713, -100.68359, node category of integrity: Degradado
#
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
#
# ---
#
# ```

# %% [markdown]
# ## Rerun `extract` with hardcoding info

# %% [markdown]
# **Check `json` under dir:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible
# ```

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible"
# json=$(find "$d" -maxdepth 1 -name "*.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/Audible_simex_metadata_files_and_device_19-07-2022.json
# {
#     "DaysBetweenFirstAndLastDate": 11,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B16",
#         "SerialNumber": "24F3190160377B16",
#         "NomenclatureNode": "1_33_0_1226",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-17",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.62713,
#         "Longitude": -100.68359,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/a3ce337e880607857659ba559cbcb6e5.wav": {
#             "Battery": "4.4V",
#             "Datetime": "04:20:00 23/02/2022 (UTC-0600)",
#             "Gain": "medium",
# ...

# %% [markdown]
# **Extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|head -n 60
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 24F3190160377B16",
#         "SerialNumber": "24F3190160377B16",
#         "NomenclatureNode": "1_33_0_1226",
#         "CumulusName": "33",
#         "CentroidCumulusLatitude": 17.57587,
#         "CentroidCumulusLongitude": -100.64479,
#         "DateDeployment": "2022-02-17",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 17.62713,
#         "Longitude": -100.68359,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/f69de8a4a4e8585d0d2b9595f4732393.WAV": {
#             "Battery": "3.9V",
#             "Datetime": "14:30:00 25/03/2022 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/"
# json=$(find "$d" -maxdepth 1 -name "*06-08-2022.json")
# echo "$json"
# python3 -mjson.tool "$json"|tail -n 10
# Out:
# /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/Audible_simex_metadata_files_and_device_06-08-2022.json
#             "Latitude": 17.62713,
#             "Longitude": -100.68359
#         }
#     },
#     "FirstAndLastDate": {
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/e844ec1b1a331be149acf5beb2c0cd49.wav": "2022-02-22",
#         "/LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1226/24F3190160377B16/2022-02-17/audios/Audible/a703a7d6a40cf6c06a2f8fbcf2f9385a.WAV": "2022-03-28"
#     },
#     "DaysBetweenFirstAndLastDate": 34
# }

# %% [markdown]
# **Include in revision ipynb (the one I gave to Mariana) and in `directories_not_processed_by_simex` next dir:**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:44:55,146 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782 has serial number 248D9B0260371FD2
# 2022-07-19 13:44:55,147 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/20211107_210000.WAV has date 2021-11-07
# 2022-07-19 13:44:55,147 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/20220501_054000.WAV has date 2022-05-01
# 2022-07-19 13:44:55,147 [INFO]  DaysBetweenFirstAndLastDate: 175
# 2022-07-19 13:44:55,300 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM248D9B0260371FD2", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-11-07", valueType: String, operator: gte}, {field: date_deployment, value: "2022-05-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-19 13:44:55,300 [INFO]  SUCCESSFUL extraction of nomenclature of node, cumulus name and date of deployment
# 2022-07-19 13:44:55,300 [INFO]  directory /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782 has nom node: 1_31_1_1213, cum name: 31, date of depl: 2022-02-22, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.46268, -100.19501, node category of integrity: Integro
# 2022-07-19 13:44:55,300 [INFO]  compute centroid of cumulus
# 2022-07-19 13:44:55,301 [INFO]  Centroid of cumulus, lat: 17.36169, long: -100.25274
# 2022-07-19 13:44:55,301 [INFO]  Validating lat and long of device are correct using lat long of cumulus centroid
# 2022-07-19 13:44:55,302 [INFO]  Latitude and Longitude of device are in cumulus geometry
# 2022-07-19 13:44:55,302 [INFO]  filling dict MetadataDevice using query results from Zendro
# 2022-07-19 13:44:55,302 [INFO]  path where files will be moved: /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22
# 2022-07-19 13:44:55,415 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost1008782/20220315_021000 2.WAV will be moved to: /LUSTRE/sacmod/SIPECAM/data/31/1_31_1_1213/248D9B0260371FD2/2022-02-22/audios/Audible with name f08b1f1c4d0b7080cd9a3d7733fe72c1.WAV
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 15:46:35,668 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14 has serial number 24F3190160377B48
# 2022-07-19 15:46:35,670 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/0.30-6144-013174.wav has date 2021-12-06
# 2022-07-19 15:46:35,670 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/0.30-6144-013192.wav has date 2022-02-22
# 2022-07-19 15:46:35,670 [INFO]  DaysBetweenFirstAndLastDate: 78
# 2022-07-19 15:46:35,837 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24F3190160377B48", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-06", valueType: String, operator: gte}, {field: date_deployment, value: "2022-02-22", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-19 15:46:35,838 [INFO]  SUCCESSFUL extraction of nomenclature of node, cumulus name and date of deployment
# 2022-07-19 15:46:35,838 [INFO]  directory /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14 has nom node: 1_33_1_1219, cum name: 33, date of depl: 2022-02-19, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.65949, -100.70323, node category of integrity: Integro
# 2022-07-19 15:46:35,838 [INFO]  compute centroid of cumulus
# 2022-07-19 15:46:35,839 [INFO]  Centroid of cumulus, lat: 17.57587, long: -100.64479
# 2022-07-19 15:46:35,839 [INFO]  Validating lat and long of device are correct using lat long of cumulus centroid
# 2022-07-19 15:46:35,839 [INFO]  Latitude and Longitude of device are in cumulus geometry
# 2022-07-19 15:46:35,840 [INFO]  filling dict MetadataDevice using query results from Zendro
# 2022-07-19 15:46:35,840 [INFO]  path where files will be moved: /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19
# 2022-07-19 15:46:36,118 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 14/0.30-6144-013819.wav will be moved to: /LUSTRE/sacmod/SIPECAM/data/33/1_33_1_1219/24F3190160377B48/2022-02-19/audios/Ultrasonico with name b9be642d4c84c1b6d6a12d8bc0270bec.wav
#
#
# ---
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 13:23:51,016 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352 has serial number 24E1440360374A34
# 2022-07-19 13:23:51,018 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/20211205_202000.WAV has date 2021-12-05
# 2022-07-19 13:23:51,018 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/20220401_034000.WAV has date 2022-04-01
# 2022-07-19 13:23:51,018 [INFO]  DaysBetweenFirstAndLastDate: 117
# 2022-07-19 13:23:51,173 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E1440360374A34", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-05", valueType: String, operator: gte}, {field: date_deployment, value: "2022-04-01", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-19 13:23:51,174 [INFO]  SUCCESSFUL extraction of nomenclature of node, cumulus name and date of deployment
# 2022-07-19 13:23:51,174 [INFO]  directory /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352 has nom node: 1_33_0_1224, cum name: 33, date of depl: 2022-01-10, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.54693, -100.63046, node category of integrity: Degradado
# 2022-07-19 13:23:51,174 [INFO]  compute centroid of cumulus
# 2022-07-19 13:23:51,175 [INFO]  Centroid of cumulus, lat: 17.57587, long: -100.64479
# 2022-07-19 13:23:51,175 [INFO]  Validating lat and long of device are correct using lat long of cumulus centroid
# 2022-07-19 13:23:51,176 [INFO]  Latitude and Longitude of device are in cumulus geometry
# 2022-07-19 13:23:51,176 [INFO]  filling dict MetadataDevice using query results from Zendro
# 2022-07-19 13:23:51,176 [INFO]  path where files will be moved: /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10
# 2022-07-19 13:23:51,287 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Orphans/Lost4078250/10305352/20220328_102000.WAV will be moved to: /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible with name 80cadc8755d99be6f797cee3cfac5240.WAV
#
#
# ---
#
#
# /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/logs_simex_move_files_to_standard_directory.logs
# 2022-07-19 15:37:46,632 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130 has serial number 24E1440360374A34
# 2022-07-19 15:37:46,634 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/0.30-6144-129448.wav has date 2021-12-06
# 2022-07-19 15:37:46,634 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/0.30-6144-129431.wav has date 2022-04-26
# 2022-07-19 15:37:46,634 [INFO]  DaysBetweenFirstAndLastDate: 141
# 2022-07-19 15:37:46,789 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: comments, value: "ADM24E1440360374A34", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-12-06", valueType: String, operator: gte}, {field: date_deployment, value: "2022-04-26", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
#         cat_integr
#         ecosystems {
#           name
#         }
#       }
#       cumulus {
#         name
#         geometry
#       }
#       date_deployment
#       latitude
#       longitude
#     }
#   }
# }
# 2022-07-19 15:37:46,789 [INFO]  SUCCESSFUL extraction of nomenclature of node, cumulus name and date of deployment
# 2022-07-19 15:37:46,789 [INFO]  directory /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130 has nom node: 1_33_0_1224, cum name: 33, date of depl: 2022-01-10, ecosystems name: Bosques templados,                          latitude and longitude of device:  17.54693, -100.63046, node category of integrity: Degradado
# 2022-07-19 15:37:46,789 [INFO]  compute centroid of cumulus
# 2022-07-19 15:37:46,790 [INFO]  Centroid of cumulus, lat: 17.57587, long: -100.64479
# 2022-07-19 15:37:46,790 [INFO]  Validating lat and long of device are correct using lat long of cumulus centroid
# 2022-07-19 15:37:46,791 [INFO]  Latitude and Longitude of device are in cumulus geometry
# 2022-07-19 15:37:46,791 [INFO]  filling dict MetadataDevice using query results from Zendro
# 2022-07-19 15:37:46,791 [INFO]  path where files will be moved: /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10
# 2022-07-19 15:37:46,865 [INFO]  File /LUSTRE/sacmod/SIPECAM/entrega.09.Junio.2022/Cumulos_33_y_31/RESPALDO/Reconstructed labeled/Audio/wav/Group 130/1.00-768-129140.wav will be moved to: /LUSTRE/sacmod/SIPECAM/data/33/1_33_0_1224/24E1440360374A34/2022-01-10/audios/Audible with name 7b0bc5520a566b03fd368964a3a16564.wav
#
# ```

# %% [markdown]
# **Update dir /LUSTRE/sacmod/SIPECAM/data/files_moved_with_simex/ (delete all txt and create only one with all files)**
