# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of all images and videos

# %% [markdown]
# Which json is the one related to this json?

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep '"DaysBetweenFirstAndLastDate": \b1\b'
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/10263609_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/10261149_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012/10262012_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/AudioMoths.N5.T4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %%
# %%bash
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048480/" > check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_0_1400 VILLAROSA/HLPXGM09048448/100RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/4/DCIM/100RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/" >> check_simex_error.txt
# echo "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX/" >> check_simex_error.txt

# %%
# %%bash
# input_file="check_simex_error.txt"
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for d in $(cat "$input_file")
#     do
#     json=$(find "$d" -name "*json*")
#     echo "$json"
#     python3 -mjson.tool "$json"|head -n 50
#     echo "------------"
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048480/HLPXGM09048480_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048480"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1396 LA LEONA/HLPXGM09048480/RCNX0001.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2022:02:07 09:52:28",
#             "SerialNumber": "HLPXGM09048480",
#             "FileSize": "18 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 800,
#             "ImageHeight": 600,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
# ...

# %% [markdown]
# **Reference dir**

# %% [markdown]
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 400 "$logs"
# Out:
# 2022-06-10 12:27:23,582 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX has serial number HLPXGM09049504
# 2022-06-10 12:27:23,583 [INFO]  tuple index out of range
# 2022-06-10 12:27:23,583 [INFO]  couldn't retrieve second_date_str possibly related to only one file taken by device
# 2022-06-10 12:27:23,583 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/RCNX0001.JPG has date 2021-10-30
# 2022-06-10 12:27:23,583 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/RCNX0001.JPG only was taken in one date and date 2021-10-31 will be used for query
# 2022-06-10 12:27:23,583 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:27:23,729 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049504", operator: like}) {
# ...

# %% [markdown]
# **Only one file was moved... then possibly it was overwritten json file**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# grep ".*_0001.JPG" "$logs"
# Out:
# 2022-06-10 12:27:24,013 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/103RECNX/RCNX0001.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos with name 7dc31fa8a4556b0330fa5f4a9301742f_0001.JPG

# %% [markdown]
# **Json file with info from dir with only one file**

# %%
# %%bash
# python3 -mjson.tool "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 1,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049504",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3020238,
#         "Longitude": -91.7482815,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/7dc31fa8a4556b0330fa5f4a9301742f_0001.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:30 13:08:27",
#             "SerialNumber": "HLPXGM09049504",
#             "FileSize": "19 KiB",
# ...

# %% [markdown]
# **Don't know what is happening... this next has the same metadata**

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/102RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|head -n 50
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049504"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:11 01:21:09",
#             "SerialNumber": "HLPXGM09049504",
#             "FileSize": "214 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/102RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|tail -n 50
# Out:
#             "GPSLatitudeRef": "North",
#             "GPSLongitudeRef": "West",
#             "GPSLatitude": 18.3005,
#             "GPSLongitude": -91.7207,
#             "SerialNumber": "HLPXGM09049504"
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/RCNX1431.AVI": {
#             "BitRate": "4.9 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
#             "VideoCompression": "Motion JPEG DIB (fourcc:\"MJPG\")",
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "3.0 MiB",
#             "DateTimeOriginal": "2021:10:29 19:02:20",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
# ...

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# grep ".*_0001.JPG" "$logs"
# Out:
# 2022-06-10 12:26:28,230 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/RCNX0001.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos with name 085c4f50e2f8d32ef4b9b6e17036113d_0001.JPG

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 40 "$logs"
# Out:
# 2022-06-10 12:26:01,881 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX has serial number HLPXGM09049504
# 2022-06-10 12:26:01,882 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/RCNX0004.JPG has date 2021-10-09
# 2022-06-10 12:26:01,882 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/1/DCIM/102RECNX/RCNX1431.AVI has date 2021-10-29
# 2022-06-10 12:26:01,882 [INFO]  DaysBetweenFirstAndLastDate: 20
# 2022-06-10 12:26:02,017 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049504", operator: like}) {
# ...

# %% [markdown]
# **¿Why there are two 0001?**

# %%
# %%bash
# ls -lh "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos" |grep ".*0001.*"
# Out:
# -rwxrwxrwx 1 1108 1100  540K Oct  9  2021 085c4f50e2f8d32ef4b9b6e17036113d_0001.JPG
# -rwxrwxrwx 1 1108 1100   20K Oct 30  2021 7dc31fa8a4556b0330fa5f4a9301742f_0001.JPG

# %%
# %%bash
# ls -lh "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos" |grep ".*0002.*"
# Out:
# -rwxrwxrwx 1 1108 1100  501K Oct  9  2021 f518cdbd8a08e40e51923bca9656f82e_0002.JPG

# %% [markdown]
# **Sólo debería haber un número:**

# %%
# %%bash
# ls -lh "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos" |grep ".*0049.*"
# Out:
# -rwxrwxrwx 1 1108 1100  215K Oct 11  2021 342faa94c81674d970f7b16c652932b2_0049.JPG

# %% [markdown]
# **Will delete:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/7dc31fa8a4556b0330fa5f4a9301742f_0001.JPG
# ```
#
# from
#
# ```
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos
# ```

# %% [markdown]
# **And use next info to create new json:**
#
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049504",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3005,
#         "Longitude": -91.7207,
#         "NodeCategoryIntegrity": "Integro"
#     }
# ```

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/7dc31fa8a4556b0330fa5f4a9301742f_0001.JPG

# %% [markdown]
# **Will modify locally `extract` cli of `simex` with only the new info that need to be added to `MetadataDevice` dict and each image and video**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 6

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049504",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3005,
#         "Longitude": -91.7207,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/c2d0eea4248921755d6672fa27d97d9e_2356.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:29 22:07:17",
#             "SerialNumber": "HLPXGM09049504",
#             "FileSize": "297 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "3.0 MB",
#             "DateTimeOriginal": "2021:10:29 19:45:22",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "5.12 s",
#             "MaxDataRate": 26542080,
# ...

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/"
# file_for_logs=$(find "$dir_to_be_processed" -name "logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs")
# tail -n 50 "$file_for_logs"
# Out:
# 2022-06-22 11:36:55,945 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/ca6cc061eecc0050c481a2c24f62d902_0720.AVI
# 2022-06-22 11:36:55,945 [INFO]  SUCCESSFUL extraction of date of /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/ca6cc061eecc0050c481a2c24f62d902_0720.AVI
# 2022-06-22 11:36:55,946 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/4d4f878f4df8bd8f3ea80bbb8a21e64b_0036.AVI
# 2022-06-22 11:36:55,946 [INFO]  SUCCESSFUL extraction of date of /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/4d4f878f4df8bd8f3ea80bbb8a21e64b_0036.AVI
# 2022-06-22 11:36:55,946 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/56608e630f1f6e7a51467e1e9c985ba6_0048.AVI
# ...

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of all images and videos

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 48,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049093",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3053674,
#         "Longitude": -91.7580359,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/1b216bbaa31a9b87f2e17ea1012f4823_0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:19 13:34:18",
#             "SerialNumber": "HLPXGM09049093",
#             "FileSize": "892 KiB",
# ...

# %% [markdown]
# **Which json is the one related to this json?, will use different technique as at the beginning of this nbook**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep 'HLPXGM09049093' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/10263609_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/10261149_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012/10262012_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/AudioMoths.N5.T4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's see if MICRO SD AURA will again be the one that did something with the cameras...**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 300 "$f"
# Out:
# 2022-06-10 12:27:29,786 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX has serial number HLPXGM09049093
# 2022-06-10 12:27:29,788 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX/RCNX0002.JPG has date 2021-10-09
# 2022-06-10 12:27:29,788 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/102RECNX/RCNX0003.AVI has date 2021-10-09
# 2022-06-10 12:27:29,788 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:27:29,922 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049093", operator: like}) {
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 100 "$f"
# Out:
# 2022-06-10 12:27:30,563 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX has serial number HLPXGM09049093
# 2022-06-10 12:27:30,564 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX/RCNX0004.JPG has date 2021-10-09
# 2022-06-10 12:27:30,564 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX/RCNX0312.AVI has date 2021-11-26
# 2022-06-10 12:27:30,564 [INFO]  DaysBetweenFirstAndLastDate: 48
# 2022-06-10 12:27:30,703 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049093", operator: like}) {
# ...

# %% [markdown]
# **It appears that it's the same problem as the first one**

# %% [markdown]
# **Let's review the *\*_0001.JPG*, *\*_0002.JPG*, *\*_0003.AVI* files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos"
# ls "$d" | grep ".*_0001.*"
# Out:
# 823bfbb128e9aba942c6a7968e780c88_0001.JPG
# bb8228955a82dd6a0eb79fda4374fb83_0001.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos"
# ls "$d" | grep ".*_0002.*"
# Out:
# 3c19811619f4cbed786b2d3d34fa0857_0002.JPG
# 4f849ed150c5bd57a8136e30cdcb92c6_0002.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos"
# ls "$d" | grep ".*_0003.*"
# Out:
# 5f92892db58711f3944780352a3e3f35_0003.AVI
# 5f92892db58711f3944780352a3e3f35_0003.mp4
# 5f92892db58711f3944780352a3e3f35_0003.webm
# 945241a1cc203774b3560f8160d5e184_0003.AVI
# 945241a1cc203774b3560f8160d5e184_0003.mp4
# 945241a1cc203774b3560f8160d5e184_0003.webm

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos"
# ls "$d" | grep ".*_0004.*"
# Out:
# 320d46805748a9dc0968ce9ec8abaa19_0004.JPG

# %%
# %%bash
# cp "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/3c19811619f4cbed786b2d3d34fa0857_0002.JPG" "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"
# cp "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/bb8228955a82dd6a0eb79fda4374fb83_0001.JPG" "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"
# cp "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/945241a1cc203774b3560f8160d5e184_0003.AVI" "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"

# %% [markdown]
# **Will delete this files from `data` dir**

# %%
# %%bash
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/3c19811619f4cbed786b2d3d34fa0857_0002.JPG"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/bb8228955a82dd6a0eb79fda4374fb83_0001.JPG"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/945241a1cc203774b3560f8160d5e184_0003.AVI"

# %% [markdown]
# **Also:**

# %%
# %%bash
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/945241a1cc203774b3560f8160d5e184_0003.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/945241a1cc203774b3560f8160d5e184_0003.webm"

# %% [markdown]
# **Check which data will be the one to be included in new json file**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$f" |head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 48,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049093",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3053674,
#         "Longitude": -91.7580359,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/1b216bbaa31a9b87f2e17ea1012f4823_0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:19 13:34:18",
#             "SerialNumber": "HLPXGM09049093",
#             "FileSize": "892 KiB",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX/103RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049093"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/3/DCIM/103RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:19 13:34:18",
#             "SerialNumber": "HLPXGM09049093",
#             "FileSize": "892 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %% [markdown]
# **Info that will be included**

# %% [markdown]
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049093",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.2951,
#         "Longitude": -91.7196,
#         "NodeCategoryIntegrity": "Integro"
#     }
# ```

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049093",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.2951,
#         "Longitude": -91.7196,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/fc1e7c22331f75162950989f898abe82_0196.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:18 15:14:27",
#             "SerialNumber": "HLPXGM09049093",
#             "FileSize": "878 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "26 MB",
#             "DateTimeOriginal": "2021:11:18 15:13:47",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 164,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "13.12 s",
#             "MaxDataRate": 26542080,
# ...

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of all images and videos

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 1,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3078397,
#         "Longitude": -91.7554607,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/a7b1af397cc181f7ad6a500c55bd69b3_0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 13:03:46",
#             "SerialNumber": "HLPXGM09049482",
#             "FileSize": "168 KiB",
# ...

# %% [markdown]
# **Which json is the one related to this json?, will use different technique as at the beginning of this nbook**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep 'HLPXGM09049482' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/10263609_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/10261149_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012/10262012_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/AudioMoths.N5.T4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's see if MICRO SD AURA will again be the one that did something with the cameras...**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/logs_simex_move_files_to_standard_directory.logs"
# head -n 300 "$f"
# Out:
# 2022-06-10 12:24:16,314 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa has serial number HLPXGM09049482
# 2022-06-10 12:24:16,316 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/RCNX3649.JPG has date 2021-08-23
# 2022-06-10 12:24:16,316 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/NODO 3_13_1_1393/2/Cámara-trampa/RCNX4019.JPG has date 2021-09-26
# 2022-06-10 12:24:16,316 [INFO]  DaysBetweenFirstAndLastDate: 34
# 2022-06-10 12:24:16,454 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 100 "$f"
# Out:
# 2022-06-10 12:25:49,840 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX has serial number HLPXGM09049482
# 2022-06-10 12:25:49,841 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/RCNX0004.JPG has date 2021-10-09
# 2022-06-10 12:25:49,841 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/RCNX0186.AVI has date 2021-11-26
# 2022-06-10 12:25:49,842 [INFO]  DaysBetweenFirstAndLastDate: 48
# 2022-06-10 12:25:50,002 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 300 "$f"
# Out:
# 2022-06-10 12:25:59,685 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX has serial number HLPXGM09049482
# 2022-06-10 12:25:59,686 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0004.JPG has date 2021-10-09
# 2022-06-10 12:25:59,686 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0024.AVI has date 2021-10-09
# 2022-06-10 12:25:59,686 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:25:59,827 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09049482", operator: like}) {
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"
# Out:
# 2022-06-10 12:26:00,116 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0004.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name a7b1af397cc181f7ad6a500c55bd69b3_0004.JPG
# 2022-06-10 12:26:00,143 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0029.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 0ce0fdc18cda8d143e44577d0359ec04_0029.JPG
# 2022-06-10 12:26:00,178 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0011.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 940162b01a2a7e3f47d155a7afe02fa4_0011.JPG
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"
# Out:
# 2022-06-10 12:26:00,781 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0012.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 2e162eccae2ad4ac67ca4454fdabf6cb_0012.AVI
# 2022-06-10 12:26:00,886 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0009.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name c07264cd67cb5e869a05f1ca5fdc5707_0009.AVI
# 2022-06-10 12:26:00,988 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/103RECNX/RCNX0027.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 131d73741fd00069c4a816dada8b7311_0027.AVI
# ...

# %% [markdown]
# **It appears that it's the same problem as the first one**

# %% [markdown]
# **Let's review the files**

# %%
# %%bash
# echo "_0004.JPG" > check_simex_error.txt
# echo "_0029.JPG" >> check_simex_error.txt
# echo "_0011.JPG" >> check_simex_error.txt
# echo "_0022.JPG" >> check_simex_error.txt
# echo "_0019.JPG" >> check_simex_error.txt
# echo "_0025.JPG" >> check_simex_error.txt
# echo "_0013.JPG" >> check_simex_error.txt
# echo "_0028.JPG" >> check_simex_error.txt
# echo "_0023.JPG" >> check_simex_error.txt
# echo "_0014.JPG" >> check_simex_error.txt
# echo "_0026.JPG" >> check_simex_error.txt
# echo "_0005.JPG" >> check_simex_error.txt
# echo "_0016.JPG" >> check_simex_error.txt
# echo "_0008.JPG" >> check_simex_error.txt
# echo "_0010.JPG" >> check_simex_error.txt
# echo "_0007.JPG" >> check_simex_error.txt
# echo "_0002.JPG" >> check_simex_error.txt
# echo "_0020.JPG" >> check_simex_error.txt
# echo "_0001.JPG" >> check_simex_error.txt
# echo "_0017.JPG" >> check_simex_error.txt
# echo "_0012.AVI" >> check_simex_error.txt
# echo "_0009.AVI" >> check_simex_error.txt
# echo "_0027.AVI" >> check_simex_error.txt
# echo "_0003.AVI" >> check_simex_error.txt
# echo "_0006.AVI" >> check_simex_error.txt
# echo "_0018.AVI" >> check_simex_error.txt
# echo "_0015.AVI" >> check_simex_error.txt
# echo "_0021.AVI" >> check_simex_error.txt
# echo "_0024.AVI" >> check_simex_error.txt

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*.$regexp.*"
#     echo "----------------"
# done
# Out:
# a5cca210f3edce6e3f23f92340920daf_0004.JPG
# a7b1af397cc181f7ad6a500c55bd69b3_0004.JPG
# ----------------
# 0ce0fdc18cda8d143e44577d0359ec04_0029.JPG
# 1b5126e3b967759ba92d1487ee375982_0029.JPG
# ----------------
# 940162b01a2a7e3f47d155a7afe02fa4_0011.JPG
# eb19c3d207245b411d8ca93fcbf4474c_0011.JPG
# ----------------
# 73793bb98ab7f32bf04141f45862915e_0022.JPG
# aa599a1cf2c75bdbe3b41136fbbe1389_0022.JPG
# ----------------
# d44d56f8c45cdce753446e3132102079_0019.JPG
# f931e2036bcb22de83167044f737b851_0019.JPG
# ----------------
# 3b223f2a00f20a294d3e57fd31c00873_0025.JPG
# 90c6f725208b3f59f857c52678cad834_0025.JPG
# ----------------
# 04d5a84feeed6983f94a2003fe06ee9d_0013.JPG
# 49242a6d33d13ff5a17a3fb7f02ddd6f_0013.JPG
# ----------------
# 011d05bc9312801aac10f0986bb978e7_0028.JPG
# f64cb4ddd5e65e4d66f2d6dbaabd2aa7_0028.JPG
# ----------------
# 9cd316b8dbbe0c4fa02427cba5a4c4e5_0023.JPG
# e44a7feec27d2e1948638a8e10986f75_0023.JPG
# ----------------
# ...

# %%
# %%bash
# echo "a7b1af397cc181f7ad6a500c55bd69b3_0004.JPG" > check_simex_error.txt
# echo "0ce0fdc18cda8d143e44577d0359ec04_0029.JPG" >> check_simex_error.txt
# echo "940162b01a2a7e3f47d155a7afe02fa4_0011.JPG" >> check_simex_error.txt
# echo "aa599a1cf2c75bdbe3b41136fbbe1389_0022.JPG" >> check_simex_error.txt
# echo "d44d56f8c45cdce753446e3132102079_0019.JPG" >> check_simex_error.txt
# echo "3b223f2a00f20a294d3e57fd31c00873_0025.JPG" >> check_simex_error.txt
# echo "04d5a84feeed6983f94a2003fe06ee9d_0013.JPG" >> check_simex_error.txt
# echo "f64cb4ddd5e65e4d66f2d6dbaabd2aa7_0028.JPG" >> check_simex_error.txt
# echo "9cd316b8dbbe0c4fa02427cba5a4c4e5_0023.JPG" >> check_simex_error.txt
# echo "54ea9282f3f72396e236a8701e9dadd8_0014.JPG" >> check_simex_error.txt
# echo "719533e1f64fd5ee387500973128ad6c_0026.JPG" >> check_simex_error.txt
# echo "40226b4ce230eab96c19b56010d14fee_0005.JPG" >> check_simex_error.txt
# echo "f54f54806577548338d6fde71eb68cdb_0016.JPG" >> check_simex_error.txt
# echo "905039341e97f61d70d31ee99112b433_0008.JPG" >> check_simex_error.txt
# echo "30d4b2cb4a2ca13cd5261cb640ec3128_0010.JPG" >> check_simex_error.txt
# echo "74a0e8456859afdf6ea1a492f13b67de_0007.JPG" >> check_simex_error.txt
# echo "5e14a39ed2f65599effcbb1144375a1e_0002.JPG" >> check_simex_error.txt
# echo "66645d54687ad686e067d399369fe231_0020.JPG" >> check_simex_error.txt
# echo "b9d1c74aa162451961a62fa6fb8599fe_0001.JPG" >> check_simex_error.txt
# echo "bbcf6b9bf27eb1a94c465886c52368d7_0017.JPG" >> check_simex_error.txt
# echo "2e162eccae2ad4ac67ca4454fdabf6cb_0012.AVI" >> check_simex_error.txt
# echo "c07264cd67cb5e869a05f1ca5fdc5707_0009.AVI" >> check_simex_error.txt
# echo "131d73741fd00069c4a816dada8b7311_0027.AVI" >> check_simex_error.txt
# echo "970e4afda6f2660b5e9658ef5cd1fa5b_0003.AVI" >> check_simex_error.txt
# echo "fc55d7c8dfe2e72a4e9444dc29751844_0006.AVI" >> check_simex_error.txt
# echo "aca8210a4234fccfc3f067e6041d21ff_0018.AVI" >> check_simex_error.txt
# echo "71e1f53f2db3b953fac4e2d9098e9799_0015.AVI" >> check_simex_error.txt
# echo "a74666ec6a57b1de2fca227f11369fa1_0021.AVI" >> check_simex_error.txt
# echo "249f1b3ff5bbb986e6798f26aa0ca591_0024.AVI" >> check_simex_error.txt

# %%
# %%bash
# dest="/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"
#
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos"
# for f in $(cat check_simex_error.txt)
#     do
#     cp "$d/$f" "$dest"
# done

# %% [markdown]
# **Will delete this files from `data` dir**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos"
# for f in $(cat check_simex_error.txt)
#     do
#     rm "$d/$f"
# done

# %% [markdown]
# **Also delete:**

# %%
# %%bash
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/2e162eccae2ad4ac67ca4454fdabf6cb_0012.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/c07264cd67cb5e869a05f1ca5fdc5707_0009.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/131d73741fd00069c4a816dada8b7311_0027.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/970e4afda6f2660b5e9658ef5cd1fa5b_0003.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/fc55d7c8dfe2e72a4e9444dc29751844_0006.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/aca8210a4234fccfc3f067e6041d21ff_0018.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/71e1f53f2db3b953fac4e2d9098e9799_0015.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/a74666ec6a57b1de2fca227f11369fa1_0021.mp4"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/249f1b3ff5bbb986e6798f26aa0ca591_0024.mp4"
#
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/2e162eccae2ad4ac67ca4454fdabf6cb_0012.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/c07264cd67cb5e869a05f1ca5fdc5707_0009.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/131d73741fd00069c4a816dada8b7311_0027.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/970e4afda6f2660b5e9658ef5cd1fa5b_0003.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/fc55d7c8dfe2e72a4e9444dc29751844_0006.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/aca8210a4234fccfc3f067e6041d21ff_0018.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/71e1f53f2db3b953fac4e2d9098e9799_0015.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/a74666ec6a57b1de2fca227f11369fa1_0021.webm"
# rm "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/249f1b3ff5bbb986e6798f26aa0ca591_0024.webm"

# %% [markdown]
# **Check which data will be the one to be included in new json file**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$f" |head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 1,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3078397,
#         "Longitude": -91.7554607,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/a7b1af397cc181f7ad6a500c55bd69b3_0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 13:03:46",
#             "SerialNumber": "HLPXGM09049482",
#             "FileSize": "168 KiB",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/104RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:01 11:29:21",
#             "SerialNumber": "HLPXGM09049482",
#             "FileSize": "746 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/104RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |tail -n 100
# Out:
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "5.12 s",
#             "MaxDataRate": 26542080,
#             "Megapixels": 0.73728,
#             "GPSLatitudeRef": "North",
#             "GPSLongitudeRef": "West",
#             "GPSLatitude": 18.3079,
#             "GPSLongitude": -91.7189,
#             "SerialNumber": "HLPXGM09049482"
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/6/DCIM/104RECNX/RCNX0057.AVI": {
#             "BitRate": "15.4 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
# ...

# %% [markdown]
# **Info that will be included**

# %% [markdown]
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3079,
#         "Longitude": -91.7189,
#         "NodeCategoryIntegrity": "Integro"
#     }
# ```

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3079,
#         "Longitude": -91.7189,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/4286c05184e3a11de0eedca410619200_0059.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:11:01 15:21:09",
#             "SerialNumber": "HLPXGM09049482",
#             "FileSize": "802 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "15 MB",
#             "DateTimeOriginal": "2021:11:18 08:43:36",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 97,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "7.76 s",
#             "MaxDataRate": 26542080,
# ...

# %% [markdown]
# **Let's see if the dir**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs`
#
# **has the same problem**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"
# Out:
# 2022-06-10 12:22:54,842 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0049.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 386e1bbd9d062485202987cf576e121f_0049.JPG
# 2022-06-10 12:22:54,852 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0130.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 35dc835a34230638350fddd4dbf07b2c_0130.JPG
# 2022-06-10 12:22:54,862 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0127.JPG will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name e878fd693c9ec969a3d25179be732941_0127.JPG
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"
# Out:
# 2022-06-10 12:22:57,745 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0012.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name e16cadcc65b37ccc57ac0727cbffb36a_0012.AVI
# 2022-06-10 12:22:57,788 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0138.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name c4ab0cf8fd0f3876730270a902e81b34_0138.AVI
# 2022-06-10 12:22:57,845 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/RCNX0009.AVI will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos with name 5c0256a53fb260ecba6dbda677c46d47_0009.AVI
# ...

# %% [markdown]
# **Lets review the files**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0130.JPG
# _0127.JPG
# _0122.JPG
# _0079.JPG
# _0055.JPG
# _0004.JPG
# _0082.JPG
# _0098.JPG
# _0062.JPG
# _0154.JPG
# _0125.JPG
# _0029.JPG
# _0067.JPG
# _0115.JPG
# _0065.JPG
# _0068.JPG
# _0164.JPG
# _0053.JPG
# _0158.JPG
# _0113.JPG
# _0173.JPG
# _0170.JPG
# _0040.JPG
# _0119.JPG
# _0046.JPG
# _0109.JPG
# _0011.JPG
# _0085.JPG
# _0121.JPG
# _0076.JPG
# _0022.JPG
# _0019.JPG
# _0188.JPG
# _0025.JPG
# _0083.JPG
# _0124.JPG
# _0043.JPG
# _0136.JPG
# _0080.JPG
# _0140.JPG
# _0092.JPG
# _0160.JPG
# _0013.JPG
# _0149.JPG
# _0151.JPG
# _0148.JPG
# _0058.JPG
# _0071.JPG
# _0172.JPG
# _0028.JPG
# _0023.JPG
# _0166.JPG
# _0059.JPG
# _0152.JPG
# _0155.JPG
# _0091.JPG
# _0194.JPG
# _0070.JPG
# _0097.JPG
# _0061.JPG
# _0145.JPG
# _0014.JPG
# _0184.JPG
# _0031.JPG
# _0131.JPG
# _0104.JPG
# _0179.JPG
# _0175.JPG
# _0134.JPG
# _0026.JPG
# _0077.JPG
# _0005.JPG
# _0035.JPG
# _0110.JPG
# _0181.JPG
# _0178.JPG
# _0133.JPG
# _0146.JPG
# _0167.JPG
# _0112.JPG
# _0016.JPG
# _0089.JPG
# ...

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error_names.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name \(.*.JPG\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# cat check_simex_error_names.txt
# Out:
# 386e1bbd9d062485202987cf576e121f_0049.JPG
# 35dc835a34230638350fddd4dbf07b2c_0130.JPG
# e878fd693c9ec969a3d25179be732941_0127.JPG
# e38672641558b19d99674dca62ad496f_0122.JPG
# 6dadb5abfd29ff4c4ca5ec6a3454ffbc_0079.JPG
# 28da5676e03df3292b73ef294e5629ee_0055.JPG
# a5cca210f3edce6e3f23f92340920daf_0004.JPG
# 364b2fc459181c7445f9d2601176a5f1_0082.JPG
# 238678e5308d39da3b5fe785e6c4b34f_0098.JPG
# 8a025c640da3d0b3f0cefa0619de4331_0062.JPG
# 32166fade2da8ab0c635fecd7eb1674b_0154.JPG
# 6469290a2c46c9613274eb2b71ae2406_0125.JPG
# 1b5126e3b967759ba92d1487ee375982_0029.JPG
# 846c94c65f73889f59be64895b33003c_0067.JPG
# d4d96fe95955f74c0f0e434ab90dc876_0115.JPG
# 1b179a8871c0f640fb73f1d4b6334dce_0065.JPG
# f8e6f9c8525052f4edf7ce823ac1b58d_0068.JPG
# d2bc02e70d720b217a8a56f0f8231921_0164.JPG
# af05a3b4b3e9400459300fe52e3364b1_0053.JPG
# 1d9bacea7347de1cfcc7b0b85df1d437_0158.JPG
# a495ac847f5a2ae9781a032686ee3f76_0113.JPG
# 9e71796db945b086b26396688321c9df_0173.JPG
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0130.JPG
# _0127.JPG
# _0122.JPG
# _0079.JPG
# _0055.JPG
# _0004.JPG
# _0082.JPG
# _0098.JPG
# _0062.JPG
# _0154.JPG
# _0125.JPG
# _0029.JPG
# _0067.JPG
# _0115.JPG
# _0065.JPG
# _0068.JPG
# _0164.JPG
# _0053.JPG
# _0158.JPG
# _0113.JPG
# _0173.JPG
# _0170.JPG
# _0040.JPG
# _0119.JPG
# _0046.JPG
# _0109.JPG
# _0011.JPG
# _0085.JPG
# _0121.JPG
# _0076.JPG
# _0022.JPG
# _0019.JPG
# _0188.JPG
# _0025.JPG
# _0083.JPG
# _0124.JPG
# _0043.JPG
# _0136.JPG
# _0080.JPG
# _0140.JPG
# _0092.JPG
# _0160.JPG
# _0013.JPG
# _0149.JPG
# _0151.JPG
# _0148.JPG
# _0058.JPG
# _0071.JPG
# _0172.JPG
# _0028.JPG
# _0023.JPG
# _0166.JPG
# _0059.JPG
# _0152.JPG
# _0155.JPG
# _0091.JPG
# _0194.JPG
# _0070.JPG
# _0097.JPG
# _0061.JPG
# _0145.JPG
# _0014.JPG
# _0184.JPG
# _0031.JPG
# _0131.JPG
# _0104.JPG
# _0179.JPG
# _0175.JPG
# _0134.JPG
# _0026.JPG
# _0077.JPG
# _0005.JPG
# _0035.JPG
# _0110.JPG
# _0181.JPG
# _0178.JPG
# _0133.JPG
# _0146.JPG
# _0167.JPG
# _0112.JPG
# _0016.JPG
# _0089.JPG
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049093/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name \(.*.AVI\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# cat check_simex_error_names.txt
# Out:
# 386e1bbd9d062485202987cf576e121f_0049.JPG
# 35dc835a34230638350fddd4dbf07b2c_0130.JPG
# e878fd693c9ec969a3d25179be732941_0127.JPG
# e38672641558b19d99674dca62ad496f_0122.JPG
# 6dadb5abfd29ff4c4ca5ec6a3454ffbc_0079.JPG
# 28da5676e03df3292b73ef294e5629ee_0055.JPG
# a5cca210f3edce6e3f23f92340920daf_0004.JPG
# 364b2fc459181c7445f9d2601176a5f1_0082.JPG
# 238678e5308d39da3b5fe785e6c4b34f_0098.JPG
# 8a025c640da3d0b3f0cefa0619de4331_0062.JPG
# 32166fade2da8ab0c635fecd7eb1674b_0154.JPG
# 6469290a2c46c9613274eb2b71ae2406_0125.JPG
# 1b5126e3b967759ba92d1487ee375982_0029.JPG
# 846c94c65f73889f59be64895b33003c_0067.JPG
# d4d96fe95955f74c0f0e434ab90dc876_0115.JPG
# 1b179a8871c0f640fb73f1d4b6334dce_0065.JPG
# f8e6f9c8525052f4edf7ce823ac1b58d_0068.JPG
# d2bc02e70d720b217a8a56f0f8231921_0164.JPG
# af05a3b4b3e9400459300fe52e3364b1_0053.JPG
# 1d9bacea7347de1cfcc7b0b85df1d437_0158.JPG
# a495ac847f5a2ae9781a032686ee3f76_0113.JPG
# 9e71796db945b086b26396688321c9df_0173.JPG
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 386e1bbd9d062485202987cf576e121f_0049.JPG
# ----------------
# 35dc835a34230638350fddd4dbf07b2c_0130.JPG
# ----------------
# e878fd693c9ec969a3d25179be732941_0127.JPG
# ----------------
# e38672641558b19d99674dca62ad496f_0122.JPG
# ----------------
# 6dadb5abfd29ff4c4ca5ec6a3454ffbc_0079.JPG
# ----------------
# 28da5676e03df3292b73ef294e5629ee_0055.JPG
# ----------------
# a5cca210f3edce6e3f23f92340920daf_0004.JPG
# ----------------
# 364b2fc459181c7445f9d2601176a5f1_0082.JPG
# ----------------
# 238678e5308d39da3b5fe785e6c4b34f_0098.JPG
# ----------------
# 8a025c640da3d0b3f0cefa0619de4331_0062.JPG
# ----------------
# 32166fade2da8ab0c635fecd7eb1674b_0154.JPG
# ----------------
# 6469290a2c46c9613274eb2b71ae2406_0125.JPG
# ----------------
# 1b5126e3b967759ba92d1487ee375982_0029.JPG
# ----------------
# 846c94c65f73889f59be64895b33003c_0067.JPG
# ----------------
# d4d96fe95955f74c0f0e434ab90dc876_0115.JPG
# ----------------
# 1b179a8871c0f640fb73f1d4b6334dce_0065.JPG
# ...

# %% [markdown]
# **There are no duplicates, then dir was extracted metadata correctly**

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of all images and videos

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 19,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3038663,
#         "Longitude": -91.7537393,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/776541fd710f92cf0c8e86e1b2668fbf_0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:27 08:12:41",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "852 KiB",
# ...

# %% [markdown]
# **Which json is the one related to this json?, will use different technique as at the beginning of this nbook**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep 'HLPXGM09048888' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/10263609_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/10261149_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012/10262012_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/AudioMoths.N5.T4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's review...**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG

# %% [markdown]
# **Other AURA dir**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG

# %% [markdown]
# **Other AURA dir**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG
# _0002.JPG
# _0001.JPG

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG
# _0002.JPG
# _0001.JPG

# %% [markdown]
# **Other AURA dir**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG
# _0002.JPG
# _0001.JPG
# _0049.JPG
# _0055.JPG
# _0004.JPG
# _0029.JPG
# _0053.JPG
# _0040.JPG
# _0046.JPG
# _0011.JPG
# _0022.JPG
# _0019.JPG
# _0025.JPG
# _0043.JPG
# _0013.JPG
# _0028.JPG
# _0023.JPG
# _0014.JPG
# _0031.JPG
# _0026.JPG
# _0005.JPG
# _0035.JPG
# _0016.JPG
# _0037.JPG
# _0056.JPG
# _0032.JPG
# _0038.JPG
# _0008.JPG
# _0047.JPG
# _0050.JPG
# _0052.JPG
# _0010.JPG
# _0044.JPG
# _0007.JPG
# _0002.JPG
# _0041.JPG
# _0020.JPG
# _0001.JPG
# _0017.JPG
# _0034.JPG

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0001.JPG
# _0001.JPG
# _0002.JPG
# _0001.JPG
# _0049.JPG
# _0055.JPG
# _0004.JPG
# _0029.JPG
# _0053.JPG
# _0040.JPG
# _0046.JPG
# _0011.JPG
# _0022.JPG
# _0019.JPG
# _0025.JPG
# _0043.JPG
# _0013.JPG
# _0028.JPG
# _0023.JPG
# _0014.JPG
# _0031.JPG
# _0026.JPG
# _0005.JPG
# _0035.JPG
# _0016.JPG
# _0037.JPG
# _0056.JPG
# _0032.JPG
# _0038.JPG
# _0008.JPG
# _0047.JPG
# _0050.JPG
# _0052.JPG
# _0010.JPG
# _0044.JPG
# _0007.JPG
# _0002.JPG
# _0041.JPG
# _0020.JPG
# _0001.JPG
# _0017.JPG
# _0034.JPG
# _0012.AVI
# _0009.AVI
# _0051.AVI
# _0027.AVI
# _0003.AVI
# _0054.AVI
# _0042.AVI
# _0048.AVI
# _0006.AVI
# _0039.AVI
# _0036.AVI
# _0033.AVI
# _0030.AVI
# _0018.AVI
# _0015.AVI
# _0021.AVI
# _0045.AVI
# _0024.AVI
# _0057.AVI

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 1dcfff6c2514938452ae6433be52c994_0001.JPG
# 7b1e95239ddf9d693377651ed3c26b68_0001.JPG
# 85906799f05abe45c6d52fff50746d62_0001.JPG
# ----------------
# 1dcfff6c2514938452ae6433be52c994_0001.JPG
# 7b1e95239ddf9d693377651ed3c26b68_0001.JPG
# 85906799f05abe45c6d52fff50746d62_0001.JPG
# ----------------
# 3949a3a18a95b8a7756d70599dbe0986_0002.JPG
# 7e22b29c4127584d8bc2ad20c6c982cc_0002.JPG
# ----------------
# 1dcfff6c2514938452ae6433be52c994_0001.JPG
# 7b1e95239ddf9d693377651ed3c26b68_0001.JPG
# 85906799f05abe45c6d52fff50746d62_0001.JPG
# ----------------
# 776541fd710f92cf0c8e86e1b2668fbf_0049.JPG
# ----------------
# 66a85e7e50eee40926100fc679396dd0_0055.JPG
# ----------------
# 71da2c53eddfa15e2e921f507cfd4b90_0004.JPG
# ----------------
# 4c00b45d8844034df76ad520d8931085_0029.JPG
# ----------------
# d7f480d45683bb8a4c277c23dd640c34_0053.JPG
# ----------------
# c412580699a3101221398a5f8c3a8f57_0040.JPG
# ----------------
# 36c26e5e0f6dceea9105d842a78b132f_0046.JPG
# ...

# %% [markdown]
# **Searching files that will be deleted**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"
# Out:
# 2022-06-10 12:27:24,310 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX has serial number HLPXGM09048888
# 2022-06-10 12:27:24,311 [INFO]  tuple index out of range
# 2022-06-10 12:27:24,311 [INFO]  couldn't retrieve second_date_str possibly related to only one file taken by device
# 2022-06-10 12:27:24,311 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/RCNX0001.JPG has date 2021-10-30
# 2022-06-10 12:27:24,311 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/RCNX0001.JPG only was taken in one date and date 2021-10-31 will be used for query
# 2022-06-10 12:27:24,311 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:27:24,449 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048888", operator: like}) {
# ...

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/7b1e95239ddf9d693377651ed3c26b68_0001.JPG`

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"
# Out:
# 2022-06-10 12:27:25,017 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX has serial number HLPXGM09048888
# 2022-06-10 12:27:25,019 [INFO]  tuple index out of range
# 2022-06-10 12:27:25,019 [INFO]  couldn't retrieve second_date_str possibly related to only one file taken by device
# 2022-06-10 12:27:25,019 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/RCNX0001.JPG has date 2021-08-11
# 2022-06-10 12:27:25,019 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/RCNX0001.JPG only was taken in one date and date 2021-08-12 will be used for query
# 2022-06-10 12:27:25,019 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:27:25,159 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048888", operator: like}) {
# ...

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/HLPXGM09048888/2021-08-11/images_videos/194b512961eac3104650b153d89c9c28_0001.JPG`

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"
# Out:
# 2022-06-10 12:27:25,470 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX has serial number HLPXGM09048888
# 2022-06-10 12:27:25,471 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/RCNX0002.JPG has date 2021-10-09
# 2022-06-10 12:27:25,471 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/RCNX0001.JPG has date 2021-10-09
# 2022-06-10 12:27:25,471 [INFO]  DaysBetweenFirstAndLastDate: 1
# 2022-06-10 12:27:25,605 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048888", operator: like}) {
# ...

# %% [markdown]
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/7e22b29c4127584d8bc2ad20c6c982cc_0002.JPG`
#
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/85906799f05abe45c6d52fff50746d62_0001.JPG`

# %% [markdown]
# **Copying files to check that they can be deleted**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/"
# dest="/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"
# cp "$d/7b1e95239ddf9d693377651ed3c26b68_0001.JPG" "$dest"
# cp "$d/194b512961eac3104650b153d89c9c28_0001.JPG" "$dest"
# cp "$d/7e22b29c4127584d8bc2ad20c6c982cc_0002.JPG" "$dest"
# cp "$d/85906799f05abe45c6d52fff50746d62_0001.JPG" "$dest"
# Out:
# cp: cannot stat '/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos//194b512961eac3104650b153d89c9c28_0001.JPG': No such file or directory

# %%
# %%bash
# cp "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/HLPXGM09048888/2021-08-11/images_videos/194b512961eac3104650b153d89c9c28_0001.JPG" "/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/"

# %% [markdown]
# **Will delete this files from `data` dir**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/"
# rm "$d/7b1e95239ddf9d693377651ed3c26b68_0001.JPG"
# rm "$d/7e22b29c4127584d8bc2ad20c6c982cc_0002.JPG"
# rm "$d/85906799f05abe45c6d52fff50746d62_0001.JPG"
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/HLPXGM09048888/2021-08-11/images_videos/"
# rm "$d/194b512961eac3104650b153d89c9c28_0001.JPG"

# %% [markdown]
# **Also file:**
#
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/9a27ef0297032ff35a5d7928c312ee1f_0003.AVI`
#
#
# **will be deleted**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/9a27ef0297032ff35a5d7928c312ee1f_0003.AVI

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/9a27ef0297032ff35a5d7928c312ee1f_0003.mp4

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/9a27ef0297032ff35a5d7928c312ee1f_0003.webm

# %% [markdown]
# **Next dir will be deleted as had only one file**
#
# `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/HLPXGM09048888`

# %% [markdown]
# **Let's see if the dir**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs`
#
# **has the same problem**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1392 NICTEHA 2/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0079.JPG
# _0055.JPG
# _0004.JPG
# _0082.JPG
# _0098.JPG
# _0062.JPG
# _0029.JPG
# _0067.JPG
# _0065.JPG
# _0068.JPG
# _0053.JPG
# _0040.JPG
# _0046.JPG
# _0011.JPG
# _0085.JPG
# _0076.JPG
# _0022.JPG
# _0019.JPG
# _0025.JPG
# _0083.JPG
# _0043.JPG
# _0080.JPG
# _0092.JPG
# _0013.JPG
# _0058.JPG
# _0071.JPG
# _0028.JPG
# _0023.JPG
# _0059.JPG
# _0091.JPG
# _0070.JPG
# _0097.JPG
# _0061.JPG
# _0014.JPG
# _0031.JPG
# _0104.JPG
# _0026.JPG
# _0077.JPG
# _0005.JPG
# _0035.JPG
# _0016.JPG
# _0089.JPG
# _0037.JPG
# _0056.JPG
# _0094.JPG
# _0032.JPG
# _0038.JPG
# _0008.JPG
# _0073.JPG
# _0047.JPG
# _0088.JPG
# _0050.JPG
# _0103.JPG
# _0052.JPG
# _0064.JPG
# _0010.JPG
# _0086.JPG
# _0095.JPG
# _0044.JPG
# _0007.JPG
# _0100.JPG
# _0002.JPG
# _0074.JPG
# _0041.JPG
# _0020.JPG
# _0001.JPG
# _0017.JPG
# _0101.JPG
# _0034.JPG
# _0012.AVI
# _0009.AVI
# _0051.AVI
# _0102.AVI
# _0027.AVI
# _0090.AVI
# _0003.AVI
# _0096.AVI
# _0054.AVI
# _0066.AVI
# _0042.AVI
# _0048.AVI
# _0006.AVI
# ...

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 776541fd710f92cf0c8e86e1b2668fbf_0049.JPG
# ----------------
# ----------------
# 66a85e7e50eee40926100fc679396dd0_0055.JPG
# ----------------
# 71da2c53eddfa15e2e921f507cfd4b90_0004.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# 4c00b45d8844034df76ad520d8931085_0029.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# d7f480d45683bb8a4c277c23dd640c34_0053.JPG
# ----------------
# c412580699a3101221398a5f8c3a8f57_0040.JPG
# ----------------
# 36c26e5e0f6dceea9105d842a78b132f_0046.JPG
# ----------------
# 67055f5620d8c7c7c5e92c6b7fbdba70_0011.JPG
# ----------------
# ----------------
# ----------------
# 302b0cf55be7c824a92b8c2cb7a2d76a_0022.JPG
# ----------------
# e59f6f88b49c27fb78cf8c8fb221e764_0019.JPG
# ----------------
# 0204ea12c981b74c4ab022fd2730c112_0025.JPG
# ----------------
# ----------------
# efc8263c90102eef6b4390c949787267_0043.JPG
# ----------------
# ----------------
# ----------------
# ...

# %% [markdown]
# **Let's see if the dir**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs`
#
# **has the same problem**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1395 SANTA GERTRUDIS/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0079.JPG
# _0055.JPG
# _0004.JPG
# _0082.JPG
# _0098.JPG
# _0062.JPG
# _0029.JPG
# _0067.JPG
# _0065.JPG
# _0068.JPG
# _0053.JPG
# _0040.JPG
# _0046.JPG
# _0011.JPG
# _0085.JPG
# _0076.JPG
# _0022.JPG
# _0019.JPG
# _0025.JPG
# _0083.JPG
# _0043.JPG
# _0080.JPG
# _0092.JPG
# _0013.JPG
# _0058.JPG
# _0071.JPG
# _0028.JPG
# _0023.JPG
# _0059.JPG
# _0091.JPG
# _0070.JPG
# _0097.JPG
# _0061.JPG
# _0014.JPG
# _0031.JPG
# _0026.JPG
# _0077.JPG
# _0005.JPG
# _0035.JPG
# _0016.JPG
# _0089.JPG
# _0037.JPG
# _0056.JPG
# _0094.JPG
# _0032.JPG
# _0038.JPG
# _0008.JPG
# _0073.JPG
# _0047.JPG
# _0088.JPG
# _0050.JPG
# _0052.JPG
# _0064.JPG
# _0010.JPG
# _0086.JPG
# _0095.JPG
# _0044.JPG
# _0007.JPG
# _0002.JPG
# _0074.JPG
# _0041.JPG
# _0020.JPG
# _0001.JPG
# _0017.JPG
# _0034.JPG
# _0012.AVI
# _0009.AVI
# _0051.AVI
# _0027.AVI
# _0090.AVI
# _0003.AVI
# _0096.AVI
# _0054.AVI
# _0066.AVI
# _0042.AVI
# _0048.AVI
# _0006.AVI
# _0072.AVI
# _0084.AVI
# _0069.AVI
# _0039.AVI
# _0081.AVI
# ...

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 776541fd710f92cf0c8e86e1b2668fbf_0049.JPG
# ----------------
# ----------------
# 66a85e7e50eee40926100fc679396dd0_0055.JPG
# ----------------
# 71da2c53eddfa15e2e921f507cfd4b90_0004.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# 4c00b45d8844034df76ad520d8931085_0029.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# d7f480d45683bb8a4c277c23dd640c34_0053.JPG
# ----------------
# c412580699a3101221398a5f8c3a8f57_0040.JPG
# ----------------
# 36c26e5e0f6dceea9105d842a78b132f_0046.JPG
# ----------------
# 67055f5620d8c7c7c5e92c6b7fbdba70_0011.JPG
# ----------------
# ----------------
# ----------------
# 302b0cf55be7c824a92b8c2cb7a2d76a_0022.JPG
# ----------------
# e59f6f88b49c27fb78cf8c8fb221e764_0019.JPG
# ----------------
# 0204ea12c981b74c4ab022fd2730c112_0025.JPG
# ----------------
# ----------------
# efc8263c90102eef6b4390c949787267_0043.JPG
# ----------------
# ----------------
# ----------------
# ...

# %% [markdown]
# **Let's see if the dir**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs`
#
# **has the same problem**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09048888/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0130.JPG
# _0127.JPG
# _0296.JPG
# _0122.JPG
# _0079.JPG
# _0311.JPG
# _0055.JPG
# _0004.JPG
# _0280.JPG
# _0082.JPG
# _0301.JPG
# _0098.JPG
# _0062.JPG
# _0154.JPG
# _0206.JPG
# _0125.JPG
# _0209.JPG
# _0029.JPG
# _0067.JPG
# _0115.JPG
# _0259.JPG
# _0065.JPG
# _0068.JPG
# _0242.JPG
# _0256.JPG
# _0203.JPG
# _0164.JPG
# _0053.JPG
# _0158.JPG
# _0239.JPG
# _0196.JPG
# _0113.JPG
# _0173.JPG
# _0170.JPG
# _0040.JPG
# _0212.JPG
# _0119.JPG
# _0046.JPG
# _0211.JPG
# _0245.JPG
# _0109.JPG
# _0011.JPG
# _0248.JPG
# _0085.JPG
# _0121.JPG
# _0314.JPG
# _0299.JPG
# _0076.JPG
# _0022.JPG
# _0019.JPG
# _0188.JPG
# _0278.JPG
# _0025.JPG
# _0197.JPG
# _0230.JPG
# _0083.JPG
# _0124.JPG
# _0043.JPG
# _0260.JPG
# _0136.JPG
# _0080.JPG
# _0140.JPG
# _0238.JPG
# _0292.JPG
# _0092.JPG
# _0160.JPG
# _0199.JPG
# _0013.JPG
# _0149.JPG
# _0151.JPG
# _0148.JPG
# _0058.JPG
# _0071.JPG
# _0172.JPG
# _0229.JPG
# _0281.JPG
# _0304.JPG
# _0028.JPG
# _0247.JPG
# _0023.JPG
# _0298.JPG
# _0310.JPG
# ...

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 776541fd710f92cf0c8e86e1b2668fbf_0049.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# 66a85e7e50eee40926100fc679396dd0_0055.JPG
# ----------------
# 71da2c53eddfa15e2e921f507cfd4b90_0004.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# 4c00b45d8844034df76ad520d8931085_0029.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# d7f480d45683bb8a4c277c23dd640c34_0053.JPG
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# ----------------
# c412580699a3101221398a5f8c3a8f57_0040.JPG
# ----------------
# ----------------
# ----------------
# ...

# %% [markdown]
# **Let's see if the dir**
#
# `/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS/logs_simex_move_files_to_standard_directory.logs`
#
# **has the same problem**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name .*\(_.*.JPG\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM FOTOS/Nodo 3_13_1_1394 NICTEHA 1/HLPXGM09049482/FOTOS/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name .*\(_.*.AVI\)/\1/;p' >> check_simex_error.txt

# %%
# %%bash
# cat check_simex_error.txt
# Out:
# _0049.JPG
# _0055.JPG
# _0004.JPG
# _0029.JPG
# _0053.JPG
# _0040.JPG
# _0046.JPG
# _0011.JPG
# _0022.JPG
# _0019.JPG
# _0025.JPG
# _0043.JPG
# _0013.JPG
# _0028.JPG
# _0023.JPG
# _0014.JPG
# _0031.JPG
# _0026.JPG
# _0005.JPG
# _0035.JPG
# _0016.JPG
# _0037.JPG
# _0056.JPG
# _0032.JPG
# _0038.JPG
# _0008.JPG
# _0047.JPG
# _0050.JPG
# _0052.JPG
# _0010.JPG
# _0044.JPG
# _0007.JPG
# _0002.JPG
# _0041.JPG
# _0020.JPG
# _0001.JPG
# _0017.JPG
# _0034.JPG
# _0012.AVI
# _0009.AVI
# _0051.AVI
# _0027.AVI
# _0003.AVI
# _0054.AVI
# _0042.AVI
# _0048.AVI
# _0006.AVI
# _0039.AVI
# _0036.AVI
# _0033.AVI
# _0030.AVI
# _0018.AVI
# _0015.AVI
# _0021.AVI
# _0045.AVI
# _0024.AVI
# _0057.AVI

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos"
# for regexp in $(cat check_simex_error.txt)
#     do
#     ls "$d"|grep ".*$regexp.*"
#     echo "----------------"
# done
# Out:
# 776541fd710f92cf0c8e86e1b2668fbf_0049.JPG
# ----------------
# 66a85e7e50eee40926100fc679396dd0_0055.JPG
# ----------------
# 71da2c53eddfa15e2e921f507cfd4b90_0004.JPG
# ----------------
# 4c00b45d8844034df76ad520d8931085_0029.JPG
# ----------------
# d7f480d45683bb8a4c277c23dd640c34_0053.JPG
# ----------------
# c412580699a3101221398a5f8c3a8f57_0040.JPG
# ----------------
# 36c26e5e0f6dceea9105d842a78b132f_0046.JPG
# ----------------
# 67055f5620d8c7c7c5e92c6b7fbdba70_0011.JPG
# ----------------
# 302b0cf55be7c824a92b8c2cb7a2d76a_0022.JPG
# ----------------
# e59f6f88b49c27fb78cf8c8fb221e764_0019.JPG
# ----------------
# 0204ea12c981b74c4ab022fd2730c112_0025.JPG
# ----------------
# efc8263c90102eef6b4390c949787267_0043.JPG
# ----------------
# 45733e0f606a44a95918b818a76bddef_0013.JPG
# ----------------
# a7e2ff753704120988883ce65403ab2d_0028.JPG
# ----------------
# 56b62c82a1291280657f44b6ae2ce923_0023.JPG
# ----------------
# dc9945557db0ae720a5556198cc5ac03_0014.JPG
# ...

# %% [markdown]
# **There are no repeated files**

# %% [markdown]
# **Check which data will be the one to be included in new json file**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$f" |head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 19,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3038663,
#         "Longitude": -91.7537393,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/776541fd710f92cf0c8e86e1b2668fbf_0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:27 08:12:41",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "852 KiB",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/104RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/104RECNX/RCNX0001.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:30 13:20:28",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "18 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 800,
#             "ImageHeight": 600,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/101RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/101RECNX/RCNX0001.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:08:11 13:04:15",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "19 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 800,
#             "ImageHeight": 600,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/102RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/102RECNX/RCNX0002.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:09 13:42:02",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "625 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/103RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |head -n 100
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/RCNX0049.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:27 08:12:41",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "852 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/103RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f" |tail -n 100
# Out:
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "5.12 s",
#             "MaxDataRate": 26542080,
#             "Megapixels": 0.73728,
#             "GPSLatitudeRef": "North",
#             "GPSLongitudeRef": "West",
#             "GPSLatitude": 18.3007,
#             "GPSLongitude": -91.7124,
#             "SerialNumber": "HLPXGM09048888"
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/RESPALDO MICRO SD AURA/CAMARAS/5/DCIM/103RECNX/RCNX0024.AVI": {
#             "BitRate": "16.8 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
# ...

# %% [markdown]
# **Info that will be included**

# %% [markdown]
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09049482",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3079,
#         "Longitude": -91.7189,
#         "NodeCategoryIntegrity": "Integro"
#     }
# ```

# %% [markdown]
# **Running `extract`**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_23-06-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048888",
#         "NomenclatureNode": "3_13_1_1392",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-10-09",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3007,
#         "Longitude": -91.7124,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/51ea970ebff14d8dc472fb368e571cbd_0044.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:13 21:12:45",
#             "SerialNumber": "HLPXGM09048888",
#             "FileSize": "272 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_23-06-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "11 MB",
#             "DateTimeOriginal": "2021:10:09 14:04:36",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 64,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "5.12 s",
#             "MaxDataRate": 26542080,
# ...

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of all images and videos

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_09-05-2022.json"
# python3 -mjson.tool "$j"|head -n 80
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 1,
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048642",
#         "NomenclatureNode": "1_95_0_1348",
#         "CumulusName": "95",
#         "DateDeployment": "2021-08-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 31.26391,
#         "Longitude": -108.95454,
#         "NodeCategoryIntegrity": "Degradado",
#         "CentroidCumulusLatitude": 31.22829,
#         "CentroidCumulusLongitude": -108.85782
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/b80e1585fda73cb6063934c95cf6adb7_0004.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:08:04 10:36:51",
#             "SerialNumber": "HLPXGM09048642",
#             "FileSize": "404 KiB",
# ...

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_09-05-2022.json"
# python3 -mjson.tool "$j"|tail -n 80
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/36134892ee75d0e9e538efaf4af89ae1_7056.AVI": {
#             "BitRate": "14.8 Mbit/sec",
#             "Endianness": "Little endian",
#             "VideoBitsPerPixel": "24",
#             "VideoCompression": "Motion JPEG DIB (fourcc:\"MJPG\")",
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "14 MiB",
#             "DateTimeOriginal": "2021:10:13 14:51:37",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
# ...

# %% [markdown]
# **Which json is the one related to this json?, will use different technique as at the beginning of this nbook**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_16-03-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep 'HLPXGM09048642' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_03/Ultrasonico/Integro/Integro_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_03/Ultrasonico/Degradado/Degradado_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_03/Audible/Integro/Integro_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_03/Audible/Degradado/Degradado_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_01/Ultrasonico/Integro/Integro_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Audios/nodo01/grabadora_01/Ultrasonico/Degradado/Degradado_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's review...**

# %% [markdown]
# **Checking if there are repeated files**

# %%
# %%bash
# rm /LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/notebooks/history_SiPeCaM/check_simex_error.txt

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"| sed -n 's/.*\(_.*.JPG\)/\1/p' >> check_simex_error.txt

# %%
# %%bash
# head -n 10 check_simex_error.txt
# Out:
# _4544.JPG
# _1640.JPG
# _8776.JPG
# _4768.JPG
# _7924.JPG
# _0457.JPG
# _2015.JPG
# _2891.JPG
# _5081.JPG
# _6788.JPG

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"| sed -n 's/.*\(_.*.AVI\)/\1/p' >> check_simex_error.txt

# %%
# %%bash
# tail -n 10 check_simex_error.txt
# Out:
# _0954.AVI
# _7566.AVI
# _8865.AVI
# _4110.AVI
# _2418.AVI
# _6381.AVI
# _1266.AVI
# _5958.AVI
# _5034.AVI
# _5298.AVI

# %%
# %%bash
# sort check_simex_error.txt|uniq -c > check_simex_error_uniq.txt

# %%
# %%bash
# grep "[2-9] _.*.JPG" check_simex_error_uniq.txt
# Out:
#       3 _0001.JPG
#       3 _0002.JPG
#       3 _0004.JPG
#       3 _0005.JPG
#       3 _0007.JPG
#       3 _0008.JPG
#       2 _0010.JPG
#       2 _0011.JPG
#       2 _0013.JPG
#       2 _0014.JPG
#       2 _0016.JPG
#       2 _0017.JPG
#       2 _0019.JPG
#       2 _0020.JPG

# %%
# %%bash
# grep "[2-9] _.*.AVI" check_simex_error_uniq.txt
# Out:
#       3 _0003.AVI
#       3 _0006.AVI
#       2 _0009.AVI
#       2 _0012.AVI
#       2 _0015.AVI
#       2 _0018.AVI
#       2 _0021.AVI

# %% [markdown]
# **There are repeated files for example:...:**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"| grep ".*_0001.JPG"
# Out:
# 14a706254d2bb64dcfbcfb4d42ae1826_0001.JPG
# 94496b4a1f9996c9adfcb8b1dcd1b958_0001.JPG
# d0d9ed41273b58358457cefa4eeed4f4_0001.JPG

# %% [markdown]
# **Let's check which files are the ones that must be deleted, two JPG's (numbers 1 to 8), one JPG (numbers 10 to 20), two videos (numbers 3, 6, 9) and one video (numbers 12, 15, 18, 21) must be deleted**

# %% [markdown]
# **Checking move log file for dirs:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/
# ```

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"
# Out:
# 2022-03-17 10:58:21,922 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX has serial number HLPXGM09048642
# 2022-03-17 10:58:21,923 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/RCNX0004.JPG has date 2021-08-04
# 2022-03-17 10:58:21,923 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/RCNX0006.AVI has date 2021-08-04
# 2022-03-17 10:58:21,924 [INFO]  DaysBetweenFirstAndLastDate: 0
# 2022-03-17 10:58:22,081 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048642", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-04", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-04", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 30 "$f"
# Out:
# 2022-03-17 10:58:23,266 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX has serial number HLPXGM09048642
# 2022-03-17 10:58:23,267 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/RCNX0049.JPG has date 2021-08-04
# 2022-03-17 10:58:23,267 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/RCNX9312.AVI has date 2021-11-24
# 2022-03-17 10:58:23,267 [INFO]  DaysBetweenFirstAndLastDate: 112
# 2022-03-17 10:58:23,419 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048642", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-04", valueType: String, operator: gte}, {field: date_deployment, value: "2021-11-24", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/logs_simex_move_files_to_standard_directory.logs"
# head -n 70 "$f"
# Out:
# 2022-03-17 11:06:30,906 [INFO]  Dir /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX has serial number HLPXGM09048642
# 2022-03-17 11:06:30,908 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/RCNX0004.JPG has date 2021-08-04
# 2022-03-17 11:06:30,908 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/RCNX0021.AVI has date 2021-08-04
# 2022-03-17 11:06:30,908 [INFO]  DaysBetweenFirstAndLastDate: 0
# 2022-03-17 11:06:31,058 [INFO]  Query to Zendro GQL: query {
#   physical_devices(pagination: {limit: 0}, search: {field: serial_number, value: "HLPXGM09048642", operator: like}) {
#     device_deploymentsFilter(pagination: {limit: 0}, search: {operator: and, search: [{field: date_deployment, value: "2021-08-04", valueType: String, operator: gte}, {field: date_deployment, value: "2021-08-04", valueType: String, operator: lte}]}) {
#       node {
#         nomenclatura
# ...

# %% [markdown]
# **The files which have DaysBetweenFirstAndLastDate: 0 are possible erronous:**
#
# ```
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/
#
# /LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/
# ```

# %% [markdown]
# **Copying some files to check what info have**

# %%
# %%bash
# rm check_simex_error_names.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name \(.*.AVI\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.AVI"| sed -n 's/.* with name \(.*.AVI\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# head -n 50 check_simex_error_names.txt
# Out:
# 62013a1875058661af1730f2392ed656_0003.AVI
# 12f7e12581099e6a24a15d1e3b896167_0006.AVI
# efa128f9550dd6cbccf5ff274fd1ce41_0012.AVI
# 7c60d1978e3822dd83be992cc7064e4e_0009.AVI
# 8faa63a38a3a2e66dd0d83ae606ca194_0003.AVI
# 4ffd806112847fd4e855e630d384e194_0006.AVI
# ed6df256120043ff7ded3b01fb376f0d_0018.AVI
# 8963e9276785ef37f5943fb59734589b_0015.AVI
# 10830bc0b2e4cf9e2f1a794ff53c86de_0021.AVI

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/101RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name \(.*.JPG\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/100RECNX/logs_simex_move_files_to_standard_directory.logs"
# cat "$f"|grep ".* with name .*.JPG"| sed -n 's/.* with name \(.*.JPG\)/\1/;p' >> check_simex_error_names.txt

# %%
# %%bash
# cat check_simex_error_names.txt
# Out:
# 62013a1875058661af1730f2392ed656_0003.AVI
# 12f7e12581099e6a24a15d1e3b896167_0006.AVI
# efa128f9550dd6cbccf5ff274fd1ce41_0012.AVI
# 7c60d1978e3822dd83be992cc7064e4e_0009.AVI
# 8faa63a38a3a2e66dd0d83ae606ca194_0003.AVI
# 4ffd806112847fd4e855e630d384e194_0006.AVI
# ed6df256120043ff7ded3b01fb376f0d_0018.AVI
# 8963e9276785ef37f5943fb59734589b_0015.AVI
# 10830bc0b2e4cf9e2f1a794ff53c86de_0021.AVI
# cbd0edf3eb6d824c3c29cca32f495463_0004.JPG
# b05bb92e9cfa1e296ad034434468f313_0005.JPG
# fd74ae462ad50463c631518853e8280e_0008.JPG
# 7fc41879c0e7bdc285ce41efd13ce145_0007.JPG
# 7a626e14415bc16b91d4c7fa0169f4eb_0002.JPG
# 94496b4a1f9996c9adfcb8b1dcd1b958_0001.JPG
# b80e1585fda73cb6063934c95cf6adb7_0004.JPG
# 39f53c6ee6160ec2fd232ba1c47b2a0a_0011.JPG
# 1e6f90821f11cf576c01baf4c4188a4c_0019.JPG
# 5d0b8652d5dffaaa33ae3e8e1ca65734_0013.JPG
# 33b3ad679c39dcea0b3ee18fd365dfe5_0014.JPG
# 41c5d4aa5b1786a163d32c04cc4ebb75_0005.JPG
# a982c2ab1f938e3a5f9a7a37e68e68c1_0016.JPG
# ...

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos"
# dest="/LUSTRE/sacmod/SIPECAM/sipecam-metadata-extractor/sipecam_files_simex_error/"
# for f in $(cat check_simex_error_names.txt)
#     do
#     cp "$d/$f" "$dest"
# done

# %% [markdown]
# **This videos and images are of persons that are putting device in the site... will be deleted**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"|grep ".*_0001.JPG"
# Out:
# 14a706254d2bb64dcfbcfb4d42ae1826_0001.JPG
# 94496b4a1f9996c9adfcb8b1dcd1b958_0001.JPG
# d0d9ed41273b58358457cefa4eeed4f4_0001.JPG

# %% [markdown]
# **delete**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos"
# for f in $(cat check_simex_error_names.txt)
#     do
#     rm "$d/$f"
# done

# %% [markdown]
# **check**

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"|grep ".*_0001.JPG"
# Out:
# 14a706254d2bb64dcfbcfb4d42ae1826_0001.JPG

# %% [markdown]
# **Also mp4 and webm**

# %%
# %%bash
# rm check_simex_error_names.txt

# %%
# %%bash
# echo "62013a1875058661af1730f2392ed656_0003.mp4" >> check_simex_error_names.txt
# echo "12f7e12581099e6a24a15d1e3b896167_0006.mp4" >> check_simex_error_names.txt
# echo "efa128f9550dd6cbccf5ff274fd1ce41_0012.mp4" >> check_simex_error_names.txt
# echo "7c60d1978e3822dd83be992cc7064e4e_0009.mp4" >> check_simex_error_names.txt
# echo "8faa63a38a3a2e66dd0d83ae606ca194_0003.mp4" >> check_simex_error_names.txt
# echo "4ffd806112847fd4e855e630d384e194_0006.mp4" >> check_simex_error_names.txt
# echo "ed6df256120043ff7ded3b01fb376f0d_0018.mp4" >> check_simex_error_names.txt
# echo "8963e9276785ef37f5943fb59734589b_0015.mp4" >> check_simex_error_names.txt
# echo "10830bc0b2e4cf9e2f1a794ff53c86de_0021.mp4" >> check_simex_error_names.txt
#
# echo "62013a1875058661af1730f2392ed656_0003.webm" >> check_simex_error_names.txt
# echo "12f7e12581099e6a24a15d1e3b896167_0006.webm" >> check_simex_error_names.txt
# echo "efa128f9550dd6cbccf5ff274fd1ce41_0012.webm" >> check_simex_error_names.txt
# echo "7c60d1978e3822dd83be992cc7064e4e_0009.webm" >> check_simex_error_names.txt
# echo "8faa63a38a3a2e66dd0d83ae606ca194_0003.webm" >> check_simex_error_names.txt
# echo "4ffd806112847fd4e855e630d384e194_0006.webm" >> check_simex_error_names.txt
# echo "ed6df256120043ff7ded3b01fb376f0d_0018.webm" >> check_simex_error_names.txt
# echo "8963e9276785ef37f5943fb59734589b_0015.webm" >> check_simex_error_names.txt
# echo "10830bc0b2e4cf9e2f1a794ff53c86de_0021.webm" >> check_simex_error_names.txt

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"|grep ".*_0021"
# Out:
# 10830bc0b2e4cf9e2f1a794ff53c86de_0021.mp4
# 10830bc0b2e4cf9e2f1a794ff53c86de_0021.webm
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.AVI
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.mp4
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.webm

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos"
# for f in $(cat check_simex_error_names.txt)
#     do
#     rm "$d/$f"
# done

# %%
# %%bash
# d="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# ls "$d"|grep ".*_0021"
# Out:
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.AVI
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.mp4
# 5621d60d0d1a57da0fd97d5fce91e2d3_0021.webm

# %% [markdown]
# **Which info json need to be included?**

# %% [markdown]
# info from: /LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_09-05-2022.json
#
# ```
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048642",
#         "NomenclatureNode": "1_95_0_1348",
#         "CumulusName": "95",
#         "DateDeployment": "2021-08-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 31.26391,
#         "Longitude": -108.95454,
#         "NodeCategoryIntegrity": "Degradado",
#         "CentroidCumulusLatitude": 31.22829,
#         "CentroidCumulusLongitude": -108.85782
#     }
# ```

# %% [markdown]
# info from:

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/102RECNX_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$f"|head -n 50
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048642"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_95/Imagenes/Degradado/CAM_01_RanchoNuevo/102RECNX/RCNX8372.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:16 12:21:13",
#             "SerialNumber": "HLPXGM09048642",
#             "FileSize": "878 KiB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
#             "ImageWidth": 2048,
#             "ImageHeight": 1440,
#             "EncodingProcess": "Baseline DCT, Huffman coding",
#             "BitsPerSample": 8,
#             "ColorComponents": 3,
#             "YCbCrSubSampling": "YCbCr4:2:2 (2 1)",
#             "XResolution": 72,
#             "YResolution": 72,
#             "ResolutionUnit": "inches",
#             "YCbCrPositioning": "Co-sited",
# ...

# %% [markdown]
# **extract**

# %%
# %%bash
# dir_to_be_processed="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/"
# #if number_of_processes is passed as arg then is assumed will execute in parallel
# extract_serial_numbers_dates_and_metadata_of_files_and_device --input_dir "$dir_to_be_processed" --number_of_processes 12

# %% [markdown]
# **Check**

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_24-06-2022.json"
# python3 -mjson.tool "$f"|head -n 80
# Out:
# {
#     "MetadataDevice": {
#         "Make": "RECONYX",
#         "Model": "HF2 PRO COVERT",
#         "SerialNumber": "HLPXGM09048642",
#         "NomenclatureNode": "1_95_0_1348",
#         "CumulusName": "95",
#         "CentroidCumulusLatitude": 31.22829,
#         "CentroidCumulusLongitude": -108.85782,
#         "DateDeployment": "2021-08-04",
#         "EcosystemsName": "Bosques templados",
#         "Latitude": 31.26391,
#         "Longitude": -108.95454,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/d1a3a6fbd2b688b3bf45e776ef90f253_5159.JPG": {
#             "Make": "RECONYX",
#             "Model": "HF2 PRO COVERT",
#             "DateTimeOriginal": "2021:10:10 12:21:12",
#             "SerialNumber": "HLPXGM09048642",
#             "FileSize": "886 kB",
#             "ExifByteOrder": "Little-endian (Intel, II)",
# ...

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_24-06-2022.json"
# python3 -mjson.tool "$f"|tail -n 80
# Out:
#             "AudioSampleRate": "16.0 kHz",
#             "AudioCompressionRate": "1.0x",
#             "AudioCompression": "Microsoft Pulse Code Modulation (PCM)",
#             "AudioBitRate": "256.4 Kbit/sec",
#             "FileSize": "12 MB",
#             "DateTimeOriginal": "2021:09:27 12:55:19",
#             "BMPVersion": "Windows V3",
#             "ImageWidth": 1024,
#             "ImageHeight": 720,
#             "Planes": 1,
#             "ImageLength": 2211840,
#             "PixelsPerMeterX": 0,
#             "PixelsPerMeterY": 0,
#             "NumColors": "Use BitDepth",
#             "NumImportantColors": "All",
#             "FrameRate": 12.5,
#             "FrameCount": 75,
#             "StreamCount": 2,
#             "AudioSampleCount": 0,
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "AvgBytesPerSec": 32050,
#             "BitsPerSample": 16,
#             "Duration": "6.00 s",
#             "MaxDataRate": 26542080,
# ...

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json" there's metadata incomplete of two audios: `53f6a102762d957a304394a618cc9da3.WAV` `ae933ffd95e4d4b06a04143bc0962510.WAV`

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$json" | head -n 60
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 49,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 243B1F055B1F3FD2",
#         "SerialNumber": "243B1F055B1F3FD2",
#         "NomenclatureNode": "3_13_1_1393",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-08-11",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3012978,
#         "Longitude": -91.7258889,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/78e68fdf513c1cdb51f3f54a3c558514.WAV": {
#             "Battery": "3.9V",
#             "Datetime": "21:20:00 18/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
# ...

# %% [markdown]
# For example, file `78e68fdf513c1cdb51f3f54a3c558514.WAV` exists in dir and in json:

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/78e68fdf513c1cdb51f3f54a3c558514.WAV"
# ls "$f"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/78e68fdf513c1cdb51f3f54a3c558514.WAV

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|grep "78e68fdf513c1cdb51f3f54a3c558514.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/78e68fdf513c1cdb51f3f54a3c558514.WAV": {

# %% [markdown]
# But `53f6a102762d957a304394a618cc9da3.WAV` exist in dir and not in json

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/53f6a102762d957a304394a618cc9da3.WAV"
# ls "$f"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/53f6a102762d957a304394a618cc9da3.WAV

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|grep "53f6a102762d957a304394a618cc9da3.WAV"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"\npython3 -mjson.tool "$j"|grep "53f6a102762d957a304394a618cc9da3.WAV"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %% [markdown]
# **Also for file `ae933ffd95e4d4b06a04143bc0962510.WAV`**

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"
# python3 -mjson.tool "$j"|grep "ae933ffd95e4d4b06a04143bc0962510.WAV"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json"\npython3 -mjson.tool "$j"|grep "ae933ffd95e4d4b06a04143bc0962510.WAV"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %% [markdown]
# **Which dirs had WAV files referred in move cli logs?**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_02-06-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep '243B1F055B1F3FD2' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Ultra/10263609/10263609_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Grabadoras/Audible 2/10261149/10261149_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1393/Audible/10262012/10262012_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_0_1399 LAS PIEDRAS/Audiomoth 1/AudioMoths.N5.T4/AudioMoths.N5.T4_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's review...**

# %% [markdown]
# **File: `53f6a102762d957a304394a618cc9da3.WAV`**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089/logs_simex_move_files_to_standard_directory.logs"
# grep "53f6a102762d957a304394a618cc9da3.WAV" "$logs"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089/logs_simex_move_files_to_standard_directory.logs"\ngrep "53f6a102762d957a304394a618cc9da3.WAV" "$logs"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/logs_simex_move_files_to_standard_directory.logs"
# grep "53f6a102762d957a304394a618cc9da3.WAV" "$logs"
# Out:
# 2022-06-10 11:49:53,630 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210913_021000.WAV will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible with name 53f6a102762d957a304394a618cc9da3.WAV

# %% [markdown]
# **lets check extract cli logs**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs"
# grep "20210913_021000.WAV" "$logs"
# Out:
# 2022-06-04 21:27:04,764 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210913_021000.WAV
# 2022-06-04 21:27:04,764 [INFO]  SUCCESSFUL extraction of date of /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210913_021000.WAV

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/10262089_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json" | grep -B20 -A20 "20210913_021000.WAV"
# Out:
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 03:00:00 15/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 4.0V and temperature was 25.8C.",
#             "Duration": 60.0050833333333
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210829_023000.WAV": {
#             "Battery": "4.2V",
#             "Datetime": "02:30:00 29/08/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
# ...

# %% [markdown]
# **Not sure why in json when `move` cli executed don't have the metadata of `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/53f6a102762d957a304394a618cc9da3.WAV`**

# %% [markdown]
# **Metadata ref:**

# %% [markdown]
# ```
# "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210913_021000.WAV": {
#             "Battery": "4.0V",
#             "Datetime": "02:10:00 13/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 02:10:00 13/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 4.0V and temperature was 24.7C.",
#             "Duration": 60.0050833333333,
#             "Latitude": 18.3012978,
#             "Longitude": -91.7258889,
#             "CentroidCumulusLatitude": 18.16965,
#             "CentroidCumulusLongitude": -91.82522
#         }
# ```

# %% [markdown]
# **file: `ae933ffd95e4d4b06a04143bc0962510.WAV`**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089/logs_simex_move_files_to_standard_directory.logs"
# grep "ae933ffd95e4d4b06a04143bc0962510.WAV" "$logs"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1392 NICTEHA 2/10262089/logs_simex_move_files_to_standard_directory.logs"\ngrep "ae933ffd95e4d4b06a04143bc0962510.WAV" "$logs"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/logs_simex_move_files_to_standard_directory.logs"
# grep "ae933ffd95e4d4b06a04143bc0962510.WAV" "$logs"
# Out:
# 2022-06-10 11:50:37,214 [INFO]  File /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210921_192000.WAV will be moved to: /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible with name ae933ffd95e4d4b06a04143bc0962510.WAV

# %% [markdown]
# **lets check extract cli logs**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs"
# grep "20210921_192000.WAV" "$logs"
# Out:
# 2022-06-04 21:27:04,865 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210921_192000.WAV
# 2022-06-04 21:27:04,865 [INFO]  SUCCESSFUL extraction of date of /LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210921_192000.WAV

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/10262089_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json" | grep -B20 -A20 "20210921_192000.WAV"
# Out:
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 14:40:00 26/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 3.6V and temperature was 32.6C.",
#             "Duration": 60.0050833333333
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210901_232000.WAV": {
#             "Battery": "4.1V",
#             "Datetime": "23:20:00 01/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
# ...

# %% [markdown]
# **Not sure why in json when `move` cli executed don't have the metadata of `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/ae933ffd95e4d4b06a04143bc0962510.WAV`**

# %% [markdown]
# **Metadata ref:**

# %% [markdown]
# ```
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210921_192000.WAV": {
#             "Battery": "3.7V",
#             "Datetime": "19:20:00 21/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 19:20:00 21/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 3.7V and temperature was 25.0C.",
#             "Duration": 60.0050833333333,
#             "Latitude": 18.3012978,
#             "Longitude": -91.7258889,
#             "CentroidCumulusLatitude": 18.16965,
#             "CentroidCumulusLongitude": -91.82522
#         }
# ```

# %% [markdown]
# **What was the reason?**

# %% [markdown]
# **Let's check the json to see the Days**

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/10262089_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|head -n 50
# Out:
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 243B1F055B1F3FD2",
#         "SerialNumber": "243B1F055B1F3FD2"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210918_212000.WAV": {
#             "Battery": "3.9V",
#             "Datetime": "21:20:00 18/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 21:20:00 18/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 3.9V and temperature was 24.8C.",
#             "Duration": 60.0050833333333
# ...

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/10262089_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|tail -n 50
# Out:
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 22:30:00 06/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 4.1V and temperature was 27.4C.",
#             "Duration": 60.0050833333333
#         },
#         "/LUSTRE/sacmod/SIPECAM/cumulo_13/entrega_27.abril.2022/SIPECAM AUDIOS/Nodo 3_13_1_1394 NICTEHA 1/10262089/20210921_124000.WAV": {
#             "Battery": "3.8V",
#             "Datetime": "12:40:00 21/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
# ...

# %% [markdown]
# **"DaysBetweenFirstAndLastDate": 49 , then this wasn't the reason**

# %% [markdown]
# **Just need to include these metadata of those files in: `/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_10-06-2022.json`**

# %% [markdown]
# **Will use cli `extend`  metadata for audio files**

# %%
# %%bash
# input_dir="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/"
# extend_metadata_of_audio_files --input_directory_audio "$input_dir"

# %% [markdown]
# **Check**

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$json" |head -n 50
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 49,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 243B1F055B1F3FD2",
#         "SerialNumber": "243B1F055B1F3FD2",
#         "NomenclatureNode": "3_13_1_1393",
#         "CumulusName": "13",
#         "CentroidCumulusLatitude": 18.16965,
#         "CentroidCumulusLongitude": -91.82522,
#         "DateDeployment": "2021-08-11",
#         "EcosystemsName": "Selvas humedas",
#         "Latitude": 18.3012978,
#         "Longitude": -91.7258889,
#         "NodeCategoryIntegrity": "Integro"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/78e68fdf513c1cdb51f3f54a3c558514.WAV": {
#             "Battery": "3.9V",
#             "Datetime": "21:20:00 18/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
# ...

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$json" |tail -n 50
# Out:
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 06:50:00 11/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 4.0V and temperature was 25.5C.",
#             "Duration": 60.0050833333333,
#             "Latitude": 18.3012978,
#             "Longitude": -91.7258889,
#             "CentroidCumulusLatitude": 18.16965,
#             "CentroidCumulusLongitude": -91.82522
#         },
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/ae933ffd95e4d4b06a04143bc0962510.WAV": {
#             "Battery": "3.7V",
#             "Datetime": "19:20:00 21/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
# ...

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$j"|grep -A40 "53f6a102762d957a304394a618cc9da3.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/53f6a102762d957a304394a618cc9da3.WAV": {
#             "Battery": "4.0V",
#             "Datetime": "02:10:00 13/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 02:10:00 13/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 4.0V and temperature was 24.7C.",
#             "Duration": 60.0050833333333,
#             "Latitude": 18.3012978,
#             "Longitude": -91.7258889,
#             "CentroidCumulusLatitude": 18.16965,
# ...

# %% [markdown]
# **Also for file `ae933ffd95e4d4b06a04143bc0962510.WAV`**

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$j"|grep -A30 "ae933ffd95e4d4b06a04143bc0962510.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/ae933ffd95e4d4b06a04143bc0962510.WAV": {
#             "Battery": "3.7V",
#             "Datetime": "19:20:00 21/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "768.0 Kbit/sec",
#             "SerialNumber": "243B1F055B1F3FD2",
#             "FileSize": "5.5 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 48000,
#             "AvgBytesPerSec": 96000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 19:20:00 21/09/2021 (UTC-6) by AudioMoth 243B1F055B1F3FD2 at medium gain setting while battery state was 3.7V and temperature was 25.0C.",
#             "Duration": 60.0050833333333,
#             "Latitude": 18.3012978,
#             "Longitude": -91.7258889,
#             "CentroidCumulusLatitude": 18.16965,
# ...

# %% [markdown]
# # In file "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json" there's metadata incomplete of one audio: `67acc1799111d5ab3fa7bad695676f1a.WAV`

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json"
# python3 -mjson.tool "$json" | head -n 50
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 52,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 2453AC025DAEB669",
#         "SerialNumber": "2453AC025DAEB669",
#         "NomenclatureNode": "4_32_0_1280",
#         "CumulusName": "32",
#         "CentroidCumulusLatitude": 18.42113,
#         "CentroidCumulusLongitude": -99.09369,
#         "DateDeployment": "2021-08-23",
#         "EcosystemsName": "Selvas secas",
#         "Latitude": 18.49711,
#         "Longitude": -99.14328,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/5e9ee27c0d4d6e39b6326fe0882a9d06.WAV": {
#             "Battery": "4.5V",
#             "Datetime": "21:20:00 18/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
# ...

# %% [markdown]
# For example, file `5e9ee27c0d4d6e39b6326fe0882a9d06.WAV` exists in dir and in json:

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/5e9ee27c0d4d6e39b6326fe0882a9d06.WAV"
# ls "$f"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/5e9ee27c0d4d6e39b6326fe0882a9d06.WAV

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json"
# python3 -mjson.tool "$j"|grep "5e9ee27c0d4d6e39b6326fe0882a9d06.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/5e9ee27c0d4d6e39b6326fe0882a9d06.WAV": {

# %% [markdown]
# But `67acc1799111d5ab3fa7bad695676f1a.WAV` exist in dir and not in json

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV"
# ls "$f"
# Out:
# /LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json"
# python3 -mjson.tool "$j"|grep "67acc1799111d5ab3fa7bad695676f1a.WAV"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'j="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json"\npython3 -mjson.tool "$j"|grep "67acc1799111d5ab3fa7bad695676f1a.WAV"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %% [markdown]
# **Which dirs had WAV files referred in move cli logs?**

# %%
# %%bash
# list_of_dirs_to_be_processed=/shared_volume/sipecam_subdirectories_04-04-2022.txt
# SAVEIFS=$IFS;IFS=$(echo -en "\n\b")
# for dir_to_be_processed in $(cat $list_of_dirs_to_be_processed)
#     do
#     json=$(find "$dir_to_be_processed" -name "*extract*json")
#     echo "$json"
#     python3 -mjson.tool "$json"|grep '2453AC025DAEB669' | head -n 5
# done
# IFS=$SAVEIFS
# Out:
# /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-1-1287/grabadoras/ultrasonico/camara_03_par2/camara_03_par2_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-1-1287/grabadoras/ultrasonico/camara_05_par3/camara_05_par3_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-1-1287/grabadoras/ultrasonico/camara_01_par1/camara_01_par1_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-1-1287/grabadoras/audible/camara_05_par_03/camara_05_par_03_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json
# ...

# %% [markdown]
# **Let's review...**

# %% [markdown]
# **File: `67acc1799111d5ab3fa7bad695676f1a.WAV`**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-0-1281/grabadoras/ultrasonico/camara06_par01/logs_simex_move_files_to_standard_directory.logs"
# grep "67acc1799111d5ab3fa7bad695676f1a.WAV" "$logs"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_2/Noviembre_2021/4-32-0-1281/grabadoras/ultrasonico/camara06_par01/logs_simex_move_files_to_standard_directory.logs"\ngrep "67acc1799111d5ab3fa7bad695676f1a.WAV" "$logs"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_3/Dic_21_-_Enero_22/4-32-0-1279/grabadoras/ultrasonico/camara_06_par01/logs_simex_move_files_to_standard_directory.logs"
# grep "67acc1799111d5ab3fa7bad695676f1a.WAV" "$logs"
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_3/Dic_21_-_Enero_22/4-32-0-1279/grabadoras/ultrasonico/camara_06_par01/logs_simex_move_files_to_standard_directory.logs"\ngrep "67acc1799111d5ab3fa7bad695676f1a.WAV" "$logs"\n')
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.8/dist-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# ...

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/logs_simex_move_files_to_standard_directory.logs"
# grep "67acc1799111d5ab3fa7bad695676f1a.WAV" "$logs"
# Out:
# 2022-04-04 22:26:56,533 [INFO]  File /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210902_044000.WAV will be moved to: /LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico with name 67acc1799111d5ab3fa7bad695676f1a.WAV

# %% [markdown]
# **lets check extract cli logs**

# %%
# %%bash
# logs="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/logs_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.logs"
# grep "20210902_044000.WAV" "$logs"
# Out:
# 2022-04-04 19:12:25,962 [INFO]  extraction of date of /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210902_044000.WAV
# 2022-04-04 19:12:25,962 [INFO]  SUCCESSFUL extraction of date of /LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210902_044000.WAV

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/grabadora_01_par02_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json" | grep  -A30 "20210902_044000.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210902_044000.WAV": {
#             "Battery": "4.6V",
#             "Datetime": "04:40:00 02/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "7.0 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
#             "AvgBytesPerSec": 768000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 04:40:00 02/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 20.1C.",
#             "Duration": "9.56 s"
#         },
# ...

# %% [markdown]
# **Metadata ref:**

# %% [markdown]
# ```
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV": {
#             "Battery": "4.6V",
#             "Datetime": "04:40:00 02/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "7.0 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
#             "AvgBytesPerSec": 768000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 04:40:00 02/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 20.1C.",
#             "Duration": "9.56 s",
#             "Latitude": 18.49711,
#             "Longitude": -99.14328,
#             "CentroidCumulusLatitude": 18.42113,
#             "CentroidCumulusLongitude": -99.09369
#         }
# ```

# %%
# %%bash
# f="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV"
# exiftool -a -j "$f"
# Out:
# [{
#   "SourceFile": "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV",
#   "ExifToolVersion": 12.42,
#   "FileName": "67acc1799111d5ab3fa7bad695676f1a.WAV",
#   "Directory": "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico",
#   "FileSize": "7.3 MB",
#   "FileModifyDate": "2022:03:29 03:15:06-06:00",
#   "FileAccessDate": "2022:04:09 22:10:21-05:00",
#   "FileInodeChangeDate": "2022:05:01 09:43:07-05:00",
#   "FilePermissions": "-rwxrwxrwx",
#   "FileType": "WAV",
#   "FileTypeExtension": "wav",
#   "MIMEType": "audio/x-wav",
#   "Encoding": "Microsoft PCM",
#   "NumChannels": 1,
#   "SampleRate": 384000,
#   "AvgBytesPerSec": 768000,
#   "BitsPerSample": 16,
#   "Comment": "Recorded at 04:40:00 02/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 20.1C.",
# ...

# %% [markdown]
# **What was the reason?**

# %% [markdown]
# **Let's check the json to see the Days**

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/grabadora_01_par02_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|head -n 50
# Out:
# {
#     "MetadataDevice": {
#         "Artist": "AudioMoth 2453AC025DAEB669",
#         "SerialNumber": "2453AC025DAEB669"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210830_000000.WAV": {
#             "Battery": "4.6V",
#             "Datetime": "00:00:00 30/08/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
#             "AvgBytesPerSec": 768000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 00:00:00 30/08/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 21.8C.",
# ...

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/grabadora_01_par02_simex_extract_serial_numbers_dates_and_metadata_of_files_and_device.json"
# python3 -mjson.tool "$json"|tail -n 50
# Out:
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
#             "AvgBytesPerSec": 768000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 03:20:00 01/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 19.4C.",
#             "Duration": "0:00:30"
#         },
#         "/LUSTRE/sacmod/SIPECAM/Cumulo_32/fecha_entrga_28.Marzo.2022/visita_1/AGO-OCT-2021/4-32-0-1280/Grabadoras/ultrasonico/grabadora_01_par02/20210828_004000.WAV": {
#             "Battery": "4.7V",
#             "Datetime": "00:40:00 28/08/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
# ...

# %% [markdown]
# **"DaysBetweenFirstAndLastDate": 10 , then this wasn't the reason**

# %% [markdown]
# **Just need to include these metadata of this file in: `/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_04-05-2022.json`**

# %% [markdown]
# **Will use cli `extend`  metadata for audio files**

# %%
# %%bash
# input_dir="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/"
# extend_metadata_of_audio_files --input_directory_audio "$input_dir"

# %% [markdown]
# **Check**

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$json" |head -n 50
# Out:
# {
#     "DaysBetweenFirstAndLastDate": 52,
#     "MetadataDevice": {
#         "Artist": "AudioMoth 2453AC025DAEB669",
#         "SerialNumber": "2453AC025DAEB669",
#         "NomenclatureNode": "4_32_0_1280",
#         "CumulusName": "32",
#         "CentroidCumulusLatitude": 18.42113,
#         "CentroidCumulusLongitude": -99.09369,
#         "DateDeployment": "2021-08-23",
#         "EcosystemsName": "Selvas secas",
#         "Latitude": 18.49711,
#         "Longitude": -99.14328,
#         "NodeCategoryIntegrity": "Degradado"
#     },
#     "MetadataFiles": {
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/5e9ee27c0d4d6e39b6326fe0882a9d06.WAV": {
#             "Battery": "4.5V",
#             "Datetime": "21:20:00 18/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
# ...

# %%
# %%bash
# json="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$json" |tail -n 50
# Out:
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 03:20:00 17/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.5V and temperature was 20.7C.",
#             "Duration": 30.0006354166667,
#             "Latitude": 18.49711,
#             "Longitude": -99.14328,
#             "CentroidCumulusLatitude": 18.42113,
#             "CentroidCumulusLongitude": -99.09369
#         },
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/a38e6127efd0807ce586f61a62e33556.WAV": {
#             "Battery": "4.5V",
#             "Datetime": "02:00:00 17/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "22 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
# ...

# %%
# %%bash
# j="/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_26-06-2022.json"
# python3 -mjson.tool "$j"|grep -A40 "67acc1799111d5ab3fa7bad695676f1a.WAV"
# Out:
#         "/LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/67acc1799111d5ab3fa7bad695676f1a.WAV": {
#             "Battery": "4.6V",
#             "Datetime": "04:40:00 02/09/2021 (UTC-0600)",
#             "Gain": "medium",
#             "Timezone": "UTC",
#             "BitRate": "6.1 Mbit/sec",
#             "SerialNumber": "2453AC025DAEB669",
#             "FileSize": "7.0 MiB",
#             "Encoding": "Microsoft PCM",
#             "NumChannels": 1,
#             "SampleRate": 384000,
#             "AvgBytesPerSec": 768000,
#             "BitsPerSample": 16,
#             "Comment": "Recorded at 04:40:00 02/09/2021 (UTC-6) by AudioMoth 2453AC025DAEB669 at medium gain setting while battery state was 4.6V and temperature was 20.1C.",
#             "Duration": "9.56 s",
#             "Latitude": 18.49711,
#             "Longitude": -99.14328,
#             "CentroidCumulusLatitude": 18.42113,
# ...

# %% [markdown]
# **In summary, jsons that were upated after this notebook**

# %% [markdown]
# ```
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049504/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049093/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09049482/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_22-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/95/1_95_0_1348/HLPXGM09048642/2021-08-04/images_videos/images_videos_simex_metadata_files_and_device_24-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1392/HLPXGM09048888/2021-10-09/images_videos/images_videos_simex_metadata_files_and_device_23-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/13/3_13_1_1393/243B1F055B1F3FD2/2021-08-11/audios/Audible/Audible_simex_metadata_files_and_device_26-06-2022.json
# /LUSTRE/sacmod/SIPECAM/data/32/4_32_0_1280/2453AC025DAEB669/2021-08-23/audios/Ultrasonico/Ultrasonico_simex_metadata_files_and_device_26-06-2022.json
# ```

# %% [markdown]
# # What will be done to avoid this missing data in jsons
#
# 1. for audios is not clear the reason(s) why metadata of three WAV's weren't in `move...json` although were in `extract...json`
#
# 2. for images and videos, in `move` cli there will be a condition stating that if `"DaysBetweenFirstAndLastDate"` is greater or equal than 2 then all files will be moved, in other case will not going to be moved to `data` dir.
